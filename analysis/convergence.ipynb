# %%
import os
import json
import math
import numpy as np
import scipy.stats as stats

inf = math.inf

existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
scores = {"ner": {}, "pos": {}, "copa": {}, "qa": {}}
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1"}

for file in os.listdir("../eval_scores/approximation"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/approximation", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                # print(els)

                if len(els) == 3:
                    lang_name, task_name, option = els
                elif len(els) == 4:
                    lang_name, task_name, option, num = els
                else:
                    raise ValueError

                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}

                # we add the data to the scores dictionary:
                # if option == extended, we add everything
                # otherwise, we append the "option" to the keys and add those

                for key in data.keys():
                    if not option == "extended":
                        new_key = f"{key}_{option}"
                    else:
                        new_key = key
                    if "convergence" in new_key:
                        # we skip the convergence scores
                        # print(new_key, "not taking convergence scores")
                        continue
                    # print(key, new_key)
                    scores[task_name][lang_name][new_key] = data[key][f1[task_name]]

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# Adding finetune baseline
for file in os.listdir("../eval_scores/ft"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/ft", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                if len(els) == 3:
                    lang_name, task_name, option = els
                else:
                    raise ValueError
                if option == "eval":
                    option = "finetune"
                else:
                    option = "finetune_" + option
                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}
                score = data["finetuned_model"][f1[task_name]]
                scores[task_name][lang_name][option] = score

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# we make a subset consisting of only the languages for which an adapter exists
scores_subset = {}
no_adapter = {}
for task_name in scores:
    scores_subset[task_name] = {}
    no_adapter[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name in existing_adapters:
            scores_subset[task_name][lang_name] = scores[task_name][lang_name]
        else:
            no_adapter[task_name][lang_name] = scores[task_name][lang_name]
# adding convergence scores
for file in os.listdir("../eval_scores/convergence"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/convergence", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                # print(els)

                if len(els) == 3:
                    lang_name, task_name, option = els
                elif len(els) == 4:
                    lang_name, task_name, option, num = els
                else:
                    raise ValueError

                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}

                # we add the data to the scores dictionary:
                # if option == extended, we add everything
                # otherwise, we append the "option" to the keys and add those

                for key in data.keys():
                    if not option == "extended":  # correctly format baseline names, "extended" == base case
                        new_key = f"{key}_{option}"
                    else:
                        new_key = key
                    # print(key, new_key)
                    new_key = f"{new_key}_convergence"
                    scores[task_name][lang_name][new_key] = data[key][f1[task_name]]

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)


def get_significance(task_name, option1, option2, alternative="two-sided", data=scores):
    all_scores1 = []
    all_scores2 = []
    if task_name == "all":
        task_names = data.keys()
    elif type(task_name) is str:
        task_names = [task_name]
    else:
        task_names = task_name
    for task_name in task_names:
        for lang_name in data[task_name]:
            if option1 in data[task_name][lang_name] and option2 in data[task_name][lang_name]:
                score1 = data[task_name][lang_name][option1]
                score2 = data[task_name][lang_name][option2]
                if task_name == "qa":
                    # we divide the scores of qa by 100
                    score1 = score1 / 100
                    score2 = score2 / 100
                all_scores1.append(score1)
                all_scores2.append(score2)
    print("average scores")
    print(f"{option1}: {np.mean(all_scores1)}")
    print(f"{option2}: {np.mean(all_scores2)}")
    t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)
    print(f"t-statistic: {t_stat}")
    print(f"p-value: {p_val}")
    return t_stat, p_val

# %%
# we calculate averages of all columns
averages = {}
for task_name in scores:
    averages[task_name] = {}
    for lang_name in scores[task_name]:
        for key in scores[task_name][lang_name]:
            if key not in averages[task_name]:
                averages[task_name][key] = [scores[task_name][lang_name][key], 1]
            else:
                averages[task_name][key][0] += scores[task_name][lang_name][key]
                averages[task_name][key][1] += 1
    averages[task_name] = {key: value[0] / value[1] for key, value in averages[task_name].items()}

# %%
# we compare the averages of each key <> key_converged
better = {}
worse = {}
for task in averages:
    better[task] = []
    worse[task] = []
    keys = averages[task].keys()
    for key in averages[task]:
        conv = key + "_convergence"
        if not key.endswith("convergence") and conv in keys:
            key_score = averages[task][key]
            conv_score = averages[task][conv]
            diff = conv_score - key_score
            if key_score > conv_score:
                worse[task].append((key, diff))
            else:
                better[task].append((key, diff))
print("outperform:", better)
print("worse performance:", worse)
# Out:
# outperform: {'ner': [('reconstructed_featural_base', 0.011284744079776532), ('reconstructed_syntactic_distVar', 0.003084054049485918), ('reconstructed_morphological_distVar', 0.004253261276940423), ('reconstructed_featural_eu', 0.009887806924539833), ('reconstructed_featural', 0.009779546031709385), ('baseline_en', 0.0146985244119342), ('baseline_avg_adapter', 0.011671328275132009), ('baseline_closest_featural', 0.00380655761073162), ('no_train_gain', 0.009286212378280423), ('reconstructed_featural_limit', 0.011702584902354873), ('reconstructed_syntactic_limit', 0.00978524531481062), ('reconstructed_morphological_limit', 0.007568609404203452), ('reconstructed_featural_sr', 0.009960298062257955), ('reconstructed_featural_threshold', 0.01401787579197411), ('reconstructed_syntactic_threshold', 0.015380781322165915), ('reconstructed_morphological_threshold', 0.013128297374519149)], 'pos': [('reconstructed_featural_eu', 0.0012114120443494913), ('baseline_en', 0.005498314720510156), ('baseline_task_adapter', 0.00019326786162021659), ('baseline_closest_featural', 0.0036788307515129848), ('no_train_gain', 0.00015740375790018746), ('reconstructed_featural_sr', 0.0010674525566118365), ('finetune', 0.019636827862103134), ('reconstructed_syntactic_distVar', 0.000605769437527437), ('reconstructed_morphological_distVar', 0.0020533443598297896), ('reconstructed_syntactic_limit', 0.0004660375159392105)], 'copa': [], 'qa': [('reconstructed_featural_base', 0.7409136548756692), ('reconstructed_syntactic_distVar', 2.025472918577904), ('reconstructed_morphological_distVar', 2.0222590331854065), ('reconstructed_featural_eu', 0.7979470838601515), ('reconstructed_featural', 0.882155620690952), ('baseline_en', 0.6365290221385891), ('baseline_task_adapter', 1.0816548192555473), ('baseline_avg_adapter', 0.5957663528372876), ('baseline_closest_featural', 0.3164483489550207), ('no_train_gain', 0.7113511893779787), ('reconstructed_featural_limit', 2.1192207589593437), ('reconstructed_syntactic_limit', 2.2023816033018875), ('reconstructed_morphological_limit', 2.070233125719554), ('reconstructed_featural_sr', 0.8631187544998369), ('reconstructed_featural_threshold', 0.818777524916456), ('reconstructed_syntactic_threshold', 0.8468091611898672), ('reconstructed_morphological_threshold', 0.9761214268848306), ('finetune', 0.7877172078527934)]}
# NO outperform: {'ner': [('baseline_task_adapter', -0.017540217918364076), ('finetune', -0.023793805308459925)], 'pos': [('reconstructed_featural_base', -2.0933590873961627e-05), ('reconstructed_featural', -0.0010761785536012591), ('baseline_avg_adapter', -0.0017089380970460866), ('reconstructed_featural_threshold', -0.0011178162315775841), ('reconstructed_syntactic_threshold', -0.0008555158176261068), ('reconstructed_morphological_threshold', -0.000403774609114782), ('reconstructed_featural_limit', -3.5595587720704813e-06), ('reconstructed_morphological_limit', -0.00037776021045249353)], 'copa': [('reconstructed_featural_base', -0.031636363636363685), ('reconstructed_featural_eu', -0.03327272727272734), ('reconstructed_featural', -0.03781818181818175), ('baseline_en', -0.024545454545454648), ('baseline_task_adapter', -0.04600000000000015), ('baseline_avg_adapter', -0.038363636363636267), ('baseline_closest_featural', -0.04472727272727273), ('no_train_gain', -0.046181818181818324), ('reconstructed_featural_limit', -0.040909090909090895), ('reconstructed_syntactic_limit', -0.040363636363636046), ('reconstructed_morphological_limit', -0.0429090909090909), ('reconstructed_featural_sr', -0.03472727272727261), ('reconstructed_featural_threshold', -0.033636363636363575), ('reconstructed_syntactic_threshold', -0.034909090909091), ('reconstructed_morphological_threshold', -0.03854545454545466), ('finetune', -0.05527272727272725)], 'qa': []}

# %%
# for those in better, we check if they are significantly better.
# for those in worse, if they are significantly worse
tasks = ["ner", "pos", "copa", "qa"]
for task in tasks:
    for key, diff in better[task]:
        print(f"{task} {key} outperforming {key}_convergence")
        t_stat, p_val = get_significance(task, key, key + "_convergence", alternative="less")
        if p_val < 0.05:
            print("The difference IS statistically significant")
        else:
            print("The difference is not statistically significant")
        print("\n")
    for key, diff in worse[task]:
        print(f"{task} {key} UNDERPERFORMING {key}_convergence")
        t_stat, p_val = get_significance(task, key, key + "_convergence", alternative="greater")
        if p_val < 0.05:
            print("The difference IS statistically significant")
        else:
            print("The difference is not statistically significant")
        print("\n")
    print("\n~\n")
# Out:
# ner reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.4928826576088594
# reconstructed_featural_base_convergence: 0.5041674016886359
# t-statistic: -3.6854645006532025
# p-value: 0.0001647721730451718
# The difference IS statistically significant
#
#
# ner reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.49418135784565886
# reconstructed_syntactic_distVar_convergence: 0.4972654118951448
# t-statistic: -0.852656751273577
# p-value: 0.19809547394429444
# The difference is not statistically significant
#
#
# ner reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.493589017046471
# reconstructed_morphological_distVar_convergence: 0.49784227832341155
# t-statistic: -1.1599823955718915
# p-value: 0.12461471394682487
# The difference is not statistically significant
#
#
# ner reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.4926479007791503
# reconstructed_featural_eu_convergence: 0.50253570770369
# t-statistic: -3.010546104978467
# p-value: 0.0015566417866610491
# The difference IS statistically significant
#
#
# ner reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.4918581901585807
# reconstructed_featural_convergence: 0.5005181511125516
# t-statistic: -2.694002897180043
# p-value: 0.003992245237513158
# The difference IS statistically significant
#
#
# ner baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.4468458284277574
# baseline_en_convergence: 0.4594860792847517
# t-statistic: -3.5758319885964442
# p-value: 0.0002448773786074038
# The difference IS statistically significant
#
#
# ner baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.38478926901646776
# baseline_avg_adapter_convergence: 0.39474749278347
# t-statistic: -2.036500124432063
# p-value: 0.021857676802406543
# The difference IS statistically significant
#
#
# ner baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.43037952773723287
# baseline_closest_featural_convergence: 0.4318966422917051
# t-statistic: -0.3137601593745911
# p-value: 0.37710113505693177
# The difference is not statistically significant
#
#
# ner no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.4843430625018126
# no_train_gain_convergence: 0.4923904046488202
# t-statistic: -2.483265952622623
# p-value: 0.007140783243043663
# The difference IS statistically significant
#
#
# ner reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.5008066852292836
# reconstructed_featural_limit_convergence: 0.513701800545938
# t-statistic: -3.1132308017699986
# p-value: 0.0012564765873644068
# The difference IS statistically significant
#
#
# ner reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.5009998237800538
# reconstructed_syntactic_limit_convergence: 0.5124193723879796
# t-statistic: -3.1801895387669554
# p-value: 0.001023517895695706
# The difference IS statistically significant
#
#
# ner reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.5007967711682277
# reconstructed_morphological_limit_convergence: 0.509818494780799
# t-statistic: -1.9450692729221704
# p-value: 0.027517014471529856
# The difference IS statistically significant
#
#
# ner reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.49249443359325856
# reconstructed_featural_sr_convergence: 0.5024547316555162
# t-statistic: -3.0274158788802823
# p-value: 0.0014775960033924802
# The difference IS statistically significant
#
#
# ner reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.49317364960103505
# reconstructed_featural_threshold_convergence: 0.5071915253930095
# t-statistic: -4.76764283274283
# p-value: 2.1416526185878705e-06
# The difference IS statistically significant
#
#
# ner reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.4916480133971154
# reconstructed_syntactic_threshold_convergence: 0.5070287947192814
# t-statistic: -4.991567549178548
# p-value: 8.015040727449055e-07
# The difference IS statistically significant
#
#
# ner reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.49466726353114376
# reconstructed_morphological_threshold_convergence: 0.5077955609056627
# t-statistic: -4.351856269211653
# p-value: 1.2241798186991213e-05
# The difference IS statistically significant
#
#
# ner baseline_task_adapter UNDERPERFORMING baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.46085327083753636
# baseline_task_adapter_convergence: 0.4420261739036118
# t-statistic: 4.3827902589652155
# p-value: 1.1906208278229101e-05
# The difference IS statistically significant
#
#
# ner finetune UNDERPERFORMING finetune_convergence
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 2.3063187160543134e-06
# The difference IS statistically significant
#
#
#
# ~
#
# pos reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.4652982989750528
# reconstructed_featural_eu_convergence: 0.46650971101940225
# t-statistic: -0.41089921054848644
# p-value: 0.3411225051884176
# The difference is not statistically significant
#
#
# pos baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.45948742508831264
# baseline_en_convergence: 0.4661530707244856
# t-statistic: -3.0470785368313513
# p-value: 0.0015764198880595871
# The difference IS statistically significant
#
#
# pos baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.4699532518188051
# baseline_task_adapter_convergence: 0.4707906285460523
# t-statistic: -0.28359590597364254
# p-value: 0.3887357323668662
# The difference is not statistically significant
#
#
# pos baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.4446079106108303
# baseline_closest_featural_convergence: 0.4491073302514373
# t-statistic: -1.7925634899737246
# p-value: 0.03845997885047299
# The difference IS statistically significant
#
#
# pos no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.4708985951212325
# no_train_gain_convergence: 0.47178066077406033
# t-statistic: -0.28005603115424565
# p-value: 0.39008794967108285
# The difference is not statistically significant
#
#
# pos reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.465432079517123
# reconstructed_featural_sr_convergence: 0.4664995320737348
# t-statistic: -0.3627374706795504
# p-value: 0.358878803687096
# The difference is not statistically significant
#
#
# pos finetune outperforming finetune_convergence
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 2.7564864348877894e-07
# The difference IS statistically significant
#
#
# pos reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.4444155981131158
# reconstructed_syntactic_distVar_convergence: 0.4429027393047145
# t-statistic: 0.42315411861967944
# p-value: 0.6631645042938707
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.44451417563067147
# reconstructed_morphological_distVar_convergence: 0.4444740613110444
# t-statistic: 0.01111810702835868
# p-value: 0.5044172502765306
# The difference is not statistically significant
#
#
# pos reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.4459253486972836
# reconstructed_syntactic_limit_convergence: 0.44639138621322294
# t-statistic: -0.13932681410773648
# p-value: 0.44482174988471634
# The difference is not statistically significant
#
#
# pos reconstructed_featural_base UNDERPERFORMING reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.46542693459112533
# reconstructed_featural_base_convergence: 0.4654060010002513
# t-statistic: 0.007008118267766595
# p-value: 0.49721291153545666
# The difference is not statistically significant
#
#
# pos reconstructed_featural UNDERPERFORMING reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.47190832970243995
# reconstructed_featural_convergence: 0.4713442322968254
# t-statistic: 0.19296992478585712
# p-value: 0.42374205146701793
# The difference is not statistically significant
#
#
# pos baseline_avg_adapter UNDERPERFORMING baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.45786177866663486
# baseline_avg_adapter_convergence: 0.4571244506963704
# t-statistic: 0.24140455044799933
# p-value: 0.40493753654524656
# The difference is not statistically significant
#
#
# pos reconstructed_featural_threshold UNDERPERFORMING reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.45636370616611877
# reconstructed_featural_threshold_convergence: 0.45524588993454135
# t-statistic: 0.40973016432940534
# p-value: 0.34149420832353233
# The difference is not statistically significant
#
#
# pos reconstructed_syntactic_threshold UNDERPERFORMING reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.45632799406803165
# reconstructed_syntactic_threshold_convergence: 0.4554724782504057
# t-statistic: 0.3013608976798919
# p-value: 0.3819211464435813
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_threshold UNDERPERFORMING reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.4566799901014456
# reconstructed_morphological_threshold_convergence: 0.45627621549233105
# t-statistic: 0.15303695789661606
# p-value: 0.4393577843359307
# The difference is not statistically significant
#
#
# pos reconstructed_featural_limit UNDERPERFORMING reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.4454339471494947
# reconstructed_featural_limit_convergence: 0.4454303875907225
# t-statistic: 0.001133409048700792
# p-value: 0.49954965480291147
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_limit UNDERPERFORMING reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.44558357423359013
# reconstructed_morphological_limit_convergence: 0.44520581402313775
# t-statistic: 0.11010022002672692
# p-value: 0.45634275265212376
# The difference is not statistically significant
#
#
#
# ~
#
# copa reconstructed_featural_base UNDERPERFORMING reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.5481818181818183
# reconstructed_featural_base_convergence: 0.5165454545454545
# t-statistic: 2.434578621006876
# p-value: 0.0175868314054098
# The difference IS statistically significant
#
#
# copa reconstructed_featural_eu UNDERPERFORMING reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.5461818181818182
# reconstructed_featural_eu_convergence: 0.512909090909091
# t-statistic: 2.6131127432537657
# p-value: 0.01295103144502098
# The difference IS statistically significant
#
#
# copa reconstructed_featural UNDERPERFORMING reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.5498181818181818
# reconstructed_featural_convergence: 0.512
# t-statistic: 3.079673918063312
# p-value: 0.005823570233253961
# The difference IS statistically significant
#
#
# copa baseline_en UNDERPERFORMING baseline_en_convergence
# average scores
# baseline_en: 0.532909090909091
# baseline_en_convergence: 0.5083636363636364
# t-statistic: 1.5639000786182238
# p-value: 0.07445346223299394
# The difference is not statistically significant
#
#
# copa baseline_task_adapter UNDERPERFORMING baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.5496363636363637
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: 3.944467458277705
# p-value: 0.001377430624254861
# The difference IS statistically significant
#
#
# copa baseline_avg_adapter UNDERPERFORMING baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.5534545454545454
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: 2.81003815393849
# p-value: 0.00923684093057717
# The difference IS statistically significant
#
#
# copa baseline_closest_featural UNDERPERFORMING baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.5645454545454546
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: 4.97971627386231
# p-value: 0.00027682863904091167
# The difference IS statistically significant
#
#
# copa no_train_gain UNDERPERFORMING no_train_gain_convergence
# average scores
# no_train_gain: 0.5492727272727274
# no_train_gain_convergence: 0.503090909090909
# t-statistic: 3.785483214627806
# p-value: 0.0017848586956840514
# The difference IS statistically significant
#
#
# copa reconstructed_featural_limit UNDERPERFORMING reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.5590909090909091
# reconstructed_featural_limit_convergence: 0.5181818181818182
# t-statistic: 3.9614149532072602
# p-value: 0.0013401510554143536
# The difference IS statistically significant
#
#
# copa reconstructed_syntactic_limit UNDERPERFORMING reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.5565454545454545
# reconstructed_syntactic_limit_convergence: 0.5161818181818183
# t-statistic: 3.395670599714849
# p-value: 0.003410256985667638
# The difference IS statistically significant
#
#
# copa reconstructed_morphological_limit UNDERPERFORMING reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.5572727272727273
# reconstructed_morphological_limit_convergence: 0.5143636363636365
# t-statistic: 4.069933511906492
# p-value: 0.0011252015024619466
# The difference IS statistically significant
#
#
# copa reconstructed_featural_sr UNDERPERFORMING reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.5467272727272726
# reconstructed_featural_sr_convergence: 0.512
# t-statistic: 2.788692641908372
# p-value: 0.009581353648903682
# The difference IS statistically significant
#
#
# copa reconstructed_featural_threshold UNDERPERFORMING reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.5509090909090909
# reconstructed_featural_threshold_convergence: 0.5172727272727273
# t-statistic: 2.680090074466375
# p-value: 0.011544576101513349
# The difference IS statistically significant
#
#
# copa reconstructed_syntactic_threshold UNDERPERFORMING reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.5529090909090908
# reconstructed_syntactic_threshold_convergence: 0.5179999999999999
# t-statistic: 2.9022365065471667
# p-value: 0.007886530259207167
# The difference IS statistically significant
#
#
# copa reconstructed_morphological_threshold UNDERPERFORMING reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.5554545454545454
# reconstructed_morphological_threshold_convergence: 0.5169090909090909
# t-statistic: 4.036082274989208
# p-value: 0.0011880730961361513
# The difference IS statistically significant
#
#
# copa finetune UNDERPERFORMING finetune_convergence
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 7.246721077131189e-05
# The difference IS statistically significant
#
#
#
# ~
#
# qa reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.719115086844108
# reconstructed_featural_base_convergence: 0.7265242233928645
# t-statistic: -3.4020853481287614
# p-value: 0.0029536472167470042
# The difference IS statistically significant
#
#
# qa reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.7067951406688155
# reconstructed_syntactic_distVar_convergence: 0.7140968215507306
# t-statistic: -2.566693786386063
# p-value: 0.016649190964600345
# The difference IS statistically significant
#
#
# qa reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.7070427012158945
# reconstructed_morphological_distVar_convergence: 0.7144436124260781
# t-statistic: -2.591394944953764
# p-value: 0.016021772863348334
# The difference IS statistically significant
#
#
# qa reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.7185970560665157
# reconstructed_featural_eu_convergence: 0.7265765269051171
# t-statistic: -2.6142662037967868
# p-value: 0.012036808392176267
# The difference IS statistically significant
#
#
# qa reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.7183037200753665
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: -3.250606540547527
# p-value: 0.003863447470832056
# The difference IS statistically significant
#
#
# qa baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.7147087976622934
# baseline_en_convergence: 0.7210740878836793
# t-statistic: -2.142170815075489
# p-value: 0.02769795505378828
# The difference IS statistically significant
#
#
# qa baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.7140887779634627
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: -3.4178251944954052
# p-value: 0.002872631156635204
# The difference IS statistically significant
#
#
# qa baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.680023842973238
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: -1.5047833344636579
# p-value: 0.08027026617378513
# The difference is not statistically significant
#
#
# qa baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.7179205348539549
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: -1.0004243663429362
# p-value: 0.1693021799474036
# The difference is not statistically significant
#
#
# qa no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.7181706806985307
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: -2.8517779706600597
# p-value: 0.007873282070370365
# The difference IS statistically significant
#
#
# qa reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.70694224676724
# reconstructed_featural_limit_convergence: 0.7153906115765453
# t-statistic: -2.8847377292065266
# p-value: 0.01018146012861893
# The difference IS statistically significant
#
#
# qa reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.7060960065888455
# reconstructed_syntactic_limit_convergence: 0.7151131010189644
# t-statistic: -3.5122578285165034
# p-value: 0.003967654848989522
# The difference IS statistically significant
#
#
# qa reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.707698069118369
# reconstructed_morphological_limit_convergence: 0.7159570908631657
# t-statistic: -3.160694884654196
# p-value: 0.006690472678349446
# The difference IS statistically significant
#
#
# qa reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.7185148855553029
# reconstructed_featural_sr_convergence: 0.7271460731003012
# t-statistic: -3.233911187708036
# p-value: 0.003979835210441125
# The difference IS statistically significant
#
#
# qa reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.7184988715163637
# reconstructed_featural_threshold_convergence: 0.7266866467655285
# t-statistic: -2.892618724824673
# p-value: 0.007318557690668558
# The difference IS statistically significant
#
#
# qa reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.7186515172510287
# reconstructed_syntactic_threshold_convergence: 0.7271196088629276
# t-statistic: -3.0374627756099053
# p-value: 0.005648842183567611
# The difference IS statistically significant
#
#
# qa reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.7188103387334812
# reconstructed_morphological_threshold_convergence: 0.7285715530023293
# t-statistic: -3.4199854455279817
# p-value: 0.0028616907968619177
# The difference IS statistically significant
#
#
# qa finetune outperforming finetune_convergence
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.21332527829156234
# The difference is not statistically significant
#
#
#
# ~

# %%
# check if "convergence" outperforms relative non-convergence scores
tasks = ["ner", "pos", "copa", "qa"]
test_columns = [
    "reconstructed_featural",
    "baseline_en",
    "baseline_avg_adapter",
    "baseline_task_adapter",
    "baseline_closest_featural",
    "no_train_gain",
    "finetune",
]
significant_more = {}
significant_less = {}
for task in tasks:
    for test_column in test_columns:
        print(f"{task} outperforming {test_column}")
        t_stat, p_val = get_significance(task, test_column, test_column + "_convergence", alternative="less")
        if p_val < 0.05:
            print("The difference is statistically significant")
            if test_column not in significant_more:
                significant_more[test_column] = {}
            significant_more[test_column][task] = (
                averages[task][test_column],
                averages[task][test_column + "_convergence"],
            )
        else:
            print("The difference is not statistically significant")
        print("\n")
        print(f"{test_column} outperforming {task}")
        t_stat, p_val = get_significance(task, test_column, test_column + "_convergence", alternative="greater")
        if p_val < 0.05:
            print("The difference is statistically significant")
            if test_column not in significant_less:
                significant_less[test_column] = {}
            significant_less[test_column][task] = (
                averages[task][test_column],
                averages[task][test_column + "_convergence"],
            )
        else:
            print("The difference is not statistically significant")
        print("-----------------------------------")
# Out:
# ner outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.4918581901585807
# reconstructed_featural_convergence: 0.5005181511125516
# t-statistic: -2.694002897180043
# p-value: 0.003992245237513158
# The difference is statistically significant
#
#
# reconstructed_featural outperforming ner
# average scores
# reconstructed_featural: 0.4918581901585807
# reconstructed_featural_convergence: 0.5005181511125516
# t-statistic: -2.694002897180043
# p-value: 0.9960077547624868
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_en
# average scores
# baseline_en: 0.4468458284277574
# baseline_en_convergence: 0.4594860792847517
# t-statistic: -3.5758319885964442
# p-value: 0.0002448773786074038
# The difference is statistically significant
#
#
# baseline_en outperforming ner
# average scores
# baseline_en: 0.4468458284277574
# baseline_en_convergence: 0.4594860792847517
# t-statistic: -3.5758319885964442
# p-value: 0.9997551226213927
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.38478926901646776
# baseline_avg_adapter_convergence: 0.39474749278347
# t-statistic: -2.036500124432063
# p-value: 0.021857676802406543
# The difference is statistically significant
#
#
# baseline_avg_adapter outperforming ner
# average scores
# baseline_avg_adapter: 0.38478926901646776
# baseline_avg_adapter_convergence: 0.39474749278347
# t-statistic: -2.036500124432063
# p-value: 0.9781423231975934
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.46085327083753636
# baseline_task_adapter_convergence: 0.4420261739036118
# t-statistic: 4.3827902589652155
# p-value: 0.9999880937917217
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming ner
# average scores
# baseline_task_adapter: 0.46085327083753636
# baseline_task_adapter_convergence: 0.4420261739036118
# t-statistic: 4.3827902589652155
# p-value: 1.1906208278229101e-05
# The difference is statistically significant
# -----------------------------------
# ner outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.43037952773723287
# baseline_closest_featural_convergence: 0.4318966422917051
# t-statistic: -0.3137601593745911
# p-value: 0.37710113505693177
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming ner
# average scores
# baseline_closest_featural: 0.43037952773723287
# baseline_closest_featural_convergence: 0.4318966422917051
# t-statistic: -0.3137601593745911
# p-value: 0.6228988649430682
# The difference is not statistically significant
# -----------------------------------
# ner outperforming no_train_gain
# average scores
# no_train_gain: 0.4843430625018126
# no_train_gain_convergence: 0.4923904046488202
# t-statistic: -2.483265952622623
# p-value: 0.007140783243043663
# The difference is statistically significant
#
#
# no_train_gain outperforming ner
# average scores
# no_train_gain: 0.4843430625018126
# no_train_gain_convergence: 0.4923904046488202
# t-statistic: -2.483265952622623
# p-value: 0.9928592167569563
# The difference is not statistically significant
# -----------------------------------
# ner outperforming finetune
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 0.9999976936812839
# The difference is not statistically significant
#
#
# finetune outperforming ner
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 2.3063187160543134e-06
# The difference is statistically significant
# -----------------------------------
# pos outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.47190832970243995
# reconstructed_featural_convergence: 0.4713442322968254
# t-statistic: 0.19296992478585712
# p-value: 0.576257948532982
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming pos
# average scores
# reconstructed_featural: 0.47190832970243995
# reconstructed_featural_convergence: 0.4713442322968254
# t-statistic: 0.19296992478585712
# p-value: 0.42374205146701793
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_en
# average scores
# baseline_en: 0.45948742508831264
# baseline_en_convergence: 0.4661530707244856
# t-statistic: -3.0470785368313513
# p-value: 0.0015764198880595871
# The difference is statistically significant
#
#
# baseline_en outperforming pos
# average scores
# baseline_en: 0.45948742508831264
# baseline_en_convergence: 0.4661530707244856
# t-statistic: -3.0470785368313513
# p-value: 0.9984235801119404
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.45786177866663486
# baseline_avg_adapter_convergence: 0.4571244506963704
# t-statistic: 0.24140455044799933
# p-value: 0.5950624634547534
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming pos
# average scores
# baseline_avg_adapter: 0.45786177866663486
# baseline_avg_adapter_convergence: 0.4571244506963704
# t-statistic: 0.24140455044799933
# p-value: 0.40493753654524656
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.4699532518188051
# baseline_task_adapter_convergence: 0.4707906285460523
# t-statistic: -0.28359590597364254
# p-value: 0.3887357323668662
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming pos
# average scores
# baseline_task_adapter: 0.4699532518188051
# baseline_task_adapter_convergence: 0.4707906285460523
# t-statistic: -0.28359590597364254
# p-value: 0.6112642676331337
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.4446079106108303
# baseline_closest_featural_convergence: 0.4491073302514373
# t-statistic: -1.7925634899737246
# p-value: 0.03845997885047299
# The difference is statistically significant
#
#
# baseline_closest_featural outperforming pos
# average scores
# baseline_closest_featural: 0.4446079106108303
# baseline_closest_featural_convergence: 0.4491073302514373
# t-statistic: -1.7925634899737246
# p-value: 0.9615400211495271
# The difference is not statistically significant
# -----------------------------------
# pos outperforming no_train_gain
# average scores
# no_train_gain: 0.4708985951212325
# no_train_gain_convergence: 0.47178066077406033
# t-statistic: -0.28005603115424565
# p-value: 0.39008794967108285
# The difference is not statistically significant
#
#
# no_train_gain outperforming pos
# average scores
# no_train_gain: 0.4708985951212325
# no_train_gain_convergence: 0.47178066077406033
# t-statistic: -0.28005603115424565
# p-value: 0.6099120503289173
# The difference is not statistically significant
# -----------------------------------
# pos outperforming finetune
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 2.7564864348877894e-07
# The difference is statistically significant
#
#
# finetune outperforming pos
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 0.9999997243513565
# The difference is not statistically significant
# -----------------------------------
# copa outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.5498181818181818
# reconstructed_featural_convergence: 0.512
# t-statistic: 3.079673918063312
# p-value: 0.994176429766746
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming copa
# average scores
# reconstructed_featural: 0.5498181818181818
# reconstructed_featural_convergence: 0.512
# t-statistic: 3.079673918063312
# p-value: 0.005823570233253961
# The difference is statistically significant
# -----------------------------------
# copa outperforming baseline_en
# average scores
# baseline_en: 0.532909090909091
# baseline_en_convergence: 0.5083636363636364
# t-statistic: 1.5639000786182238
# p-value: 0.9255465377670061
# The difference is not statistically significant
#
#
# baseline_en outperforming copa
# average scores
# baseline_en: 0.532909090909091
# baseline_en_convergence: 0.5083636363636364
# t-statistic: 1.5639000786182238
# p-value: 0.07445346223299394
# The difference is not statistically significant
# -----------------------------------
# copa outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.5534545454545454
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: 2.81003815393849
# p-value: 0.9907631590694228
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming copa
# average scores
# baseline_avg_adapter: 0.5534545454545454
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: 2.81003815393849
# p-value: 0.00923684093057717
# The difference is statistically significant
# -----------------------------------
# copa outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.5496363636363637
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: 3.944467458277705
# p-value: 0.9986225693757451
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming copa
# average scores
# baseline_task_adapter: 0.5496363636363637
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: 3.944467458277705
# p-value: 0.001377430624254861
# The difference is statistically significant
# -----------------------------------
# copa outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.5645454545454546
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: 4.97971627386231
# p-value: 0.9997231713609591
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming copa
# average scores
# baseline_closest_featural: 0.5645454545454546
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: 4.97971627386231
# p-value: 0.00027682863904091167
# The difference is statistically significant
# -----------------------------------
# copa outperforming no_train_gain
# average scores
# no_train_gain: 0.5492727272727274
# no_train_gain_convergence: 0.503090909090909
# t-statistic: 3.785483214627806
# p-value: 0.998215141304316
# The difference is not statistically significant
#
#
# no_train_gain outperforming copa
# average scores
# no_train_gain: 0.5492727272727274
# no_train_gain_convergence: 0.503090909090909
# t-statistic: 3.785483214627806
# p-value: 0.0017848586956840514
# The difference is statistically significant
# -----------------------------------
# copa outperforming finetune
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 0.9999275327892287
# The difference is not statistically significant
#
#
# finetune outperforming copa
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 7.246721077131189e-05
# The difference is statistically significant
# -----------------------------------
# qa outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.7183037200753665
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: -3.250606540547527
# p-value: 0.003863447470832056
# The difference is statistically significant
#
#
# reconstructed_featural outperforming qa
# average scores
# reconstructed_featural: 0.7183037200753665
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: -3.250606540547527
# p-value: 0.9961365525291679
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_en
# average scores
# baseline_en: 0.7147087976622934
# baseline_en_convergence: 0.7210740878836793
# t-statistic: -2.142170815075489
# p-value: 0.02769795505378828
# The difference is statistically significant
#
#
# baseline_en outperforming qa
# average scores
# baseline_en: 0.7147087976622934
# baseline_en_convergence: 0.7210740878836793
# t-statistic: -2.142170815075489
# p-value: 0.9723020449462118
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.680023842973238
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: -1.5047833344636579
# p-value: 0.08027026617378513
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming qa
# average scores
# baseline_avg_adapter: 0.680023842973238
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: -1.5047833344636579
# p-value: 0.9197297338262149
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.7140887779634627
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: -3.4178251944954052
# p-value: 0.002872631156635204
# The difference is statistically significant
#
#
# baseline_task_adapter outperforming qa
# average scores
# baseline_task_adapter: 0.7140887779634627
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: -3.4178251944954052
# p-value: 0.9971273688433648
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.7179205348539549
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: -1.0004243663429362
# p-value: 0.1693021799474036
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming qa
# average scores
# baseline_closest_featural: 0.7179205348539549
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: -1.0004243663429362
# p-value: 0.8306978200525964
# The difference is not statistically significant
# -----------------------------------
# qa outperforming no_train_gain
# average scores
# no_train_gain: 0.7181706806985307
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: -2.8517779706600597
# p-value: 0.007873282070370365
# The difference is statistically significant
#
#
# no_train_gain outperforming qa
# average scores
# no_train_gain: 0.7181706806985307
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: -2.8517779706600597
# p-value: 0.9921267179296297
# The difference is not statistically significant
# -----------------------------------
# qa outperforming finetune
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.21332527829156234
# The difference is not statistically significant
#
#
# finetune outperforming qa
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.7866747217084377
# The difference is not statistically significant
# -----------------------------------

# %% [markdown]
# # Results
# NER
# 	• Approximation & Baselines (ADAPTER)
# 		○ Better in all cases, Statistically significant
# 			§ all over the line (1 exception out of 16)
# 	• Finetune
# 		○ Worse, statistically significant but small difference
# POS
# 	• Approximation
# 		○ No significantly worse for convergence, very small differences
# 	• Baselines
# 		○ Better
# 			§ Significant
# 				□ En adapter, MAD-X (closest featural) setting
# 			§ Not significant: no-train-gain
# 	• Finetune
# 		○ Better, statistically significant
# COPA
# 	• Significantly worse all over the line!
# 	• --> Reason: very small dataset,
# 		○ if need for eval (convergence stopping criterium), then performance further decreases
# QA
# 	• Significantly better all over the line!
# 	• Training cost
#
# ## Conclusion: fair comparison
# NER: take convergence scores to maintain comparibility in the setting (only small difference for finetune)
# POS: convergence for both adapter and finetune, our method underperforms but not significantly
# COPA: Take non-convergence all over the line
# QA: convergence all over the line

# %%
# We make a new directory under eval_scores with the results that we will use for further eval
if not os.path.exists("../eval_scores/selected"):
    os.makedirs("../eval_scores/selected")
task2selection = {"ner": "convergence", "pos": "convergence", "copa": "no_convergence", "qa": "convergence"}
scores_selected = {}
for task_name in task2selection:
    scores_selected[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name not in scores_selected[task_name]:
            scores_selected[task_name][lang_name] = {}
        if task2selection[task_name] == "convergence":
            for key in scores[task_name][lang_name]:
                if key.endswith("convergence"):
                    new_key = key.split("_convergence")[0]
                    if not task_name == "qa":
                        scores_selected[task_name][lang_name][new_key] = scores[task_name][lang_name][key]
                    else:
                        # we divide the scores of qa by 100
                        scores_selected[task_name][lang_name][new_key] = scores[task_name][lang_name][key] / 100
        else:  # no convergence: copa
            for key in scores[task_name][lang_name]:
                if not key.endswith("convergence"):
                    scores_selected[task_name][lang_name][key] = scores[task_name][lang_name][key]
    with open(f"../eval_scores/selected/{task_name}.json", "w") as f:
        json.dump(scores_selected[task_name], f, indent=4)
