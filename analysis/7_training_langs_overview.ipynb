# %%
import os
import json
import math
import pandas as pd

# From huggingface api, with our trained adapters (eu, sr)
existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
# scraped from cc-100 website
xlm_included_langs = [
    "af",
    "am",
    "ar",
    "as",
    "az",
    "be",
    "bg",
    "bn",
    "br",
    "bs",
    "ca",
    "cs",
    "cy",
    "da",
    "de",
    "el",
    "en",
    "eo",
    "es",
    "et",
    "eu",
    "fa",
    "ff",
    "fi",
    "fr",
    "fy",
    "ga",
    "gd",
    "gl",
    "gn",
    "gu",
    "ha",
    "he",
    "hi",
    "hr",
    "ht",
    "hu",
    "hy",
    "id",
    "ig",
    "is",
    "it",
    "ja",
    "jv",
    "ka",
    "kk",
    "km",
    "kn",
    "ko",
    "ku",
    "ky",
    "la",
    "lg",
    "li",
    "ln",
    "lo",
    "lt",
    "lv",
    "mg",
    "mk",
    "ml",
    "mn",
    "mr",
    "ms",
    "my",
    "ne",
    "nl",
    "no",
    "ns",
    "om",
    "or",
    "pa",
    "pl",
    "ps",
    "pt",
    "qu",
    "rm",
    "ro",
    "ru",
    "sa",
    "si",
    "sc",
    "sd",
    "sk",
    "sl",
    "so",
    "sq",
    "sr",
    "ss",
    "su",
    "sv",
    "sw",
    "ta",
    "te",
    "th",
    "tl",
    "tn",
    "tr",
    "ug",
    "uk",
    "ur",
    "uz",
    "vi",
    "wo",
    "xh",
    "yi",
    "yo",
    "zu",
    "zh",
]
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1", "sib": "eval_accuracy"}
tasks = list(f1.keys())
scores = {task: {} for task in tasks}
inf = math.inf
for file in os.listdir("../eval_scores/selected"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/selected", file), "r") as f:
                data = json.load(f)
                task_name = file.split(".")[0]

                scores[task_name] = data

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)
langs = set()
for task in tasks:
    for lang_name in scores[task]:
        if "reconstructed_featural" not in scores[task][lang_name].keys():
            continue
        langs.add(lang_name)

# %% [markdown]
# # Analysing task - language pairs
# We will make a dataframe with columns corresponding to tasks,
# and rows corresponding to the languages in our data

# %%
# we make a code - english language mapping
from qq import LanguageData, TagType

ld = LanguageData.from_db()

lang_en = {}
for lang in langs:
    try:
        eng = ld.get(lang, tag_type=TagType.BCP_47_CODE).english_name
        lang_en[lang] = eng
    except KeyError:
        print(f"KeyError for language: {lang}")

# %%
# Define your columns
rows = []
for lang in langs:
    row = {"Language": f"{lang_en[lang]} ({lang})"}
    for task in tasks:
        row[task] = lang in scores.get(task, [])
    print(f"{lang} has data for {[row[task] for task in tasks]} tasks.")
    rows.append(row)

df = pd.DataFrame(rows, columns=["Language"] + tasks)
df
# Out:
# yue has data for [False, False, True, False, True] tasks.
# ta has data for [True, True, True, False, True] tasks.
# taq has data for [False, False, False, False, True] tasks.
# lmo has data for [True, False, False, False, True] tasks.
# so has data for [True, False, False, False, True] tasks.
# npi has data for [False, False, False, False, True] tasks.
# ay has data for [True, False, False, False, False] tasks.
# nds has data for [True, False, False, False, False] tasks.
# ne has data for [True, False, False, False, False] tasks.
# sq has data for [True, False, True, False, False] tasks.
# sv has data for [True, False, True, False, True] tasks.
# cy has data for [True, False, True, False, True] tasks.
# nus has data for [False, False, False, False, True] tasks.
# lb has data for [True, False, False, False, True] tasks.
# ory has data for [False, False, False, False, True] tasks.
# ja has data for [True, False, True, False, True] tasks.
# si has data for [True, False, False, False, True] tasks.
# cv has data for [True, False, False, False, False] tasks.
# ln has data for [True, False, False, False, True] tasks.
# myv has data for [False, False, True, False, False] tasks.
# am has data for [True, False, True, False, True] tasks.
# tpi has data for [False, False, False, False, True] tasks.
# war has data for [True, False, False, False, True] tasks.
# als has data for [True, False, False, False, True] tasks.
# ug has data for [True, False, True, False, True] tasks.
# gun has data for [False, False, True, False, False] tasks.
# fuv has data for [False, False, False, False, True] tasks.
# mi has data for [True, False, False, False, True] tasks.
# os has data for [True, False, False, False, False] tasks.
# ba has data for [True, False, False, False, True] tasks.
# tl has data for [True, False, True, False, True] tasks.
# nso has data for [False, False, False, False, True] tasks.
# xh has data for [False, False, False, False, True] tasks.
# ace has data for [True, False, False, False, True] tasks.
# th has data for [True, True, True, True, True] tasks.
# wbp has data for [False, False, True, False, False] tasks.
# myu has data for [False, False, True, False, False] tasks.
# azb has data for [False, False, False, False, True] tasks.
# sco has data for [True, False, False, False, False] tasks.
# sw has data for [True, True, False, False, False] tasks.
# tg has data for [True, False, False, False, True] tasks.
# kmr has data for [False, False, True, False, True] tasks.
# azj has data for [False, False, False, False, True] tasks.
# lus has data for [False, False, False, False, True] tasks.
# as has data for [True, False, False, False, True] tasks.
# ps has data for [True, False, False, False, False] tasks.
# aeb has data for [False, False, False, False, True] tasks.
# ydd has data for [False, False, False, False, True] tasks.
# mr has data for [True, False, True, False, True] tasks.
# dz has data for [False, False, False, False, True] tasks.
# ce has data for [True, False, False, False, False] tasks.
# af has data for [True, False, True, False, True] tasks.
# nb has data for [False, False, False, False, True] tasks.
# bar has data for [True, False, False, False, False] tasks.
# es has data for [True, False, True, True, True] tasks.
# ru has data for [True, False, True, True, True] tasks.
# pl has data for [True, False, True, False, True] tasks.
# knc has data for [False, False, False, False, True] tasks.
# ka has data for [True, False, False, False, True] tasks.
# da has data for [True, False, True, False, True] tasks.
# luo has data for [False, False, False, False, True] tasks.
# ceb has data for [True, False, False, False, True] tasks.
# ny has data for [False, False, False, False, True] tasks.
# bem has data for [False, False, False, False, True] tasks.
# be has data for [True, False, True, False, True] tasks.
# crh has data for [True, False, False, False, True] tasks.
# sr has data for [True, False, True, False, True] tasks.
# tk has data for [True, False, False, False, True] tasks.
# rm has data for [True, False, False, False, False] tasks.
# fi has data for [True, False, True, False, True] tasks.
# gn has data for [True, False, False, False, True] tasks.
# ary has data for [False, False, False, False, True] tasks.
# mhr has data for [True, False, False, False, False] tasks.
# el has data for [True, False, True, True, True] tasks.
# et has data for [True, True, True, False, True] tasks.
# mdf has data for [False, False, True, False, False] tasks.
# qu has data for [True, True, False, False, False] tasks.
# mni has data for [False, False, False, False, True] tasks.
# umb has data for [False, False, False, False, True] tasks.
# cdo has data for [True, False, False, False, False] tasks.
# sl has data for [True, False, True, False, True] tasks.
# plt has data for [False, False, False, False, True] tasks.
# wo has data for [False, False, True, False, True] tasks.
# ilo has data for [True, False, False, False, True] tasks.
# khk has data for [False, False, False, False, True] tasks.
# fon has data for [False, False, False, False, True] tasks.
# ckb has data for [True, False, False, False, True] tasks.
# pag has data for [False, False, False, False, True] tasks.
# hi has data for [True, False, True, True, True] tasks.
# vi has data for [True, True, True, True, True] tasks.
# ro has data for [True, False, True, True, True] tasks.
# scn has data for [True, False, False, False, True] tasks.
# pes has data for [False, False, False, False, True] tasks.
# mk has data for [True, False, False, False, True] tasks.
# diq has data for [True, False, False, False, False] tasks.
# hr has data for [True, False, True, False, True] tasks.
# is has data for [True, False, True, False, True] tasks.
# su has data for [True, False, False, False, True] tasks.
# pbt has data for [False, False, False, False, True] tasks.
# frr has data for [True, False, False, False, False] tasks.
# shn has data for [False, False, False, False, True] tasks.
# pap has data for [False, False, False, False, True] tasks.
# olo has data for [False, False, True, False, False] tasks.
# bug has data for [False, False, False, False, True] tasks.
# st has data for [False, False, False, False, True] tasks.
# en has data for [True, False, True, True, True] tasks.
# ban has data for [False, False, False, False, True] tasks.
# sh has data for [True, False, False, False, False] tasks.
# br has data for [True, False, True, False, False] tasks.
# eo has data for [True, False, False, False, True] tasks.
# cop has data for [False, False, True, False, False] tasks.
# ks has data for [False, False, False, False, True] tasks.
# fy has data for [True, False, False, False, False] tasks.
# ml has data for [True, False, False, False, True] tasks.
# fj has data for [False, False, False, False, True] tasks.
# zu has data for [False, False, False, False, True] tasks.
# bxr has data for [False, False, True, False, False] tasks.
# bn has data for [True, False, False, False, True] tasks.
# sms has data for [False, False, True, False, False] tasks.
# tn has data for [False, False, False, False, True] tasks.
# hy has data for [True, False, True, False, True] tasks.
# hu has data for [True, False, True, False, True] tasks.
# fo has data for [True, False, True, False, True] tasks.
# tzm has data for [False, False, False, False, True] tasks.
# he has data for [True, False, True, False, True] tasks.
# fr has data for [True, False, True, False, True] tasks.
# pnb has data for [True, False, False, False, False] tasks.
# apc has data for [False, False, False, False, True] tasks.
# ki has data for [False, False, False, False, True] tasks.
# mzn has data for [True, False, False, False, False] tasks.
# uzn has data for [False, False, False, False, True] tasks.
# ti has data for [False, False, False, False, True] tasks.
# mos has data for [False, False, False, False, True] tasks.
# lo has data for [False, False, False, False, True] tasks.
# cs has data for [True, False, True, False, True] tasks.
# kn has data for [True, False, False, False, True] tasks.
# bm has data for [False, False, True, False, True] tasks.
# ars has data for [False, False, False, False, True] tasks.
# apu has data for [False, False, True, False, False] tasks.
# fur has data for [True, False, False, False, True] tasks.
# gan has data for [True, False, False, False, False] tasks.
# tw has data for [False, False, False, False, True] tasks.
# lv has data for [True, False, True, False, False] tasks.
# tr has data for [True, True, True, True, True] tasks.
# sm has data for [False, False, False, False, True] tasks.
# gd has data for [True, False, True, False, True] tasks.
# acm has data for [False, False, False, False, True] tasks.
# id has data for [True, True, True, False, True] tasks.
# km has data for [True, False, False, False, True] tasks.
# gv has data for [False, False, True, False, False] tasks.
# swh has data for [False, False, False, False, True] tasks.
# eu has data for [True, False, True, False, True] tasks.
# rn has data for [False, False, False, False, True] tasks.
# ss has data for [False, False, False, False, True] tasks.
# aqz has data for [False, False, True, False, False] tasks.
# sah has data for [True, False, False, False, False] tasks.
# ht has data for [False, True, False, False, True] tasks.
# jv has data for [True, False, False, False, True] tasks.
# mag has data for [False, False, False, False, True] tasks.
# uk has data for [True, False, True, False, True] tasks.
# ky has data for [True, False, False, False, True] tasks.
# arb has data for [False, False, False, False, True] tasks.
# rw has data for [True, False, False, False, True] tasks.
# ckt has data for [False, False, True, False, False] tasks.
# ur has data for [True, False, True, False, True] tasks.
# yo has data for [True, False, True, False, True] tasks.
# arz has data for [True, False, False, False, True] tasks.
# vep has data for [True, False, False, False, False] tasks.
# kam has data for [False, False, False, False, True] tasks.
# pcm has data for [False, False, True, False, False] tasks.
# hak has data for [True, False, False, False, False] tasks.
# vls has data for [True, False, False, False, False] tasks.
# sg has data for [False, False, False, False, True] tasks.
# ha has data for [False, False, False, False, True] tasks.
# mai has data for [False, False, False, False, True] tasks.
# ca has data for [True, False, True, False, True] tasks.
# nl has data for [True, False, True, False, True] tasks.
# tt has data for [True, False, False, False, True] tasks.
# awa has data for [False, False, False, False, True] tasks.
# ts has data for [False, False, False, False, True] tasks.
# kab has data for [False, False, False, False, True] tasks.
# xmf has data for [True, False, False, False, False] tasks.
# ku has data for [True, False, False, False, False] tasks.
# ig has data for [True, False, False, False, True] tasks.
# gl has data for [True, False, True, False, True] tasks.
# uz has data for [True, False, False, False, False] tasks.
# kac has data for [False, False, False, False, True] tasks.
# ko has data for [True, False, True, False, True] tasks.
# nap has data for [True, False, False, False, False] tasks.
# mt has data for [True, False, True, False, True] tasks.
# kpv has data for [False, False, True, False, False] tasks.
# sat has data for [False, False, False, False, True] tasks.
# gu has data for [True, False, False, False, True] tasks.
# bs has data for [True, False, False, False, True] tasks.
# mn has data for [True, False, False, False, False] tasks.
# my has data for [True, False, False, False, True] tasks.
# zea has data for [True, False, False, False, False] tasks.
# dyu has data for [False, False, False, False, True] tasks.
# bho has data for [False, False, True, False, True] tasks.
# gaz has data for [False, False, False, False, True] tasks.
# co has data for [True, False, False, False, False] tasks.
# oc has data for [True, False, False, False, True] tasks.
# te has data for [True, False, True, False, True] tasks.
# ga has data for [True, False, True, False, True] tasks.
# pt has data for [True, False, True, False, True] tasks.
# ayr has data for [False, False, False, False, True] tasks.
# lt has data for [True, False, True, False, True] tasks.
# min has data for [True, False, False, False, True] tasks.
# kk has data for [True, False, True, False, True] tasks.
# kea has data for [False, False, False, False, True] tasks.
# it has data for [True, True, True, False, True] tasks.
# de has data for [True, False, True, True, True] tasks.
# kbp has data for [False, False, False, False, True] tasks.
# lua has data for [False, False, False, False, True] tasks.
# sd has data for [True, False, False, False, True] tasks.
# an has data for [True, False, False, False, False] tasks.
# bo has data for [True, False, False, False, True] tasks.
# no has data for [True, False, True, False, False] tasks.
# ee has data for [False, False, False, False, True] tasks.
# pa has data for [True, False, False, False, True] tasks.
# wuu has data for [True, False, False, False, False] tasks.
# zh has data for [True, True, True, True, True] tasks.
# quy has data for [False, False, False, False, True] tasks.
# lg has data for [False, False, False, False, True] tasks.
# prs has data for [False, False, False, False, True] tasks.
# zsm has data for [False, False, False, False, True] tasks.
# bg has data for [True, False, True, False, True] tasks.
# ak has data for [False, False, False, False, True] tasks.
# tpn has data for [False, False, True, False, False] tasks.
# ar has data for [True, False, True, True, False] tasks.
# gsw has data for [False, False, True, False, False] tasks.
# dv has data for [True, False, False, False, False] tasks.
# sn has data for [False, False, False, False, True] tasks.
# ext has data for [True, False, False, False, False] tasks.
#                Language    ner   copa    pos     qa    sib
# 0     Yue Chinese (yue)  False  False   True  False   True
# 1            Tamil (ta)   True   True   True  False   True
# 2        Tamasheq (taq)  False  False  False  False   True
# 3         Lombard (lmo)   True  False  False  False   True
# 4           Somali (so)   True  False  False  False   True
# ..                  ...    ...    ...    ...    ...    ...
# 229         Arabic (ar)   True  False   True   True  False
# 230  Swiss German (gsw)  False  False   True  False  False
# 231        Dhivehi (dv)   True  False  False  False  False
# 232          Shona (sn)  False  False  False  False   True
# 233  Extremaduran (ext)   True  False  False  False  False
#
# [234 rows x 6 columns]

# %%
# from this dataframe, we pop all the rows that are present in only 1 task, and store them in a task_exclusive dict
task_exclusive = {task: [] for task in tasks}
for index, row in df.iterrows():
    task_count = sum(row[task] for task in tasks)
    if task_count == 1:
        for task in tasks:
            if row[task]:
                task_exclusive[task].append(row["Language"])
                break
df_filtered = df[~df.apply(lambda row: sum(row[task] for task in tasks) == 1, axis=1)]
df_filtered
# Out:
#               Language    ner   copa    pos     qa    sib
# 0    Yue Chinese (yue)  False  False   True  False   True
# 1           Tamil (ta)   True   True   True  False   True
# 3        Lombard (lmo)   True  False  False  False   True
# 4          Somali (so)   True  False  False  False   True
# 9        Albanian (sq)   True  False   True  False  False
# ..                 ...    ...    ...    ...    ...    ...
# 217     Norwegian (no)   True  False   True  False  False
# 219       Punjabi (pa)   True  False  False  False   True
# 221       Chinese (zh)   True   True   True   True   True
# 226     Bulgarian (bg)   True  False   True  False   True
# 229        Arabic (ar)   True  False   True   True  False
#
# [108 rows x 6 columns]

# %%
# we print this as latex with 1 and 0 for presence and absence of data
df_filtered = df_filtered.replace({True: 1, False: 0})
# we order the languages alphabetically
df_filtered = df_filtered.sort_values(by="Language").reset_index(drop=True)


# 1) define a little formatter that wraps 1→green, 0→red
def color_binary(x):
    if pd.isna(x):
        return ""
    return r"\textcolor{" + ("green" if x == 1 else "red") + r"}{" + str(int(x)) + r"}"


# 2) build a dict mapping each task‐column to that formatter
formatters = {task: color_binary for task in tasks}

# 3) emit LaTeX, letting our raw commands through
latex = df_filtered.to_latex(
    index=False,
    escape=False,  # don’t escape backslashes
    formatters=formatters,
)
print(latex)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# Language & ner & copa & pos & qa & sib \\
# \midrule
# Achinese (ace) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Afrikaans (af) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Albanian (sq) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Amharic (am) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Arabic (ar) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} \\
# Armenian (hy) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Assamese (as) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bambara (bm) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bashkir (ba) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Basque (eu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Belarusian (be) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bengali (bn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bhojpuri (bho) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bosnian (bs) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Breton (br) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Bulgarian (bg) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Catalan (ca) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Cebuano (ceb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Chinese (zh) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Crimean Tatar (crh) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Croatian (hr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Czech (cs) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Danish (da) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Dutch (nl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Egyptian Arabic (arz) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# English (en) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Esperanto (eo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Estonian (et) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Faroese (fo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Finnish (fi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# French (fr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Friulian (fur) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Galician (gl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Georgian (ka) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# German (de) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Greek (el) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Guarani (gn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Gujarati (gu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Haitian Creole (ht) & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Hebrew (he) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Hindi (hi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Hungarian (hu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Icelandic (is) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Igbo (ig) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Ilocano (ilo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Indonesian (id) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Irish (ga) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Italian (it) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Japanese (ja) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Javanese (jv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kannada (kn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kazakh (kk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Khmer (km) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kinyarwanda (rw) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Korean (ko) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kyrgyz (ky) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Latvian (lv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Lingala (ln) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Lithuanian (lt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Lombard (lmo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Luxembourgish (lb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Macedonian (mk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Malayalam (ml) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Maltese (mt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Maori (mi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Marathi (mr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Minangkabau (min) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Myanmar (Burmese) (my) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Northern Kurdish (kmr) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Norwegian (no) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Occitan (oc) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Polish (pl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Portuguese (pt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Punjabi (pa) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Quechua (qu) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Romanian (ro) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Russian (ru) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Scots Gaelic (gd) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Serbian (sr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sicilian (scn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sindhi (sd) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sinhala (si) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Slovenian (sl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Somali (so) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sorani Kurdish (ckb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Spanish (es) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Sundanese (su) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Swahili (sw) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Swedish (sv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tagalog (tl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tajik (tg) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tamil (ta) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tatar (tt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Telugu (te) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Thai (th) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Tibetan (bo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tosk Albanian (als) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Turkish (tr) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Turkmen (tk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Ukrainian (uk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Urdu (ur) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Uyghur (ug) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Vietnamese (vi) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Waray (war) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Welsh (cy) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Wolof (wo) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Yoruba (yo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Yue Chinese (yue) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# \bottomrule
# \end{tabular}

# %%
import pandas as pd

# (Assuming df_filtered is already prepared, with True/False → 1/0 and sorted by "Language".)

# 1) Find the midpoint and split into two DataFrames
n = len(df_filtered)
mid = (n + 1) // 2  # put the extra row (if odd) into the first half
df1 = df_filtered.iloc[:mid].reset_index(drop=True)
df2 = df_filtered.iloc[mid:].reset_index(drop=True)


# 2) Re-use the same color formatter and formatters dict you already have
def color_binary(x):
    if pd.isna(x):
        return ""
    return r"\textcolor{" + ("green" if x == 1 else "red") + r"}{" + str(int(x)) + r"}"


formatters = {task: color_binary for task in tasks}

# 3) Generate two separate LaTeX tables (no surrounding "table" environment yet)
latex1 = df1.to_latex(index=False, escape=False, formatters=formatters)
latex2 = df2.to_latex(index=False, escape=False, formatters=formatters)

# 4) Combine them into one LaTeX snippet using two minipages
combined = r"""\begin{table}[ht]
\centering
\begin{minipage}{0.48\textwidth}
# %s
\end{minipage}\hfill
\begin{minipage}{0.48\textwidth}
# %s
\end{minipage}
\end{table}
""" % (latex1, latex2)

print(combined)
# Out:
# \begin{table}[ht]
# \centering
# \begin{minipage}{0.48\textwidth}
# \begin{tabular}{lrrrrr}
# \toprule
# Language & ner & copa & pos & qa & sib \\
# \midrule
# Achinese (ace) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Afrikaans (af) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Albanian (sq) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Amharic (am) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Arabic (ar) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} \\
# Armenian (hy) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Assamese (as) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bambara (bm) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bashkir (ba) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Basque (eu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Belarusian (be) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bengali (bn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bhojpuri (bho) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Bosnian (bs) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Breton (br) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Bulgarian (bg) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Catalan (ca) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Cebuano (ceb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Chinese (zh) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Crimean Tatar (crh) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Croatian (hr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Czech (cs) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Danish (da) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Dutch (nl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Egyptian Arabic (arz) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# English (en) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Esperanto (eo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Estonian (et) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Faroese (fo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Finnish (fi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# French (fr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Friulian (fur) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Galician (gl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Georgian (ka) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# German (de) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Greek (el) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Guarani (gn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Gujarati (gu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Haitian Creole (ht) & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Hebrew (he) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Hindi (hi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Hungarian (hu) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Icelandic (is) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Igbo (ig) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Ilocano (ilo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Indonesian (id) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Irish (ga) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Italian (it) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Japanese (ja) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Javanese (jv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kannada (kn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kazakh (kk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Khmer (km) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kinyarwanda (rw) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# \bottomrule
# \end{tabular}
#
# \end{minipage}\hfill
# \begin{minipage}{0.48\textwidth}
# \begin{tabular}{lrrrrr}
# \toprule
# Language & ner & copa & pos & qa & sib \\
# \midrule
# Korean (ko) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Kyrgyz (ky) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Latvian (lv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Lingala (ln) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Lithuanian (lt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Lombard (lmo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Luxembourgish (lb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Macedonian (mk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Malayalam (ml) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Maltese (mt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Maori (mi) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Marathi (mr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Minangkabau (min) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Myanmar (Burmese) (my) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Northern Kurdish (kmr) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Norwegian (no) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Occitan (oc) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Polish (pl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Portuguese (pt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Punjabi (pa) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Quechua (qu) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Romanian (ro) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Russian (ru) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Scots Gaelic (gd) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Serbian (sr) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sicilian (scn) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sindhi (sd) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sinhala (si) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Slovenian (sl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Somali (so) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Sorani Kurdish (ckb) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Spanish (es) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Sundanese (su) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Swahili (sw) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Swedish (sv) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tagalog (tl) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tajik (tg) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tamil (ta) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tatar (tt) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Telugu (te) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Thai (th) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Tibetan (bo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Tosk Albanian (als) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Turkish (tr) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Turkmen (tk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Ukrainian (uk) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Urdu (ur) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Uyghur (ug) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Vietnamese (vi) & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} & \textcolor{green}{1} \\
# Waray (war) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Welsh (cy) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Wolof (wo) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Yoruba (yo) & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# Yue Chinese (yue) & \textcolor{red}{0} & \textcolor{red}{0} & \textcolor{green}{1} & \textcolor{red}{0} & \textcolor{green}{1} \\
# \bottomrule
# \end{tabular}
#
# \end{minipage}
# \end{table}

# %%
import re

# we first sort the languages alphabetically
task_exclusive = {task: sorted(task_exclusive[task]) for task in tasks}
# we make a table with the languages that are exclusive to one task
task_exclusive_df = pd.DataFrame(
    {"Task": ["NER", "POS", "COPA", "QA", "SIB"], "Languages": [", ".join(task_exclusive[task]) for task in tasks]}
)
task_exclusive_df = task_exclusive_df.sort_values(by="Task").reset_index(drop=True)


# we print this as latex,
# we want there to be a line break after every FOUR languages
def format_languages(languages, max_len=50):
    langs = [lang.strip() for lang in languages.split(",")]
    lines = []
    current = ""
    for lang in langs:
        if not current:
            # start a fresh line
            current = lang
        else:
            # would adding ", "+lang exceed max_len?
            sep = ", "
            if len(current) + len(sep) + len(lang) <= max_len:
                current = f"{current}{sep}{lang}"
            else:
                # commit the current line and start a new one
                lines.append(current)
                current = lang
    # append the last buffer
    if current:
        lines.append(current)

    # join with LaTeX linebreaks, wrap in makecell
    body = r" \\ ".join(lines)
    return r"\makecell[l]{" + body + r"}"


# Apply to your DataFrame just like before
task_exclusive_df["Languages"] = task_exclusive_df["Languages"].apply(lambda cell: format_languages(cell, max_len=80))
latex_exclusive = task_exclusive_df.to_latex(index=False, escape=False)
# 2) insert a \hline after every data row
lines = latex_exclusive.splitlines()
out = []
for line in lines:
    out.append(line)
    # detect a data‐row: has an '&' and ends with '\\'
    if re.match(r"\s*[^\\].*&.*\\\\$", line):
        out.append(r"\hline")
new_latex = "\n".join(out)

print(new_latex)
# Out:
# \begin{tabular}{ll}
# \toprule
# Task & Languages \\
# \hline
# \midrule
# COPA & \makecell[l]{Akuntsu (aqz), Apurinã (apu), Chukot (ckt), Coptic (cop), Erzya (myv) \\ Komi-Zyrian (kpv), Livvi (olo), Manx (gv), Mbyá Guaraní (gun), Moksha (mdf) \\ Mundurukú (myu), Nigerian Pidgin (pcm), Russia Buriat (bxr), Skolt Sami (sms) \\ Swiss German (gsw), Tupinambá (tpn), Warlpiri (wbp)} \\
# \hline
# NER & \makecell[l]{Aragonese (an), Aymara (ay), Bavarian (bar), Chechen (ce), Chuvash (cv) \\ Corsican (co), Dhivehi (dv), Dimli (diq), Eastern Mari (mhr), Extremaduran (ext) \\ Frisian (fy), Gan Chinese (gan), Hakka Chinese (hak), Kurmanji Kurdish (ku) \\ Low German (nds), Mazanderani (mzn), Min Dong Chinese (cdo), Mingrelian (xmf) \\ Mongolian (mn), Neapolitan (nap), Nepali (ne), Northern Frisian (frr) \\ Ossetian (os), Pashto (ps), Romansh (rm), Scots (sco), Serbo-Croatian (sh) \\ Uzbek (uz), Veps (vep), Vlaams (vls), Western Panjabi (pnb), Wu Chinese (wuu) \\ Yakut (sah), Zeeuws (zea)} \\
# \hline
# POS & \makecell[l]{} \\
# \hline
# QA & \makecell[l]{} \\
# \hline
# SIB & \makecell[l]{Awadhi (awa), Ayacucho Quechua (quy), Balinese (ban), Bemba (bem) \\ Buginese (bug), Central Atlas Tamazight (tzm), Central Aymara (ayr) \\ Central Kanuri (knc), Chichewa (ny), Dari (prs), Dyula (dyu), Dzongkha (dz) \\ Eastern Yiddish (ydd), Ewe (ee), Fijian (fj), Fon (fon), Halh Mongolian (khk) \\ Hausa (ha), Iranian Persian (pes), Kabiyè (kbp), Kabuverdianu (kea) \\ Kabyle (kab), Kachin (kac), Kamba (kam), Kashmiri (ks), Kikuyu (ki), Lao (lo) \\ Luba-Lulua (lua), Luganda (lg), Luo (luo), Magahi (mag), Maithili (mai) \\ Meiteilon (Manipuri) (mni), Mesopotamian Arabic (acm), Mizo (lus) \\ Moroccan Arabic (ary), Mossi (mos), Najdi Arabic (ars), Nepali (npi) \\ Nigerian Fulfulde (fuv), North Azerbaijani (azj), North Levantine Arabic (apc) \\ Northern Uzbek (uzn), Norwegian Bokmål (nb), Nuer (nus), Odia (ory) \\ Pangasinan (pag), Papiamento (pap), Plateau Malagasy (plt), Rundi (rn) \\ Samoan (sm), Sango (sg), Santali (sat), Sepedi (nso), Sesotho (st), Shan (shn) \\ Shona (sn), South Azerbaijani (azb), Southern Pashto (pbt) \\ Standard Arabic (arb), Standard Malay (zsm), Swahili (swh), Swati (ss) \\ Tamasheq (taq), Tigrinya (ti), Tok Pisin (tpi), Tsonga (ts), Tswana (tn) \\ Tunisian Arabic (aeb), Twi (ak), Twi (tw), Umbundu (umb) \\ West Central Oromo (gaz), Xhosa (xh), Zulu (zu)} \\
# \hline
# \bottomrule
# \end{tabular}
