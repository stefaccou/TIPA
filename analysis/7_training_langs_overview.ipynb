# %%
import os
import json
import math
import pandas as pd

# From huggingface api, with our trained adapters (eu, sr)
existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
# scraped from cc-100 website
xlm_included_langs = [
    "af",
    "am",
    "ar",
    "as",
    "az",
    "be",
    "bg",
    "bn",
    "br",
    "bs",
    "ca",
    "cs",
    "cy",
    "da",
    "de",
    "el",
    "en",
    "eo",
    "es",
    "et",
    "eu",
    "fa",
    "ff",
    "fi",
    "fr",
    "fy",
    "ga",
    "gd",
    "gl",
    "gn",
    "gu",
    "ha",
    "he",
    "hi",
    "hr",
    "ht",
    "hu",
    "hy",
    "id",
    "ig",
    "is",
    "it",
    "ja",
    "jv",
    "ka",
    "kk",
    "km",
    "kn",
    "ko",
    "ku",
    "ky",
    "la",
    "lg",
    "li",
    "ln",
    "lo",
    "lt",
    "lv",
    "mg",
    "mk",
    "ml",
    "mn",
    "mr",
    "ms",
    "my",
    "ne",
    "nl",
    "no",
    "ns",
    "om",
    "or",
    "pa",
    "pl",
    "ps",
    "pt",
    "qu",
    "rm",
    "ro",
    "ru",
    "sa",
    "si",
    "sc",
    "sd",
    "sk",
    "sl",
    "so",
    "sq",
    "sr",
    "ss",
    "su",
    "sv",
    "sw",
    "ta",
    "te",
    "th",
    "tl",
    "tn",
    "tr",
    "ug",
    "uk",
    "ur",
    "uz",
    "vi",
    "wo",
    "xh",
    "yi",
    "yo",
    "zu",
    "zh",
]
scores = {"ner": {}, "pos": {}, "copa": {}, "qa": {}}
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1"}
inf = math.inf
for file in os.listdir("../eval_scores/selected"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/selected", file), "r") as f:
                data = json.load(f)
                task_name = file.split(".")[0]

                scores[task_name] = data

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)
langs = set()
tasks = ["ner", "pos", "copa", "qa"]
for task in tasks:
    for lang_name in scores[task]:
        if "reconstructed_featural" not in scores[task][lang_name].keys():
            continue
        langs.add(lang_name)

# %% [markdown]
# # Analysing task - language pairs
# We will make a dataframe with columns corresponding to tasks,
# and rows corresponding to the languages in our data

# %%
# we make a code - english language mapping
from qq import LanguageData, TagType

ld = LanguageData.from_db()

lang_en = {}
for lang in langs:
    try:
        eng = ld.get(lang, tag_type=TagType.BCP_47_CODE).english_name
        lang_en[lang] = eng
    except KeyError:
        print(f"KeyError for language: {lang}")

# %%
# Define your columns
rows = []
for lang in langs:
    row = {"Language": f"{lang_en[lang]} ({lang})"}
    for task in tasks:
        row[task] = lang in scores.get(task, [])
    print(f"{lang} has data for {[row[task] for task in tasks]} tasks.")
    rows.append(row)

df = pd.DataFrame(rows, columns=["Language"] + tasks)
df
# Out:
# myv has data for [False, True, False, False] tasks.
# oc has data for [True, False, False, False] tasks.
# fr has data for [True, True, False, False] tasks.
# ps has data for [True, False, False, False] tasks.
# ckb has data for [True, False, False, False] tasks.
# os has data for [True, False, False, False] tasks.
# th has data for [True, True, True, True] tasks.
# gun has data for [False, True, False, False] tasks.
# cop has data for [False, True, False, False] tasks.
# cs has data for [True, True, False, False] tasks.
# cy has data for [True, True, False, False] tasks.
# hak has data for [True, False, False, False] tasks.
# uz has data for [True, False, False, False] tasks.
# war has data for [True, False, False, False] tasks.
# vls has data for [True, False, False, False] tasks.
# nds has data for [True, False, False, False] tasks.
# is has data for [True, True, False, False] tasks.
# tt has data for [True, False, False, False] tasks.
# ur has data for [True, True, False, False] tasks.
# olo has data for [False, True, False, False] tasks.
# sl has data for [True, True, False, False] tasks.
# tl has data for [True, True, False, False] tasks.
# bn has data for [True, False, False, False] tasks.
# vep has data for [True, False, False, False] tasks.
# yue has data for [False, True, False, False] tasks.
# crh has data for [True, False, False, False] tasks.
# sah has data for [True, False, False, False] tasks.
# ga has data for [True, True, False, False] tasks.
# af has data for [True, True, False, False] tasks.
# km has data for [True, False, False, False] tasks.
# mi has data for [True, False, False, False] tasks.
# mt has data for [True, True, False, False] tasks.
# ru has data for [True, True, False, True] tasks.
# ar has data for [True, True, False, True] tasks.
# rw has data for [True, False, False, False] tasks.
# lv has data for [True, True, False, False] tasks.
# aqz has data for [False, True, False, False] tasks.
# zh has data for [True, True, True, True] tasks.
# wbp has data for [False, True, False, False] tasks.
# co has data for [True, False, False, False] tasks.
# lt has data for [True, True, False, False] tasks.
# tg has data for [True, False, False, False] tasks.
# apu has data for [False, True, False, False] tasks.
# mzn has data for [True, False, False, False] tasks.
# lmo has data for [True, False, False, False] tasks.
# my has data for [True, False, False, False] tasks.
# ta has data for [True, True, True, False] tasks.
# dv has data for [True, False, False, False] tasks.
# sw has data for [True, False, True, False] tasks.
# ug has data for [True, True, False, False] tasks.
# eu has data for [True, True, False, False] tasks.
# he has data for [True, True, False, False] tasks.
# ext has data for [True, False, False, False] tasks.
# gsw has data for [False, True, False, False] tasks.
# en has data for [True, True, False, True] tasks.
# eo has data for [True, False, False, False] tasks.
# nl has data for [True, True, False, False] tasks.
# ku has data for [True, False, False, False] tasks.
# scn has data for [True, False, False, False] tasks.
# nap has data for [True, False, False, False] tasks.
# bxr has data for [False, True, False, False] tasks.
# mdf has data for [False, True, False, False] tasks.
# de has data for [True, True, False, True] tasks.
# ba has data for [True, False, False, False] tasks.
# ig has data for [True, False, False, False] tasks.
# pl has data for [True, True, False, False] tasks.
# am has data for [True, True, False, False] tasks.
# da has data for [True, True, False, False] tasks.
# sd has data for [True, False, False, False] tasks.
# wo has data for [False, True, False, False] tasks.
# ace has data for [True, False, False, False] tasks.
# pnb has data for [True, False, False, False] tasks.
# ce has data for [True, False, False, False] tasks.
# hy has data for [True, True, False, False] tasks.
# tr has data for [True, True, True, True] tasks.
# be has data for [True, True, False, False] tasks.
# kmr has data for [False, True, False, False] tasks.
# fy has data for [True, False, False, False] tasks.
# ceb has data for [True, False, False, False] tasks.
# gu has data for [True, False, False, False] tasks.
# cv has data for [True, False, False, False] tasks.
# ilo has data for [True, False, False, False] tasks.
# ln has data for [True, False, False, False] tasks.
# as has data for [True, False, False, False] tasks.
# mk has data for [True, False, False, False] tasks.
# mr has data for [True, True, False, False] tasks.
# it has data for [True, True, True, False] tasks.
# rm has data for [True, False, False, False] tasks.
# cdo has data for [True, False, False, False] tasks.
# ca has data for [True, True, False, False] tasks.
# yo has data for [True, True, False, False] tasks.
# ht has data for [False, False, True, False] tasks.
# uk has data for [True, True, False, False] tasks.
# lb has data for [True, False, False, False] tasks.
# ro has data for [True, True, False, True] tasks.
# gd has data for [True, True, False, False] tasks.
# ko has data for [True, True, False, False] tasks.
# kpv has data for [False, True, False, False] tasks.
# bg has data for [True, True, False, False] tasks.
# mhr has data for [True, False, False, False] tasks.
# sq has data for [True, True, False, False] tasks.
# et has data for [True, True, True, False] tasks.
# su has data for [True, False, False, False] tasks.
# br has data for [True, True, False, False] tasks.
# si has data for [True, False, False, False] tasks.
# gn has data for [True, False, False, False] tasks.
# pt has data for [True, True, False, False] tasks.
# sh has data for [True, False, False, False] tasks.
# fo has data for [True, True, False, False] tasks.
# frr has data for [True, False, False, False] tasks.
# hr has data for [True, True, False, False] tasks.
# el has data for [True, True, False, True] tasks.
# wuu has data for [True, False, False, False] tasks.
# bs has data for [True, False, False, False] tasks.
# gv has data for [False, True, False, False] tasks.
# sco has data for [True, False, False, False] tasks.
# min has data for [True, False, False, False] tasks.
# zea has data for [True, False, False, False] tasks.
# als has data for [True, False, False, False] tasks.
# ky has data for [True, False, False, False] tasks.
# id has data for [True, True, True, False] tasks.
# an has data for [True, False, False, False] tasks.
# ne has data for [True, False, False, False] tasks.
# tpn has data for [False, True, False, False] tasks.
# bho has data for [False, True, False, False] tasks.
# myu has data for [False, True, False, False] tasks.
# pcm has data for [False, True, False, False] tasks.
# gan has data for [True, False, False, False] tasks.
# vi has data for [True, True, True, True] tasks.
# kk has data for [True, True, False, False] tasks.
# hi has data for [True, True, False, True] tasks.
# bm has data for [False, True, False, False] tasks.
# sms has data for [False, True, False, False] tasks.
# ka has data for [True, False, False, False] tasks.
# arz has data for [True, False, False, False] tasks.
# jv has data for [True, False, False, False] tasks.
# ckt has data for [False, True, False, False] tasks.
# no has data for [True, True, False, False] tasks.
# diq has data for [True, False, False, False] tasks.
# kn has data for [True, False, False, False] tasks.
# pa has data for [True, False, False, False] tasks.
# fi has data for [True, True, False, False] tasks.
# so has data for [True, False, False, False] tasks.
# fur has data for [True, False, False, False] tasks.
# qu has data for [True, False, True, False] tasks.
# sv has data for [True, True, False, False] tasks.
# bo has data for [True, False, False, False] tasks.
# ay has data for [True, False, False, False] tasks.
# gl has data for [True, True, False, False] tasks.
# sr has data for [True, True, False, False] tasks.
# ja has data for [True, True, False, False] tasks.
# hu has data for [True, True, False, False] tasks.
# xmf has data for [True, False, False, False] tasks.
# mn has data for [True, False, False, False] tasks.
# bar has data for [True, False, False, False] tasks.
# te has data for [True, True, False, False] tasks.
# es has data for [True, True, False, True] tasks.
#                  Language    ner    pos   copa     qa
# 0             Erzya (myv)  False   True  False  False
# 1            Occitan (oc)   True  False  False  False
# 2             French (fr)   True   True  False  False
# 3             Pashto (ps)   True  False  False  False
# 4    Sorani Kurdish (ckb)   True  False  False  False
# ..                    ...    ...    ...    ...    ...
# 152      Mingrelian (xmf)   True  False  False  False
# 153        Mongolian (mn)   True  False  False  False
# 154        Bavarian (bar)   True  False  False  False
# 155           Telugu (te)   True   True  False  False
# 156          Spanish (es)   True   True  False   True
#
# [157 rows x 5 columns]

# %%
# from this dataframe, we pop all the rows that are present in only 1 task, and store them in a task_exclusive dict
task_exclusive = {task: [] for task in tasks}
for index, row in df.iterrows():
    task_count = sum(row[task] for task in tasks)
    if task_count == 1:
        for task in tasks:
            if row[task]:
                task_exclusive[task].append(row["Language"])
                break
df_filtered = df[~df.apply(lambda row: sum(row[task] for task in tasks) == 1, axis=1)]
df_filtered
# Out:
#               Language   ner    pos   copa     qa
# 2          French (fr)  True   True  False  False
# 6            Thai (th)  True   True   True   True
# 9           Czech (cs)  True   True  False  False
# 10          Welsh (cy)  True   True  False  False
# 16      Icelandic (is)  True   True  False  False
# 18           Urdu (ur)  True   True  False  False
# 20      Slovenian (sl)  True   True  False  False
# 21        Tagalog (tl)  True   True  False  False
# 27          Irish (ga)  True   True  False  False
# 28      Afrikaans (af)  True   True  False  False
# 31        Maltese (mt)  True   True  False  False
# 32        Russian (ru)  True   True  False   True
# 33         Arabic (ar)  True   True  False   True
# 35        Latvian (lv)  True   True  False  False
# 37        Chinese (zh)  True   True   True   True
# 40     Lithuanian (lt)  True   True  False  False
# 46          Tamil (ta)  True   True   True  False
# 48        Swahili (sw)  True  False   True  False
# 49         Uyghur (ug)  True   True  False  False
# 50         Basque (eu)  True   True  False  False
# 51         Hebrew (he)  True   True  False  False
# 54        English (en)  True   True  False   True
# 56          Dutch (nl)  True   True  False  False
# 62         German (de)  True   True  False   True
# 65         Polish (pl)  True   True  False  False
# 66        Amharic (am)  True   True  False  False
# 67         Danish (da)  True   True  False  False
# 73       Armenian (hy)  True   True  False  False
# 74        Turkish (tr)  True   True   True   True
# 75     Belarusian (be)  True   True  False  False
# 85        Marathi (mr)  True   True  False  False
# 86        Italian (it)  True   True   True  False
# 89        Catalan (ca)  True   True  False  False
# 90         Yoruba (yo)  True   True  False  False
# 92      Ukrainian (uk)  True   True  False  False
# 94       Romanian (ro)  True   True  False   True
# 95   Scots Gaelic (gd)  True   True  False  False
# 96         Korean (ko)  True   True  False  False
# 98      Bulgarian (bg)  True   True  False  False
# 100      Albanian (sq)  True   True  False  False
# 101      Estonian (et)  True   True   True  False
# 103        Breton (br)  True   True  False  False
# 106    Portuguese (pt)  True   True  False  False
# 108       Faroese (fo)  True   True  False  False
# 110      Croatian (hr)  True   True  False  False
# 111         Greek (el)  True   True  False   True
# 120    Indonesian (id)  True   True   True  False
# 128    Vietnamese (vi)  True   True   True   True
# 129        Kazakh (kk)  True   True  False  False
# 130         Hindi (hi)  True   True  False   True
# 137     Norwegian (no)  True   True  False  False
# 141       Finnish (fi)  True   True  False  False
# 144       Quechua (qu)  True  False   True  False
# 145       Swedish (sv)  True   True  False  False
# 148      Galician (gl)  True   True  False  False
# 149       Serbian (sr)  True   True  False  False
# 150      Japanese (ja)  True   True  False  False
# 151     Hungarian (hu)  True   True  False  False
# 155        Telugu (te)  True   True  False  False
# 156       Spanish (es)  True   True  False   True

# %%
# we print this as latex with 1 and 0 for presence and absence of data
df_filtered = df_filtered.replace({True: 1, False: 0})
# we order the languages alphabetically
df_filtered = df_filtered.sort_values(by="Language").reset_index(drop=True)


# 1) define a little formatter that wraps 1→green, 0→red
def color_binary(x):
    if pd.isna(x):
        return ""
    return r"\textcolor{" + ("OliveGreen" if x == 1 else "red") + r"}{" + str(int(x)) + r"}"


# 2) build a dict mapping each task‐column to that formatter
formatters = {task: color_binary for task in tasks}

# 3) emit LaTeX, letting our raw commands through
latex = df_filtered.to_latex(
    index=False,
    escape=False,  # don’t escape backslashes
    formatters=formatters,
)
print(latex)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# Language & ner & pos & copa & qa \\
# \midrule
# Afrikaans (af) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Albanian (sq) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Amharic (am) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Arabic (ar) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Armenian (hy) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Basque (eu) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Belarusian (be) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Breton (br) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Bulgarian (bg) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Catalan (ca) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Chinese (zh) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} \\
# Croatian (hr) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Czech (cs) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Danish (da) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Dutch (nl) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# English (en) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Estonian (et) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Faroese (fo) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Finnish (fi) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# French (fr) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Galician (gl) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# German (de) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Greek (el) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Hebrew (he) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Hindi (hi) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Hungarian (hu) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Icelandic (is) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Indonesian (id) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Irish (ga) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Italian (it) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Japanese (ja) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Kazakh (kk) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Korean (ko) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Latvian (lv) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Lithuanian (lt) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Maltese (mt) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Marathi (mr) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Norwegian (no) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Polish (pl) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Portuguese (pt) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Quechua (qu) & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Romanian (ro) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Russian (ru) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Scots Gaelic (gd) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Serbian (sr) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Slovenian (sl) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Spanish (es) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} \\
# Swahili (sw) & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Swedish (sv) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Tagalog (tl) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Tamil (ta) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} \\
# Telugu (te) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Thai (th) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} \\
# Turkish (tr) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} \\
# Ukrainian (uk) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Urdu (ur) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Uyghur (ug) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Vietnamese (vi) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} \\
# Welsh (cy) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# Yoruba (yo) & \textcolor{OliveGreen}{1} & \textcolor{OliveGreen}{1} & \textcolor{red}{0} & \textcolor{red}{0} \\
# \bottomrule
# \end{tabular}

# %%
len(task_exclusive["ner"]), len(task_exclusive["pos"]), len(task_exclusive["copa"]), len(task_exclusive["qa"])
# Out:
# (74, 22, 1, 0)

# %%
import re

# we first sort the languages alphabetically
task_exclusive = {task: sorted(task_exclusive[task]) for task in tasks}
# we make a table with the languages that are exclusive to one task
task_exclusive_df = pd.DataFrame(
    {"Task": ["NER", "POS", "COPA", "QA"], "Languages": [", ".join(task_exclusive[task]) for task in tasks]}
)
task_exclusive_df = task_exclusive_df.sort_values(by="Task").reset_index(drop=True)


# we print this as latex,
# we want there to be a line break after every FOUR languages
def format_languages(languages, max_len=50):
    langs = [lang.strip() for lang in languages.split(",")]
    lines = []
    current = ""
    for lang in langs:
        if not current:
            # start a fresh line
            current = lang
        else:
            # would adding ", "+lang exceed max_len?
            sep = ", "
            if len(current) + len(sep) + len(lang) <= max_len:
                current = f"{current}{sep}{lang}"
            else:
                # commit the current line and start a new one
                lines.append(current)
                current = lang
    # append the last buffer
    if current:
        lines.append(current)

    # join with LaTeX linebreaks, wrap in makecell
    body = r" \\ ".join(lines)
    return r"\makecell[l]{" + body + r"}"


# Apply to your DataFrame just like before
task_exclusive_df["Languages"] = task_exclusive_df["Languages"].apply(lambda cell: format_languages(cell, max_len=35))
latex_exclusive = task_exclusive_df.to_latex(index=False, escape=False)
# 2) insert a \hline after every data row
lines = latex_exclusive.splitlines()
out = []
for line in lines:
    out.append(line)
    # detect a data‐row: has an '&' and ends with '\\'
    if re.match(r"\s*[^\\].*&.*\\\\$", line):
        out.append(r"\hline")
new_latex = "\n".join(out)

print(new_latex)
# Out:
# \begin{tabular}{ll}
# \toprule
# Task & Languages \\
# \hline
# \midrule
# COPA & \makecell[l]{Haitian Creole (ht)} \\
# \hline
# NER & \makecell[l]{Achinese (ace), Aragonese (an) \\ Assamese (as), Aymara (ay) \\ Bashkir (ba), Bavarian (bar) \\ Bengali (bn), Bosnian (bs) \\ Cebuano (ceb), Chechen (ce) \\ Chuvash (cv), Corsican (co) \\ Crimean Tatar (crh), Dhivehi (dv) \\ Dimli (diq), Eastern Mari (mhr) \\ Egyptian Arabic (arz) \\ Esperanto (eo), Extremaduran (ext) \\ Frisian (fy), Friulian (fur) \\ Gan Chinese (gan), Georgian (ka) \\ Guarani (gn), Gujarati (gu) \\ Hakka Chinese (hak), Igbo (ig) \\ Ilocano (ilo), Javanese (jv) \\ Kannada (kn), Khmer (km) \\ Kinyarwanda (rw) \\ Kurmanji Kurdish (ku), Kyrgyz (ky) \\ Lingala (ln), Lombard (lmo) \\ Low German (nds) \\ Luxembourgish (lb), Macedonian (mk) \\ Maori (mi), Mazanderani (mzn) \\ Min Dong Chinese (cdo) \\ Minangkabau (min), Mingrelian (xmf) \\ Mongolian (mn) \\ Myanmar (Burmese) (my) \\ Neapolitan (nap), Nepali (ne) \\ Northern Frisian (frr) \\ Occitan (oc), Ossetian (os) \\ Pashto (ps), Punjabi (pa) \\ Romansh (rm), Scots (sco) \\ Serbo-Croatian (sh), Sicilian (scn) \\ Sindhi (sd), Sinhala (si) \\ Somali (so), Sorani Kurdish (ckb) \\ Sundanese (su), Tajik (tg) \\ Tatar (tt), Tibetan (bo) \\ Tosk Albanian (als), Uzbek (uz) \\ Veps (vep), Vlaams (vls) \\ Waray (war), Western Panjabi (pnb) \\ Wu Chinese (wuu), Yakut (sah) \\ Zeeuws (zea)} \\
# \hline
# POS & \makecell[l]{Akuntsu (aqz), Apurinã (apu) \\ Bambara (bm), Bhojpuri (bho) \\ Chukot (ckt), Coptic (cop) \\ Erzya (myv), Komi-Zyrian (kpv) \\ Livvi (olo), Manx (gv) \\ Mbyá Guaraní (gun), Moksha (mdf) \\ Mundurukú (myu) \\ Nigerian Pidgin (pcm) \\ Northern Kurdish (kmr) \\ Russia Buriat (bxr) \\ Skolt Sami (sms) \\ Swiss German (gsw), Tupinambá (tpn) \\ Warlpiri (wbp), Wolof (wo) \\ Yue Chinese (yue)} \\
# \hline
# QA & \makecell[l]{} \\
# \hline
# \bottomrule
# \end{tabular}
