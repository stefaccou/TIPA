# %%
import os
import json
import math
import numpy as np
import scipy.stats as stats

# from huggingface_hub import HfApi
# api = HfApi()
# def get_available_adapters():
#     # get all adapters from huggingface
#     all_models = api.list_models(author="AdapterHub",
#     library="adapter-transformers",
#     search="xlm-roberta-base-"
#     )
#
#     to_load = {
#         m.modelId: m.modelId.split("xlm-roberta-base-")[-1].rsplit("-wiki_pfeiffer", 1)[0]
#         for m in all_models
#         if m.modelId.startswith("AdapterHub/xlm-roberta-base-")
#            and m.modelId.endswith("-wiki_pfeiffer")
#     }
#     return to_load
# to_load = get_available_adapters()
# existing_adapters = list(to_load.values()) + ["eu", "sr"]
existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
scores = {"ner": {}, "pos": {}, "copa": {}, "qa": {}}
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1", "sib": "eval_accuracy"}
inf = math.inf
for file in os.listdir("../eval_scores/approximation"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/approximation", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                # print(els)

                if len(els) == 3:
                    lang_name, task_name, option = els
                elif len(els) == 4:
                    lang_name, task_name, option, num = els

                if task_name == "sib":
                    continue
                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}

                # we add the data to the scores dictionary:
                # if option == extended, we add everything
                # otherwise, we append the "option" to the keys and add those

                for key in data.keys():
                    if not option == "extended":
                        new_key = f"{key}_{option}"
                    else:
                        new_key = key
                    if "convergence" in new_key:
                        # we skip the convergence scores
                        # print(new_key, "not taking convergence scores")
                        continue
                    # print(key, new_key)
                    scores[task_name][lang_name][new_key] = data[key][f1[task_name]]

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# Adding finetune baseline
for file in os.listdir("../eval_scores/ft"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/ft", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                if len(els) == 3:
                    lang_name, task_name, option = els

                if task_name == "sib":
                    continue
                if option == "eval":
                    option = "finetune"
                else:
                    option = "finetune_" + option
                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}
                score = data["finetuned_model"][f1[task_name]]
                scores[task_name][lang_name][option] = score

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# we make a subset consisting of only the languages for which an adapter exists
scores_subset = {}
no_adapter = {}
for task_name in scores:
    scores_subset[task_name] = {}
    no_adapter[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name in existing_adapters:
            scores_subset[task_name][lang_name] = scores[task_name][lang_name]
        else:
            no_adapter[task_name][lang_name] = scores[task_name][lang_name]
# adding convergence scores
for file in os.listdir("../eval_scores/convergence"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/convergence", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                # print(els)

                if len(els) == 3:
                    lang_name, task_name, option = els
                elif len(els) == 4:
                    lang_name, task_name, option, num = els

                if lang_name not in scores[task_name]:
                    scores[task_name][lang_name] = {}

                # we add the data to the scores dictionary:
                # if option == extended, we add everything
                # otherwise, we append the "option" to the keys and add those

                for key in data.keys():
                    if not option == "extended":  # correctly format baseline names, "extended" == base case
                        new_key = f"{key}_{option}"
                    else:
                        new_key = key
                    # print(key, new_key)
                    new_key = f"{new_key}_convergence"
                    scores[task_name][lang_name][new_key] = data[key][f1[task_name]]

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)
scores["ner"]


def get_significance(task_name, option1, option2, alternative="two-sided", data=scores):
    all_scores1 = []
    all_scores2 = []
    if task_name == "all":
        task_names = data.keys()
    elif type(task_name) is str:
        task_names = [task_name]
    else:
        task_names = task_name
    for task_name in task_names:
        for lang_name in data[task_name]:
            if option1 in data[task_name][lang_name] and option2 in data[task_name][lang_name]:
                score1 = data[task_name][lang_name][option1]
                score2 = data[task_name][lang_name][option2]
                if task_name == "qa":
                    # we divide the scores of qa by 100
                    score1 = score1 / 100
                    score2 = score2 / 100
                all_scores1.append(score1)
                all_scores2.append(score2)
    print("average scores")
    print(f"{option1}: {np.mean(all_scores1)}")
    print(f"{option2}: {np.mean(all_scores2)}")
    t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)
    print(f"t-statistic: {t_stat}")
    print(f"p-value: {p_val}")
    return t_stat, p_val
# Out:
# KeyError: nl_qa_test_squad_nl.json
# KeyError: nl_qa_test_squad_nl_bis.json
# KeyError: nl_qa_test_squad_nl_bis_bis.json
# KeyError: ace_sib_Arab_eval.json
# KeyError: ace_sib_Latn_eval.json
# KeyError: acm_sib_Arab_eval.json
# KeyError: acq_sib_Arab_eval.json
# KeyError: aeb_sib_Arab_eval.json
# KeyError: af_sib_Latn_eval.json
# KeyError: ajp_sib_Arab_eval.json
# KeyError: ak_sib_Latn_eval.json
# KeyError: als_sib_Latn_eval.json
# KeyError: am_sib_Ethi_eval.json
# KeyError: apc_sib_Arab_eval.json
# KeyError: arb_sib_Arab_eval.json
# KeyError: arb_sib_Latn_eval.json
# KeyError: ars_sib_Arab_eval.json
# KeyError: ary_sib_Arab_eval.json
# KeyError: arz_sib_Arab_eval.json
# KeyError: ast_sib_Latn_eval.json
# KeyError: as_sib_Beng_eval.json
# KeyError: awa_sib_Deva_eval.json
# KeyError: ayr_sib_Latn_eval.json
# KeyError: azb_sib_Arab_eval.json
# KeyError: azj_sib_Latn_eval.json
# KeyError: ban_sib_Latn_eval.json
# KeyError: ba_sib_Cyrl_eval.json
# KeyError: bem_sib_Latn_eval.json
# KeyError: be_sib_Cyrl_eval.json
# KeyError: bg_sib_Cyrl_eval.json
# KeyError: bho_sib_Deva_eval.json
# KeyError: bjn_sib_Arab_eval.json
# KeyError: bjn_sib_Latn_eval.json
# KeyError: bm_sib_Latn_eval.json
# KeyError: bn_sib_Beng_eval.json
# KeyError: bo_sib_Tibt_eval.json
# KeyError: bs_sib_Latn_eval.json
# KeyError: bug_sib_Latn_eval.json
# KeyError: ca_sib_Latn_eval.json
# KeyError: ceb_sib_Latn_eval.json
# KeyError: cjk_sib_Latn_eval.json
# KeyError: ckb_sib_Arab_eval.json
# KeyError: crh_sib_Latn_eval.json
# KeyError: cs_sib_Latn_eval.json
# KeyError: cy_sib_Latn_eval.json
# KeyError: da_sib_Latn_eval.json
# KeyError: de_sib_Latn_eval.json
# KeyError: dik_sib_Latn_eval.json
# KeyError: dyu_sib_Latn_eval.json
# KeyError: dz_sib_Tibt_eval.json
# KeyError: ee_sib_Latn_eval.json
# KeyError: el_sib_Grek_eval.json
# KeyError: en_sib_Latn_eval.json
# KeyError: eo_sib_Latn_eval.json
# KeyError: es_sib_Latn_eval.json
# KeyError: et_sib_Latn_eval.json
# KeyError: eu_sib_Latn_eval.json
# KeyError: fi_sib_Latn_eval.json
# KeyError: fj_sib_Latn_eval.json
# KeyError: fon_sib_Latn_eval.json
# KeyError: fo_sib_Latn_eval.json
# KeyError: fr_sib_Latn_eval.json
# KeyError: fur_sib_Latn_eval.json
# KeyError: fuv_sib_Latn_eval.json
# KeyError: gaz_sib_Latn_eval.json
# KeyError: ga_sib_Latn_eval.json
# KeyError: gd_sib_Latn_eval.json
# KeyError: gl_sib_Latn_eval.json
# KeyError: gn_sib_Latn_eval.json
# KeyError: gu_sib_Gujr_eval.json
# KeyError: ha_sib_Latn_eval.json
# KeyError: he_sib_Hebr_eval.json
# KeyError: hi_sib_Deva_eval.json
# KeyError: hne_sib_Deva_eval.json
# KeyError: hr_sib_Latn_eval.json
# KeyError: ht_sib_Latn_eval.json
# KeyError: hu_sib_Latn_eval.json
# KeyError: hy_sib_Armn_eval.json
# KeyError: id_sib_Latn_eval.json
# KeyError: ig_sib_Latn_eval.json
# KeyError: ilo_sib_Latn_eval.json
# KeyError: is_sib_Latn_eval.json
# KeyError: it_sib_Latn_eval.json
# KeyError: ja_sib_Jpan_eval.json
# KeyError: jv_sib_Latn_eval.json
# KeyError: kab_sib_Latn_eval.json
# KeyError: kac_sib_Latn_eval.json
# KeyError: kam_sib_Latn_eval.json
# KeyError: ka_sib_Geor_eval.json
# KeyError: kbp_sib_Latn_eval.json
# KeyError: kea_sib_Latn_eval.json
# KeyError: kg_sib_Latn_eval.json
# KeyError: khk_sib_Cyrl_eval.json
# KeyError: ki_sib_Latn_eval.json
# KeyError: kk_sib_Cyrl_eval.json
# KeyError: kmb_sib_Latn_eval.json
# KeyError: kmr_sib_Latn_eval.json
# KeyError: km_sib_Khmr_eval.json
# KeyError: knc_sib_Arab_eval.json
# KeyError: knc_sib_Latn_eval.json
# KeyError: kn_sib_Knda_eval.json
# KeyError: ko_sib_Hang_eval.json
# KeyError: ks_sib_Arab_eval.json
# KeyError: ks_sib_Deva_eval.json
# KeyError: ky_sib_Cyrl_eval.json
# KeyError: lb_sib_Latn_eval.json
# KeyError: lg_sib_Latn_eval.json
# KeyError: lij_sib_Latn_eval.json
# KeyError: li_sib_Latn_eval.json
# KeyError: lmo_sib_Latn_eval.json
# KeyError: ln_sib_Latn_eval.json
# KeyError: lo_sib_Laoo_eval.json
# KeyError: ltg_sib_Latn_eval.json
# KeyError: lt_sib_Latn_eval.json
# KeyError: lua_sib_Latn_eval.json
# KeyError: luo_sib_Latn_eval.json
# KeyError: lus_sib_Latn_eval.json
# KeyError: lvs_sib_Latn_eval.json
# KeyError: mag_sib_Deva_eval.json
# KeyError: mai_sib_Deva_eval.json
# KeyError: min_sib_Arab_eval.json
# KeyError: min_sib_Latn_eval.json
# KeyError: mi_sib_Latn_eval.json
# KeyError: mk_sib_Cyrl_eval.json
# KeyError: ml_sib_Mlym_eval.json
# KeyError: mni_sib_Beng_eval.json
# KeyError: mos_sib_Latn_eval.json
# KeyError: mr_sib_Deva_eval.json
# KeyError: mt_sib_Latn_eval.json
# KeyError: my_sib_Mymr_eval.json
# KeyError: nb_sib_Latn_eval.json
# KeyError: nl_sib_Latn_eval.json
# KeyError: nn_sib_Latn_eval.json
# KeyError: npi_sib_Deva_eval.json
# KeyError: nso_sib_Latn_eval.json
# KeyError: nus_sib_Latn_eval.json
# KeyError: ny_sib_Latn_eval.json
# KeyError: oc_sib_Latn_eval.json
# KeyError: ory_sib_Orya_eval.json
# KeyError: pag_sib_Latn_eval.json
# KeyError: pap_sib_Latn_eval.json
# KeyError: pa_sib_Guru_eval.json
# KeyError: pbt_sib_Arab_eval.json
# KeyError: pes_sib_Arab_eval.json
# KeyError: plt_sib_Latn_eval.json
# KeyError: pl_sib_Latn_eval.json
# KeyError: prs_sib_Arab_eval.json
# KeyError: pt_sib_Latn_eval.json
# KeyError: quy_sib_Latn_eval.json
# KeyError: rn_sib_Latn_eval.json
# KeyError: ro_sib_Latn_eval.json
# KeyError: ru_sib_Cyrl_eval.json
# KeyError: rw_sib_Latn_eval.json
# KeyError: sat_sib_Olck_eval.json
# KeyError: scn_sib_Latn_eval.json
# KeyError: sc_sib_Latn_eval.json
# KeyError: sd_sib_Arab_eval.json
# KeyError: sg_sib_Latn_eval.json
# KeyError: shn_sib_Mymr_eval.json
# KeyError: si_sib_Sinh_eval.json
# KeyError: sk_sib_Latn_eval.json
# KeyError: sl_sib_Latn_eval.json
# KeyError: sm_sib_Latn_eval.json
# KeyError: sn_sib_Latn_eval.json
# KeyError: so_sib_Latn_eval.json
# KeyError: sr_sib_Cyrl_eval.json
# KeyError: ss_sib_Latn_eval.json
# KeyError: st_sib_Latn_eval.json
# KeyError: su_sib_Latn_eval.json
# KeyError: sv_sib_Latn_eval.json
# KeyError: swh_sib_Latn_eval.json
# KeyError: szl_sib_Latn_eval.json
# KeyError: taq_sib_Latn_eval.json
# KeyError: taq_sib_Tfng_eval.json
# KeyError: ta_sib_Taml_eval.json
# KeyError: te_sib_Telu_eval.json
# KeyError: tg_sib_Cyrl_eval.json
# KeyError: th_sib_Thai_eval.json
# KeyError: ti_sib_Ethi_eval.json
# KeyError: tk_sib_Latn_eval.json
# KeyError: tl_sib_Latn_eval.json
# KeyError: tn_sib_Latn_eval.json
# KeyError: tpi_sib_Latn_eval.json
# KeyError: tr_sib_Latn_eval.json
# KeyError: ts_sib_Latn_eval.json
# KeyError: tt_sib_Cyrl_eval.json
# KeyError: tum_sib_Latn_eval.json
# KeyError: tw_sib_Latn_eval.json
# KeyError: tzm_sib_Tfng_eval.json
# KeyError: ug_sib_Arab_eval.json
# KeyError: uk_sib_Cyrl_eval.json
# KeyError: umb_sib_Latn_eval.json
# KeyError: ur_sib_Arab_eval.json
# KeyError: uzn_sib_Latn_eval.json
# KeyError: vec_sib_Latn_eval.json
# KeyError: vi_sib_Latn_eval.json
# KeyError: war_sib_Latn_eval.json
# KeyError: wo_sib_Latn_eval.json
# KeyError: xh_sib_Latn_eval.json
# KeyError: ydd_sib_Hebr_eval.json
# KeyError: yo_sib_Latn_eval.json
# KeyError: yue_sib_Hant_eval.json
# KeyError: zh_sib_Hans_eval.json
# KeyError: zh_sib_Hant_eval.json
# KeyError: zsm_sib_Latn_eval.json
# KeyError: zu_sib_Latn_eval.json

# %%
# we calculate averages of all columns
averages = {}
for task_name in scores:
    averages[task_name] = {}
    for lang_name in scores[task_name]:
        for key in scores[task_name][lang_name]:
            if key not in averages[task_name]:
                averages[task_name][key] = [scores[task_name][lang_name][key], 1]
            else:
                averages[task_name][key][0] += scores[task_name][lang_name][key]
                averages[task_name][key][1] += 1
    averages[task_name] = {key: value[0] / value[1] for key, value in averages[task_name].items()}

# %%
# we compare the averages of each key <> key_converged
better = {}
worse = {}
for task in averages:
    better[task] = []
    worse[task] = []
    keys = averages[task].keys()
    for key in averages[task]:
        conv = key + "_convergence"
        if not key.endswith("convergence") and conv in keys:
            key_score = averages[task][key]
            conv_score = averages[task][conv]
            diff = conv_score - key_score
            if key_score > conv_score:
                worse[task].append((key, diff))
            else:
                better[task].append((key, diff))
print("outperform:", better)
print("NO outperform:", worse)
# Out:
# outperform: {'ner': [('reconstructed_featural_base', 0.0), ('reconstructed_syntactic_distVar', 0.0), ('reconstructed_morphological_distVar', 0.0), ('reconstructed_featural_eu', 0.0), ('reconstructed_featural', 0.0), ('baseline_en', 0.0), ('baseline_task_adapter', 0.0), ('baseline_avg_adapter', 0.0), ('baseline_closest_featural', 0.0), ('no_train_gain', 0.0), ('reconstructed_featural_limit', 0.0), ('reconstructed_syntactic_limit', 0.0), ('reconstructed_morphological_limit', 0.0), ('reconstructed_featural_sr', 0.0), ('reconstructed_featural_threshold', 0.0), ('reconstructed_syntactic_threshold', 0.0), ('reconstructed_morphological_threshold', 0.0)], 'pos': [('reconstructed_featural_base', 0.0), ('reconstructed_featural_eu', 0.0), ('reconstructed_featural', 0.0), ('baseline_en', 0.0), ('baseline_task_adapter', 0.0), ('baseline_avg_adapter', 0.0), ('baseline_closest_featural', 0.0), ('no_train_gain', 0.0), ('reconstructed_featural_sr', 0.0), ('reconstructed_featural_threshold', 0.0), ('reconstructed_syntactic_threshold', 0.0), ('reconstructed_morphological_threshold', 0.0), ('finetune', 0.019636827862103134), ('reconstructed_syntactic_distVar', 0.0), ('reconstructed_morphological_distVar', 0.0), ('reconstructed_featural_limit', 0.0), ('reconstructed_syntactic_limit', 0.0), ('reconstructed_morphological_limit', 0.0), ('baseline_en_threshold', 0.0), ('baseline_task_adapter_threshold', 0.0), ('baseline_avg_adapter_threshold', 0.0), ('baseline_closest_featural_threshold', 0.0), ('baseline_closest_syntactic_threshold', 0.0), ('baseline_closest_morphological_threshold', 0.0), ('no_train_gain_threshold', 0.0)], 'copa': [('reconstructed_featural_base', 0.0), ('reconstructed_featural_eu', 0.0), ('reconstructed_featural', 0.0), ('baseline_en', 0.0), ('baseline_task_adapter', 0.0), ('baseline_avg_adapter', 0.0), ('baseline_closest_featural', 0.0), ('no_train_gain', 0.0), ('reconstructed_featural_limit', 0.0), ('reconstructed_syntactic_limit', 0.0), ('reconstructed_morphological_limit', 0.0), ('reconstructed_featural_sr', 0.0), ('reconstructed_featural_threshold', 0.0), ('reconstructed_syntactic_threshold', 0.0), ('reconstructed_morphological_threshold', 0.0)], 'qa': [('reconstructed_featural_base', 0.0), ('reconstructed_syntactic_distVar', 0.0), ('reconstructed_morphological_distVar', 0.0), ('reconstructed_featural_eu', 0.0), ('reconstructed_featural', 0.0), ('baseline_en', 0.0), ('baseline_task_adapter', 0.0), ('baseline_avg_adapter', 0.0), ('baseline_closest_featural', 0.0), ('no_train_gain', 0.0), ('reconstructed_featural_limit', 0.0), ('reconstructed_morphological_limit', 0.0), ('reconstructed_syntactic_limit', 0.0), ('reconstructed_featural_sr', 0.0), ('reconstructed_featural_threshold', 0.0), ('reconstructed_syntactic_threshold', 0.0), ('reconstructed_morphological_threshold', 0.0), ('finetune', 0.7877172078527934)]}
# NO outperform: {'ner': [('finetune', -0.023793805308459925)], 'pos': [], 'copa': [('finetune', -0.05527272727272725)], 'qa': []}

# %%
# for those in better, we check if they are significantly better.
# for those in worse, if they are significantly worse
tasks = ["ner", "pos", "copa", "qa"]
for task in tasks:
    for key, diff in better[task]:
        print(f"{task} {key} outperforming {key}_convergence")
        t_stat, p_val = get_significance(task, key, key + "_convergence", alternative="less")
        if p_val < 0.05:
            print("The difference IS statistically significant")
        else:
            print("The difference is not statistically significant")
        print("\n")
    for key, diff in worse[task]:
        print(f"{task} {key} UNDERPERFORMING {key}_convergence")
        t_stat, p_val = get_significance(task, key, key + "_convergence", alternative="greater")
        if p_val < 0.05:
            print("The difference IS statistically significant")
        else:
            print("The difference is not statistically significant")
        print("\n")
    print("\n~\n")
# Out:
# ner reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.5041674016886359
# reconstructed_featural_base_convergence: 0.5041674016886359
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.4972654118951448
# reconstructed_syntactic_distVar_convergence: 0.4972654118951448
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.49784227832341155
# reconstructed_morphological_distVar_convergence: 0.49784227832341155
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.50253570770369
# reconstructed_featural_eu_convergence: 0.50253570770369
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.5013399275268126
# reconstructed_featural_convergence: 0.5013399275268126
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.45986180313931335
# baseline_en_convergence: 0.45986180313931335
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.44275300926552397
# baseline_task_adapter_convergence: 0.44275300926552397
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.39532461426531496
# baseline_avg_adapter_convergence: 0.39532461426531496
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.4334773294245811
# baseline_closest_featural_convergence: 0.4334773294245811
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.4931179220070703
# no_train_gain_convergence: 0.4931179220070703
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.5125092701316386
# reconstructed_featural_limit_convergence: 0.5125092701316386
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.5107850690948645
# reconstructed_syntactic_limit_convergence: 0.5107850690948645
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.5083653805724313
# reconstructed_morphological_limit_convergence: 0.5083653805724313
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.5024547316555162
# reconstructed_featural_sr_convergence: 0.5024547316555162
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.5071915253930095
# reconstructed_featural_threshold_convergence: 0.5071915253930095
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.5070287947192814
# reconstructed_syntactic_threshold_convergence: 0.5070287947192814
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.5077955609056627
# reconstructed_morphological_threshold_convergence: 0.5077955609056627
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# ner finetune UNDERPERFORMING finetune_convergence
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 2.3063187160543134e-06
# The difference IS statistically significant
#
#
#
# ~
#
# pos reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.4654060010002513
# reconstructed_featural_base_convergence: 0.4654060010002513
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.46650971101940225
# reconstructed_featural_eu_convergence: 0.46650971101940225
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.4679441087506307
# reconstructed_featural_convergence: 0.4679441087506307
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.4629605609742856
# baseline_en_convergence: 0.4629605609742856
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.4672603118980092
# baseline_task_adapter_convergence: 0.4672603118980092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.45354927056693806
# baseline_avg_adapter_convergence: 0.45354927056693806
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.44610633002409844
# baseline_closest_featural_convergence: 0.44610633002409844
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.4685519779311475
# no_train_gain_convergence: 0.4685519779311475
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.4664995320737348
# reconstructed_featural_sr_convergence: 0.4664995320737348
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.45524588993454135
# reconstructed_featural_threshold_convergence: 0.45524588993454135
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.4554724782504057
# reconstructed_syntactic_threshold_convergence: 0.4554724782504057
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.45627621549233105
# reconstructed_morphological_threshold_convergence: 0.45627621549233105
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos finetune outperforming finetune_convergence
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 2.7564864348877894e-07
# The difference IS statistically significant
#
#
# pos reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.4450213675506433
# reconstructed_syntactic_distVar_convergence: 0.4450213675506433
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.44656751999050137
# reconstructed_morphological_distVar_convergence: 0.44656751999050137
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.4454303875907225
# reconstructed_featural_limit_convergence: 0.4454303875907225
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.44639138621322294
# reconstructed_syntactic_limit_convergence: 0.44639138621322294
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.44520581402313775
# reconstructed_morphological_limit_convergence: 0.44520581402313775
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_en_threshold outperforming baseline_en_threshold_convergence
# average scores
# baseline_en_threshold: 0.36875494621679444
# baseline_en_threshold_convergence: 0.36875494621679444
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_task_adapter_threshold outperforming baseline_task_adapter_threshold_convergence
# average scores
# baseline_task_adapter_threshold: 0.3722896679990427
# baseline_task_adapter_threshold_convergence: 0.3722896679990427
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_avg_adapter_threshold outperforming baseline_avg_adapter_threshold_convergence
# average scores
# baseline_avg_adapter_threshold: 0.3548812829931457
# baseline_avg_adapter_threshold_convergence: 0.3548812829931457
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_closest_featural_threshold outperforming baseline_closest_featural_threshold_convergence
# average scores
# baseline_closest_featural_threshold: 0.3590922675663072
# baseline_closest_featural_threshold_convergence: 0.3590922675663072
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_closest_syntactic_threshold outperforming baseline_closest_syntactic_threshold_convergence
# average scores
# baseline_closest_syntactic_threshold: 0.3590922675663072
# baseline_closest_syntactic_threshold_convergence: 0.3590922675663072
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos baseline_closest_morphological_threshold outperforming baseline_closest_morphological_threshold_convergence
# average scores
# baseline_closest_morphological_threshold: 0.3590922675663072
# baseline_closest_morphological_threshold_convergence: 0.3590922675663072
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# pos no_train_gain_threshold outperforming no_train_gain_threshold_convergence
# average scores
# no_train_gain_threshold: 0.37296585392016157
# no_train_gain_threshold_convergence: 0.37296585392016157
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
#
# ~
#
# copa reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.5165454545454545
# reconstructed_featural_base_convergence: 0.5165454545454545
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.512909090909091
# reconstructed_featural_eu_convergence: 0.512909090909091
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.512
# reconstructed_featural_convergence: 0.512
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.5083636363636364
# baseline_en_convergence: 0.5083636363636364
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.5036363636363635
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.5150909090909092
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.5198181818181818
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.503090909090909
# no_train_gain_convergence: 0.503090909090909
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.5181818181818182
# reconstructed_featural_limit_convergence: 0.5181818181818182
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.5161818181818183
# reconstructed_syntactic_limit_convergence: 0.5161818181818183
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.5143636363636365
# reconstructed_morphological_limit_convergence: 0.5143636363636365
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.512
# reconstructed_featural_sr_convergence: 0.512
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.5172727272727273
# reconstructed_featural_threshold_convergence: 0.5172727272727273
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.5179999999999999
# reconstructed_syntactic_threshold_convergence: 0.5179999999999999
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.5169090909090909
# reconstructed_morphological_threshold_convergence: 0.5169090909090909
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# copa finetune UNDERPERFORMING finetune_convergence
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 7.246721077131189e-05
# The difference IS statistically significant
#
#
#
# ~
#
# qa reconstructed_featural_base outperforming reconstructed_featural_base_convergence
# average scores
# reconstructed_featural_base: 0.7265242233928645
# reconstructed_featural_base_convergence: 0.7265242233928645
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_syntactic_distVar outperforming reconstructed_syntactic_distVar_convergence
# average scores
# reconstructed_syntactic_distVar: 0.7270498698545946
# reconstructed_syntactic_distVar_convergence: 0.7270498698545946
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_morphological_distVar outperforming reconstructed_morphological_distVar_convergence
# average scores
# reconstructed_morphological_distVar: 0.7272652915477485
# reconstructed_morphological_distVar_convergence: 0.7272652915477485
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_featural_eu outperforming reconstructed_featural_eu_convergence
# average scores
# reconstructed_featural_eu: 0.7265765269051171
# reconstructed_featural_eu_convergence: 0.7265765269051171
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_featural outperforming reconstructed_featural_convergence
# average scores
# reconstructed_featural: 0.7271252762822759
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa baseline_en outperforming baseline_en_convergence
# average scores
# baseline_en: 0.7210740878836793
# baseline_en_convergence: 0.7210740878836793
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa baseline_task_adapter outperforming baseline_task_adapter_convergence
# average scores
# baseline_task_adapter: 0.724905326156018
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa baseline_avg_adapter outperforming baseline_avg_adapter_convergence
# average scores
# baseline_avg_adapter: 0.6859815065016108
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa baseline_closest_featural outperforming baseline_closest_featural_convergence
# average scores
# baseline_closest_featural: 0.7210850183435054
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa no_train_gain outperforming no_train_gain_convergence
# average scores
# no_train_gain: 0.7252841925923107
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_featural_limit outperforming reconstructed_featural_limit_convergence
# average scores
# reconstructed_featural_limit: 0.7281344543568334
# reconstructed_featural_limit_convergence: 0.7281344543568334
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_morphological_limit outperforming reconstructed_morphological_limit_convergence
# average scores
# reconstructed_morphological_limit: 0.7284004003755643
# reconstructed_morphological_limit_convergence: 0.7284004003755643
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_syntactic_limit outperforming reconstructed_syntactic_limit_convergence
# average scores
# reconstructed_syntactic_limit: 0.7281198226218644
# reconstructed_syntactic_limit_convergence: 0.7281198226218644
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_featural_sr outperforming reconstructed_featural_sr_convergence
# average scores
# reconstructed_featural_sr: 0.7271460731003012
# reconstructed_featural_sr_convergence: 0.7271460731003012
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_featural_threshold outperforming reconstructed_featural_threshold_convergence
# average scores
# reconstructed_featural_threshold: 0.7266866467655285
# reconstructed_featural_threshold_convergence: 0.7266866467655285
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_syntactic_threshold outperforming reconstructed_syntactic_threshold_convergence
# average scores
# reconstructed_syntactic_threshold: 0.7271196088629276
# reconstructed_syntactic_threshold_convergence: 0.7271196088629276
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa reconstructed_morphological_threshold outperforming reconstructed_morphological_threshold_convergence
# average scores
# reconstructed_morphological_threshold: 0.7285715530023293
# reconstructed_morphological_threshold_convergence: 0.7285715530023293
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# qa finetune outperforming finetune_convergence
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.21332527829156234
# The difference is not statistically significant
#
#
#
# ~
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\scipy\stats\_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\scipy\stats\_stats_py.py:1214: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero

# %%
# check if "convergence" outperforms relative non-convergence scores
tasks = ["ner", "pos", "copa", "qa"]
test_columns = [
    "reconstructed_featural",
    "baseline_en",
    "baseline_avg_adapter",
    "baseline_task_adapter",
    "baseline_closest_featural",
    "no_train_gain",
    "finetune",
]
significant_more = {}
significant_less = {}
for task in tasks:
    for test_column in test_columns:
        print(f"{task} outperforming {test_column}")
        t_stat, p_val = get_significance(task, test_column, test_column + "_convergence", alternative="less")
        if p_val < 0.05:
            print("The difference is statistically significant")
            if test_column not in significant_more:
                significant_more[test_column] = {}
            significant_more[test_column][task] = (
                averages[task][test_column],
                averages[task][test_column + "_convergence"],
            )
        else:
            print("The difference is not statistically significant")
        print("\n")
        print(f"{test_column} outperforming {task}")
        t_stat, p_val = get_significance(task, test_column, test_column + "_convergence", alternative="greater")
        if p_val < 0.05:
            print("The difference is statistically significant")
            if test_column not in significant_less:
                significant_less[test_column] = {}
            significant_less[test_column][task] = (
                averages[task][test_column],
                averages[task][test_column + "_convergence"],
            )
        else:
            print("The difference is not statistically significant")
        print("-----------------------------------")
# Out:
# ner outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.5013399275268126
# reconstructed_featural_convergence: 0.5013399275268126
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming ner
# average scores
# reconstructed_featural: 0.5013399275268126
# reconstructed_featural_convergence: 0.5013399275268126
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_en
# average scores
# baseline_en: 0.45986180313931335
# baseline_en_convergence: 0.45986180313931335
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_en outperforming ner
# average scores
# baseline_en: 0.45986180313931335
# baseline_en_convergence: 0.45986180313931335
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.39532461426531496
# baseline_avg_adapter_convergence: 0.39532461426531496
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming ner
# average scores
# baseline_avg_adapter: 0.39532461426531496
# baseline_avg_adapter_convergence: 0.39532461426531496
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.44275300926552397
# baseline_task_adapter_convergence: 0.44275300926552397
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming ner
# average scores
# baseline_task_adapter: 0.44275300926552397
# baseline_task_adapter_convergence: 0.44275300926552397
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.4334773294245811
# baseline_closest_featural_convergence: 0.4334773294245811
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming ner
# average scores
# baseline_closest_featural: 0.4334773294245811
# baseline_closest_featural_convergence: 0.4334773294245811
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming no_train_gain
# average scores
# no_train_gain: 0.4931179220070703
# no_train_gain_convergence: 0.4931179220070703
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# no_train_gain outperforming ner
# average scores
# no_train_gain: 0.4931179220070703
# no_train_gain_convergence: 0.4931179220070703
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# ner outperforming finetune
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 0.9999976936812839
# The difference is not statistically significant
#
#
# finetune outperforming ner
# average scores
# finetune: 0.4138695075474663
# finetune_convergence: 0.3900757022390063
# t-statistic: 4.749359702468565
# p-value: 2.3063187160543134e-06
# The difference is statistically significant
# -----------------------------------
# pos outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.4679441087506307
# reconstructed_featural_convergence: 0.4679441087506307
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming pos
# average scores
# reconstructed_featural: 0.4679441087506307
# reconstructed_featural_convergence: 0.4679441087506307
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_en
# average scores
# baseline_en: 0.4629605609742856
# baseline_en_convergence: 0.4629605609742856
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_en outperforming pos
# average scores
# baseline_en: 0.4629605609742856
# baseline_en_convergence: 0.4629605609742856
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.45354927056693806
# baseline_avg_adapter_convergence: 0.45354927056693806
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming pos
# average scores
# baseline_avg_adapter: 0.45354927056693806
# baseline_avg_adapter_convergence: 0.45354927056693806
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.4672603118980092
# baseline_task_adapter_convergence: 0.4672603118980092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming pos
# average scores
# baseline_task_adapter: 0.4672603118980092
# baseline_task_adapter_convergence: 0.4672603118980092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.44610633002409844
# baseline_closest_featural_convergence: 0.44610633002409844
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming pos
# average scores
# baseline_closest_featural: 0.44610633002409844
# baseline_closest_featural_convergence: 0.44610633002409844
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming no_train_gain
# average scores
# no_train_gain: 0.4685519779311475
# no_train_gain_convergence: 0.4685519779311475
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# no_train_gain outperforming pos
# average scores
# no_train_gain: 0.4685519779311475
# no_train_gain_convergence: 0.4685519779311475
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# pos outperforming finetune
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 2.7564864348877894e-07
# The difference is statistically significant
#
#
# finetune outperforming pos
# average scores
# finetune: 0.3693497963144302
# finetune_convergence: 0.38898662417653296
# t-statistic: -5.398830373817152
# p-value: 0.9999997243513565
# The difference is not statistically significant
# -----------------------------------
# copa outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.512
# reconstructed_featural_convergence: 0.512
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming copa
# average scores
# reconstructed_featural: 0.512
# reconstructed_featural_convergence: 0.512
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming baseline_en
# average scores
# baseline_en: 0.5083636363636364
# baseline_en_convergence: 0.5083636363636364
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_en outperforming copa
# average scores
# baseline_en: 0.5083636363636364
# baseline_en_convergence: 0.5083636363636364
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.5150909090909092
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming copa
# average scores
# baseline_avg_adapter: 0.5150909090909092
# baseline_avg_adapter_convergence: 0.5150909090909092
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.5036363636363635
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming copa
# average scores
# baseline_task_adapter: 0.5036363636363635
# baseline_task_adapter_convergence: 0.5036363636363635
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.5198181818181818
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming copa
# average scores
# baseline_closest_featural: 0.5198181818181818
# baseline_closest_featural_convergence: 0.5198181818181818
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming no_train_gain
# average scores
# no_train_gain: 0.503090909090909
# no_train_gain_convergence: 0.503090909090909
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# no_train_gain outperforming copa
# average scores
# no_train_gain: 0.503090909090909
# no_train_gain_convergence: 0.503090909090909
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# copa outperforming finetune
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 0.9999275327892287
# The difference is not statistically significant
#
#
# finetune outperforming copa
# average scores
# finetune: 0.5552727272727273
# finetune_convergence: 0.5
# t-statistic: 5.9307618575274645
# p-value: 7.246721077131189e-05
# The difference is statistically significant
# -----------------------------------
# qa outperforming reconstructed_featural
# average scores
# reconstructed_featural: 0.7271252762822759
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# reconstructed_featural outperforming qa
# average scores
# reconstructed_featural: 0.7271252762822759
# reconstructed_featural_convergence: 0.7271252762822759
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_en
# average scores
# baseline_en: 0.7210740878836793
# baseline_en_convergence: 0.7210740878836793
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_en outperforming qa
# average scores
# baseline_en: 0.7210740878836793
# baseline_en_convergence: 0.7210740878836793
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_avg_adapter
# average scores
# baseline_avg_adapter: 0.6859815065016108
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_avg_adapter outperforming qa
# average scores
# baseline_avg_adapter: 0.6859815065016108
# baseline_avg_adapter_convergence: 0.6859815065016108
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_task_adapter
# average scores
# baseline_task_adapter: 0.724905326156018
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_task_adapter outperforming qa
# average scores
# baseline_task_adapter: 0.724905326156018
# baseline_task_adapter_convergence: 0.724905326156018
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming baseline_closest_featural
# average scores
# baseline_closest_featural: 0.7210850183435054
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# baseline_closest_featural outperforming qa
# average scores
# baseline_closest_featural: 0.7210850183435054
# baseline_closest_featural_convergence: 0.7210850183435054
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming no_train_gain
# average scores
# no_train_gain: 0.7252841925923107
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
#
#
# no_train_gain outperforming qa
# average scores
# no_train_gain: 0.7252841925923107
# no_train_gain_convergence: 0.7252841925923107
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# qa outperforming finetune
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.21332527829156234
# The difference is not statistically significant
#
#
# finetune outperforming qa
# average scores
# finetune: 0.5257946347854969
# finetune_convergence: 0.5336718068640248
# t-statistic: -0.8254594979510611
# p-value: 0.7866747217084377
# The difference is not statistically significant
# -----------------------------------

# %% [markdown]
# # Results
# NER
# 	• Approximation & Baselines (ADAPTER)
# 		○ Better in all cases, Statistically significant
# 			§ all over the line (1 exception out of 16)
# 	• Finetune
# 		○ Worse, statistically significant but small difference
# POS
# 	• Approximation
# 		○ No significantly worse for convergence, very small differences
# 	• Baselines
# 		○ Better
# 			§ Significant
# 				□ En adapter, MAD-X (closest featural) setting
# 			§ Not significant: no-train-gain
# 	• Finetune
# 		○ Better, statistically significant
# COPA
# 	• Significantly worse all over the line!
# 	• --> Reason: very small dataset,
# 		○ if need for eval (convergence stopping criterium), then performance further decreases
# QA
# 	• Significantly better all over the line!
# 	• Training cost
#
# ## Conclusion: fair comparison
# NER: take convergence scores to maintain comparibility in the setting (only small difference for finetune)
# POS: convergence for both adapter and finetune, our method underperforms but not significantly
# COPA: Take non-convergence all over the line
# QA: convergence all over the line

# %%
# We make a new directory under eval_scores with the results that we will use for further eval
if not os.path.exists("../eval_scores/selected"):
    os.makedirs("../eval_scores/selected")
task2selection = {"ner": "convergence", "pos": "convergence", "copa": "no_convergence", "qa": "convergence"}
scores_selected = {}
for task_name in task2selection:
    scores_selected[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name not in scores_selected[task_name]:
            scores_selected[task_name][lang_name] = {}
        if task2selection[task_name] == "convergence":
            for key in scores[task_name][lang_name]:
                if key.endswith("convergence"):
                    new_key = key.split("_convergence")[0]
                    if not task_name == "qa":
                        scores_selected[task_name][lang_name][new_key] = scores[task_name][lang_name][key]
                    else:
                        # we divide the scores of qa by 100
                        scores_selected[task_name][lang_name][new_key] = scores[task_name][lang_name][key] / 100
        else:  # no convergence: copa
            for key in scores[task_name][lang_name]:
                if not key.endswith("convergence"):
                    scores_selected[task_name][lang_name][key] = scores[task_name][lang_name][key]
    with open(f"../eval_scores/selected/{task_name}.json", "w") as f:
        json.dump(scores_selected[task_name], f, indent=4)

# %%
# we make a similar file for the sib scores, added at a later stage
sib_scores = {}
for file in os.listdir("../eval_scores/approximation"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/approximation", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                # print(els)

                if len(els) == 3:
                    continue
                elif len(els) == 4:
                    lang_name, task_name, script, option = els
                elif len(els) == 5:
                    lang_name, task_name, script, option, num = els

                if not task_name == "sib":
                    continue
                if lang_name not in sib_scores.keys():
                    sib_scores[lang_name] = {}

                # we add the data to the scores dictionary:
                # if option == extended, we add everything
                # otherwise, we append the "option" to the keys and add those

                for key in data.keys():
                    if not option == "extended":
                        new_key = f"{key}_{script}_{option}"
                    else:
                        new_key = f"{key}_{script}"
                    # print(key, new_key)
                    sib_scores[lang_name][new_key] = data[key][f1[task_name]]

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# %%
# Adding finetune baseline
for file in os.listdir("../eval_scores/ft"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/ft", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                if len(els) == 3:
                    lang_name, task_name, option = els
                elif len(els) == 4:
                    lang_name, task_name, script, option = els
                if not task_name == "sib":
                    continue
                if option == "eval":
                    option = "finetune" + "_" + script
                else:
                    option = "finetune_" + option + "_" + script
                if lang_name not in sib_scores:
                    sib_scores[lang_name] = {}

                score = data["finetuned_model"][f1[task_name]]
                sib_scores[lang_name][option] = score

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# %%
import re

one_per_lang_sib = {}
all_sib_scores = {}
lang2script = {}
# if there are multiple scripts for a language, we simply average over them. if not, we take the value
for lang, keys in sib_scores.items():
    one_per_lang_sib[lang] = {}
    all_sib_scores[lang] = {}
    scripts = [key.split("_")[1] for key in keys if key.startswith("finetune")]
    lang2script[lang] = scripts
    if len(scripts) == 1:
        # we remove all f"_{script}" from the keys and put them in one_per_lang_sib[lang]
        script = scripts[0]
        pattern = f"_{script}"
        lang2script[lang] = scripts

        for key, value in keys.items():
            new_key = re.sub(pattern, "", key)
            # print(f"{key} -> {new_key}")
            one_per_lang_sib[lang][new_key] = value
    else:
        pattern = f"_({'|'.join(scripts)})"
        for key, value in keys.items():
            new_key = re.sub(pattern, "", key)
            if new_key not in one_per_lang_sib[lang]:
                one_per_lang_sib[lang][new_key] = [value, 1]
            else:
                one_per_lang_sib[lang][new_key][0] += value
                one_per_lang_sib[lang][new_key][1] += 1
        # we average the values
        for key in one_per_lang_sib[lang]:
            if type(one_per_lang_sib[lang][key]) is list:
                one_per_lang_sib[lang][key] = one_per_lang_sib[lang][key][0] / one_per_lang_sib[lang][key][1]
            else:
                one_per_lang_sib[lang][key] = one_per_lang_sib[lang][key]
    for script in scripts:
        all_sib_scores[lang][script] = {}
        pattern = f"_{script}"
        for key, value in keys.items():
            # we do not consider those that do not have the pattern
            if pattern not in key:
                continue
            new_key = re.sub(pattern, "", key)
            all_sib_scores[lang][script][new_key] = value

# we save the one_per_lang_sib to a json file
with open("../eval_scores/selected/sib.json", "w") as f:
    json.dump(one_per_lang_sib, f, indent=4)
with open("../eval_scores/all_sib/sib.json", "w") as f:
    json.dump(all_sib_scores, f, indent=4)

# %%
all_sib_scores
# Out:
# {'ace': {'Arab': {'reconstructed_featural_base': 0.16176470588235295,
#    'reconstructed_syntactic_distVar': 0.1715686274509804,
#    'reconstructed_morphological_distVar': 0.1715686274509804,
#    'reconstructed_featural_eu': 0.1715686274509804,
#    'reconstructed_featural': 0.1715686274509804,
#    'baseline_en': 0.11274509803921569,
#    'baseline_task_adapter': 0.17647058823529413,
#    'baseline_avg_adapter': 0.10294117647058823,
#    'baseline_closest_featural': 0.12254901960784313,
#    'no_train_gain': 0.14215686274509803,
#    'reconstructed_featural_limit': 0.14705882352941177,
#    'reconstructed_morphological_limit': 0.14215686274509803,
#    'reconstructed_syntactic_limit': 0.16176470588235295,
#    'reconstructed_featural_sr': 0.1715686274509804,
#    'reconstructed_featural_threshold': 0.16666666666666666,
#    'reconstructed_morphological_threshold': 0.15196078431372548,
#    'reconstructed_syntactic_threshold': 0.16666666666666666,
#    'finetune': 0.18137254901960784},
#   'Latn': {'reconstructed_featural_base': 0.6568627450980392,
#    'reconstructed_syntactic_distVar': 0.6666666666666666,
#    'reconstructed_morphological_distVar': 0.6666666666666666,
#    'reconstructed_featural_eu': 0.6617647058823529,
#    'reconstructed_featural': 0.6617647058823529,
#    'baseline_en': 0.6127450980392157,
#    'baseline_task_adapter': 0.6568627450980392,
#    'baseline_avg_adapter': 0.45098039215686275,
#    'baseline_closest_featural': 0.696078431372549,
#    'no_train_gain': 0.7009803921568627,
#    'reconstructed_featural_limit': 0.6862745098039216,
#    'reconstructed_morphological_limit': 0.6911764705882353,
#    'reconstructed_syntactic_limit': 0.6911764705882353,
#    'reconstructed_featural_sr': 0.6666666666666666,
#    'reconstructed_featural_threshold': 0.6617647058823529,
#    'reconstructed_morphological_threshold': 0.6911764705882353,
#    'reconstructed_syntactic_threshold': 0.6862745098039216,
#    'finetune': 0.5196078431372549}},
#  'acm': {'Arab': {'reconstructed_featural_base': 0.8480392156862745,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8529411764705882,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural': 0.8578431372549019,
#    'baseline_en': 0.7696078431372549,
#    'baseline_task_adapter': 0.8284313725490197,
#    'baseline_avg_adapter': 0.7598039215686274,
#    'baseline_closest_featural': 0.7401960784313726,
#    'no_train_gain': 0.8480392156862745,
#    'reconstructed_featural_limit': 0.8529411764705882,
#    'reconstructed_morphological_limit': 0.8529411764705882,
#    'reconstructed_syntactic_limit': 0.8529411764705882,
#    'reconstructed_featural_sr': 0.8529411764705882,
#    'reconstructed_featural_threshold': 0.8627450980392157,
#    'reconstructed_morphological_threshold': 0.8529411764705882,
#    'reconstructed_syntactic_threshold': 0.8627450980392157,
#    'finetune': 0.8382352941176471}},
#  'acq': {'Arab': {'reconstructed_featural_base': 0.8578431372549019,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8578431372549019,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural_limit': 0.8578431372549019,
#    'reconstructed_morphological_limit': 0.8578431372549019,
#    'reconstructed_syntactic_limit': 0.8578431372549019,
#    'reconstructed_featural_sr': 0.8578431372549019,
#    'reconstructed_featural_threshold': 0.8578431372549019,
#    'reconstructed_morphological_threshold': 0.8578431372549019,
#    'reconstructed_syntactic_threshold': 0.8578431372549019,
#    'finetune': 0.8578431372549019}},
#  'aeb': {'Arab': {'reconstructed_featural_base': 0.8235294117647058,
#    'reconstructed_syntactic_distVar': 0.8235294117647058,
#    'reconstructed_morphological_distVar': 0.8235294117647058,
#    'reconstructed_featural_eu': 0.8235294117647058,
#    'reconstructed_featural': 0.8235294117647058,
#    'baseline_en': 0.7009803921568627,
#    'baseline_task_adapter': 0.7696078431372549,
#    'baseline_avg_adapter': 0.6862745098039216,
#    'baseline_closest_featural': 0.5392156862745098,
#    'no_train_gain': 0.7843137254901961,
#    'reconstructed_featural_limit': 0.8088235294117647,
#    'reconstructed_morphological_limit': 0.8235294117647058,
#    'reconstructed_syntactic_limit': 0.8088235294117647,
#    'reconstructed_featural_sr': 0.8284313725490197,
#    'reconstructed_featural_threshold': 0.8235294117647058,
#    'reconstructed_morphological_threshold': 0.8235294117647058,
#    'reconstructed_syntactic_threshold': 0.8235294117647058,
#    'finetune': 0.803921568627451}},
#  'af': {'Latn': {'reconstructed_featural_base': 0.8480392156862745,
#    'reconstructed_syntactic_distVar': 0.8480392156862745,
#    'reconstructed_morphological_distVar': 0.8480392156862745,
#    'reconstructed_featural_eu': 0.8431372549019608,
#    'reconstructed_featural': 0.8480392156862745,
#    'baseline_en': 0.8431372549019608,
#    'baseline_task_adapter': 0.8480392156862745,
#    'baseline_avg_adapter': 0.803921568627451,
#    'baseline_closest_featural': 0.8382352941176471,
#    'no_train_gain': 0.8578431372549019,
#    'reconstructed_featural_limit': 0.8529411764705882,
#    'reconstructed_morphological_limit': 0.8480392156862745,
#    'reconstructed_syntactic_limit': 0.8529411764705882,
#    'reconstructed_featural_sr': 0.8431372549019608,
#    'reconstructed_featural_threshold': 0.8480392156862745,
#    'reconstructed_morphological_threshold': 0.8480392156862745,
#    'reconstructed_syntactic_threshold': 0.8480392156862745,
#    'finetune': 0.8725490196078431}},
#  'ajp': {'Arab': {'reconstructed_featural_base': 0.8186274509803921,
#    'reconstructed_syntactic_distVar': 0.8186274509803921,
#    'reconstructed_morphological_distVar': 0.8186274509803921,
#    'reconstructed_featural_eu': 0.8186274509803921,
#    'reconstructed_featural_limit': 0.8186274509803921,
#    'reconstructed_morphological_limit': 0.8186274509803921,
#    'reconstructed_syntactic_limit': 0.8186274509803921,
#    'reconstructed_featural_sr': 0.8186274509803921,
#    'reconstructed_featural_threshold': 0.8186274509803921,
#    'reconstructed_morphological_threshold': 0.8186274509803921,
#    'reconstructed_syntactic_threshold': 0.8186274509803921,
#    'finetune': 0.803921568627451}},
#  'ak': {'Latn': {'reconstructed_featural_base': 0.29411764705882354,
#    'reconstructed_syntactic_distVar': 0.29411764705882354,
#    'reconstructed_morphological_distVar': 0.29411764705882354,
#    'reconstructed_featural_eu': 0.29411764705882354,
#    'reconstructed_featural': 0.29411764705882354,
#    'baseline_en': 0.3480392156862745,
#    'baseline_task_adapter': 0.30392156862745096,
#    'baseline_avg_adapter': 0.24509803921568626,
#    'baseline_closest_featural': 0.30392156862745096,
#    'no_train_gain': 0.3137254901960784,
#    'reconstructed_featural_limit': 0.29411764705882354,
#    'reconstructed_morphological_limit': 0.28921568627450983,
#    'reconstructed_syntactic_limit': 0.29901960784313725,
#    'reconstructed_featural_sr': 0.29411764705882354,
#    'reconstructed_featural_threshold': 0.29411764705882354,
#    'reconstructed_morphological_threshold': 0.29411764705882354,
#    'reconstructed_syntactic_threshold': 0.29411764705882354,
#    'finetune': 0.3382352941176471}},
#  'als': {'Latn': {'reconstructed_featural_base': 0.8578431372549019,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8578431372549019,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural': 0.8578431372549019,
#    'baseline_en': 0.8431372549019608,
#    'baseline_task_adapter': 0.8578431372549019,
#    'baseline_avg_adapter': 0.8431372549019608,
#    'baseline_closest_featural': 0.8235294117647058,
#    'no_train_gain': 0.8823529411764706,
#    'reconstructed_featural_limit': 0.8676470588235294,
#    'reconstructed_morphological_limit': 0.8382352941176471,
#    'reconstructed_syntactic_limit': 0.8676470588235294,
#    'reconstructed_featural_sr': 0.8578431372549019,
#    'reconstructed_featural_threshold': 0.8578431372549019,
#    'reconstructed_morphological_threshold': 0.8578431372549019,
#    'reconstructed_syntactic_threshold': 0.8578431372549019,
#    'finetune': 0.8774509803921569}},
#  'am': {'Ethi': {'reconstructed_featural_base': 0.7058823529411765,
#    'reconstructed_syntactic_distVar': 0.696078431372549,
#    'reconstructed_morphological_distVar': 0.7009803921568627,
#    'reconstructed_featural_eu': 0.7107843137254902,
#    'reconstructed_featural': 0.7009803921568627,
#    'baseline_en': 0.6225490196078431,
#    'baseline_task_adapter': 0.7058823529411765,
#    'baseline_avg_adapter': 0.5392156862745098,
#    'baseline_closest_featural': 0.5882352941176471,
#    'no_train_gain': 0.7107843137254902,
#    'reconstructed_featural_limit': 0.7058823529411765,
#    'reconstructed_morphological_limit': 0.7205882352941176,
#    'reconstructed_syntactic_limit': 0.7058823529411765,
#    'reconstructed_featural_sr': 0.7107843137254902,
#    'reconstructed_featural_threshold': 0.7058823529411765,
#    'reconstructed_morphological_threshold': 0.6911764705882353,
#    'reconstructed_syntactic_threshold': 0.696078431372549,
#    'finetune': 0.7009803921568627}},
#  'apc': {'Arab': {'reconstructed_featural_base': 0.8382352941176471,
#    'reconstructed_syntactic_distVar': 0.8235294117647058,
#    'reconstructed_morphological_distVar': 0.8235294117647058,
#    'reconstructed_featural_eu': 0.8333333333333334,
#    'reconstructed_featural': 0.8235294117647058,
#    'baseline_en': 0.7156862745098039,
#    'baseline_task_adapter': 0.7941176470588235,
#    'baseline_avg_adapter': 0.7205882352941176,
#    'baseline_closest_featural': 0.7745098039215687,
#    'no_train_gain': 0.8088235294117647,
#    'reconstructed_featural_limit': 0.8088235294117647,
#    'reconstructed_morphological_limit': 0.8333333333333334,
#    'reconstructed_syntactic_limit': 0.7990196078431373,
#    'reconstructed_featural_sr': 0.8333333333333334,
#    'reconstructed_featural_threshold': 0.8284313725490197,
#    'reconstructed_morphological_threshold': 0.8284313725490197,
#    'reconstructed_syntactic_threshold': 0.8137254901960784,
#    'finetune': 0.8235294117647058}},
#  'arb': {'Arab': {'reconstructed_featural_base': 0.8578431372549019,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8529411764705882,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural': 0.8529411764705882,
#    'baseline_en': 0.7941176470588235,
#    'baseline_task_adapter': 0.8529411764705882,
#    'baseline_avg_adapter': 0.7794117647058824,
#    'baseline_closest_featural': 0.8186274509803921,
#    'no_train_gain': 0.8431372549019608,
#    'reconstructed_featural_limit': 0.8480392156862745,
#    'reconstructed_morphological_limit': 0.8578431372549019,
#    'reconstructed_syntactic_limit': 0.8578431372549019,
#    'reconstructed_featural_sr': 0.8578431372549019,
#    'reconstructed_featural_threshold': 0.8529411764705882,
#    'reconstructed_morphological_threshold': 0.8480392156862745,
#    'reconstructed_syntactic_threshold': 0.8529411764705882,
#    'finetune': 0.8333333333333334},
#   'Latn': {'reconstructed_featural_base': 0.30392156862745096,
#    'reconstructed_syntactic_distVar': 0.29901960784313725,
#    'reconstructed_morphological_distVar': 0.29411764705882354,
#    'reconstructed_featural_eu': 0.3088235294117647,
#    'reconstructed_featural': 0.29901960784313725,
#    'baseline_en': 0.2696078431372549,
#    'baseline_task_adapter': 0.30392156862745096,
#    'baseline_avg_adapter': 0.22058823529411764,
#    'baseline_closest_featural': 0.1715686274509804,
#    'no_train_gain': 0.2107843137254902,
#    'reconstructed_featural_limit': 0.30392156862745096,
#    'reconstructed_morphological_limit': 0.3480392156862745,
#    'reconstructed_syntactic_limit': 0.3137254901960784,
#    'reconstructed_featural_sr': 0.3088235294117647,
#    'reconstructed_featural_threshold': 0.30392156862745096,
#    'reconstructed_morphological_threshold': 0.27450980392156865,
#    'reconstructed_syntactic_threshold': 0.29901960784313725,
#    'finetune': 0.24509803921568626}},
#  'ars': {'Arab': {'reconstructed_featural_base': 0.8627450980392157,
#    'reconstructed_syntactic_distVar': 0.8627450980392157,
#    'reconstructed_morphological_distVar': 0.8627450980392157,
#    'reconstructed_featural_eu': 0.8627450980392157,
#    'reconstructed_featural': 0.8627450980392157,
#    'baseline_en': 0.7990196078431373,
#    'baseline_task_adapter': 0.8480392156862745,
#    'baseline_avg_adapter': 0.7892156862745098,
#    'baseline_closest_featural': 0.6078431372549019,
#    'no_train_gain': 0.8529411764705882,
#    'reconstructed_featural_limit': 0.8529411764705882,
#    'reconstructed_morphological_limit': 0.8627450980392157,
#    'reconstructed_syntactic_limit': 0.8529411764705882,
#    'reconstructed_featural_sr': 0.8627450980392157,
#    'reconstructed_featural_threshold': 0.8627450980392157,
#    'reconstructed_morphological_threshold': 0.8627450980392157,
#    'reconstructed_syntactic_threshold': 0.8627450980392157,
#    'finetune': 0.8480392156862745}},
#  'ary': {'Arab': {'reconstructed_featural_base': 0.8382352941176471,
#    'reconstructed_syntactic_distVar': 0.8382352941176471,
#    'reconstructed_morphological_distVar': 0.8382352941176471,
#    'reconstructed_featural_eu': 0.8382352941176471,
#    'reconstructed_featural': 0.8382352941176471,
#    'baseline_en': 0.6519607843137255,
#    'baseline_task_adapter': 0.8284313725490197,
#    'baseline_avg_adapter': 0.6911764705882353,
#    'baseline_closest_featural': 0.6813725490196079,
#    'no_train_gain': 0.7843137254901961,
#    'reconstructed_featural_limit': 0.8186274509803921,
#    'reconstructed_morphological_limit': 0.8382352941176471,
#    'reconstructed_syntactic_limit': 0.8235294117647058,
#    'reconstructed_featural_sr': 0.8382352941176471,
#    'reconstructed_featural_threshold': 0.8333333333333334,
#    'reconstructed_morphological_threshold': 0.8382352941176471,
#    'reconstructed_syntactic_threshold': 0.8333333333333334,
#    'finetune': 0.7941176470588235}},
#  'arz': {'Arab': {'reconstructed_featural_base': 0.8088235294117647,
#    'reconstructed_syntactic_distVar': 0.8088235294117647,
#    'reconstructed_morphological_distVar': 0.8088235294117647,
#    'reconstructed_featural_eu': 0.8088235294117647,
#    'reconstructed_featural': 0.8088235294117647,
#    'baseline_en': 0.7254901960784313,
#    'baseline_task_adapter': 0.7794117647058824,
#    'baseline_avg_adapter': 0.6911764705882353,
#    'baseline_closest_featural': 0.7696078431372549,
#    'no_train_gain': 0.803921568627451,
#    'reconstructed_featural_limit': 0.7990196078431373,
#    'reconstructed_morphological_limit': 0.7990196078431373,
#    'reconstructed_syntactic_limit': 0.7990196078431373,
#    'reconstructed_featural_sr': 0.8088235294117647,
#    'reconstructed_featural_threshold': 0.803921568627451,
#    'reconstructed_morphological_threshold': 0.8088235294117647,
#    'reconstructed_syntactic_threshold': 0.8088235294117647,
#    'finetune': 0.8137254901960784}},
#  'ast': {'Latn': {'reconstructed_featural_base': 0.803921568627451,
#    'reconstructed_syntactic_distVar': 0.803921568627451,
#    'reconstructed_morphological_distVar': 0.803921568627451,
#    'reconstructed_featural_eu': 0.803921568627451,
#    'reconstructed_featural_limit': 0.803921568627451,
#    'reconstructed_morphological_limit': 0.803921568627451,
#    'reconstructed_syntactic_limit': 0.803921568627451,
#    'reconstructed_featural_sr': 0.803921568627451,
#    'reconstructed_featural_threshold': 0.803921568627451,
#    'reconstructed_morphological_threshold': 0.803921568627451,
#    'reconstructed_syntactic_threshold': 0.803921568627451,
#    'finetune': 0.8137254901960784}},
#  'as': {'Beng': {'reconstructed_featural_base': 0.6421568627450981,
#    'reconstructed_syntactic_distVar': 0.6421568627450981,
#    'reconstructed_morphological_distVar': 0.6372549019607843,
#    'reconstructed_featural_eu': 0.6421568627450981,
#    'reconstructed_featural': 0.6372549019607843,
#    'baseline_en': 0.5343137254901961,
#    'baseline_task_adapter': 0.6519607843137255,
#    'baseline_avg_adapter': 0.47549019607843135,
#    'baseline_closest_featural': 0.22549019607843138,
#    'no_train_gain': 0.6029411764705882,
#    'reconstructed_featural_limit': 0.6568627450980392,
#    'reconstructed_morphological_limit': 0.6372549019607843,
#    'reconstructed_syntactic_limit': 0.5980392156862745,
#    'reconstructed_featural_sr': 0.6421568627450981,
#    'reconstructed_featural_threshold': 0.6421568627450981,
#    'reconstructed_morphological_threshold': 0.6372549019607843,
#    'reconstructed_syntactic_threshold': 0.6519607843137255,
#    'finetune': 0.6225490196078431}},
#  'awa': {'Deva': {'reconstructed_featural_base': 0.8235294117647058,
#    'reconstructed_syntactic_distVar': 0.8235294117647058,
#    'reconstructed_morphological_distVar': 0.8235294117647058,
#    'reconstructed_featural_eu': 0.8235294117647058,
#    'reconstructed_featural': 0.8235294117647058,
#    'baseline_en': 0.7401960784313726,
#    'baseline_task_adapter': 0.8137254901960784,
#    'baseline_avg_adapter': 0.6519607843137255,
#    'baseline_closest_featural': 0.8137254901960784,
#    'no_train_gain': 0.8186274509803921,
#    'reconstructed_featural_limit': 0.8186274509803921,
#    'reconstructed_morphological_limit': 0.8284313725490197,
#    'reconstructed_syntactic_limit': 0.8382352941176471,
#    'reconstructed_featural_sr': 0.8235294117647058,
#    'reconstructed_featural_threshold': 0.8284313725490197,
#    'reconstructed_morphological_threshold': 0.8186274509803921,
#    'reconstructed_syntactic_threshold': 0.8284313725490197,
#    'finetune': 0.7598039215686274}},
#  'ayr': {'Latn': {'reconstructed_featural_base': 0.35784313725490197,
#    'reconstructed_syntactic_distVar': 0.35294117647058826,
#    'reconstructed_morphological_distVar': 0.35294117647058826,
#    'reconstructed_featural_eu': 0.35294117647058826,
#    'reconstructed_featural': 0.3480392156862745,
#    'baseline_en': 0.3284313725490196,
#    'baseline_task_adapter': 0.3235294117647059,
#    'baseline_avg_adapter': 0.25980392156862747,
#    'baseline_closest_featural': 0.4166666666666667,
#    'no_train_gain': 0.3627450980392157,
#    'reconstructed_featural_limit': 0.35784313725490197,
#    'reconstructed_morphological_limit': 0.37254901960784315,
#    'reconstructed_syntactic_limit': 0.36764705882352944,
#    'reconstructed_featural_sr': 0.35294117647058826,
#    'reconstructed_featural_threshold': 0.36764705882352944,
#    'reconstructed_morphological_threshold': 0.36764705882352944,
#    'reconstructed_syntactic_threshold': 0.3627450980392157,
#    'finetune': 0.2107843137254902}},
#  'azb': {'Arab': {'reconstructed_featural_base': 0.6617647058823529,
#    'reconstructed_syntactic_distVar': 0.6666666666666666,
#    'reconstructed_morphological_distVar': 0.6666666666666666,
#    'reconstructed_featural_eu': 0.6617647058823529,
#    'reconstructed_featural': 0.6666666666666666,
#    'baseline_en': 0.5049019607843137,
#    'baseline_task_adapter': 0.6666666666666666,
#    'baseline_avg_adapter': 0.4852941176470588,
#    'baseline_closest_featural': 0.45098039215686275,
#    'no_train_gain': 0.6127450980392157,
#    'reconstructed_featural_limit': 0.6421568627450981,
#    'reconstructed_morphological_limit': 0.6666666666666666,
#    'reconstructed_syntactic_limit': 0.6470588235294118,
#    'reconstructed_featural_sr': 0.6617647058823529,
#    'reconstructed_featural_threshold': 0.6568627450980392,
#    'reconstructed_morphological_threshold': 0.6666666666666666,
#    'reconstructed_syntactic_threshold': 0.6666666666666666,
#    'finetune': 0.7058823529411765}},
#  'azj': {'Latn': {'reconstructed_featural_base': 0.8627450980392157,
#    'reconstructed_syntactic_distVar': 0.8627450980392157,
#    'reconstructed_morphological_distVar': 0.8627450980392157,
#    'reconstructed_featural_eu': 0.8627450980392157,
#    'reconstructed_featural': 0.8627450980392157,
#    'baseline_en': 0.8186274509803921,
#    'baseline_task_adapter': 0.8186274509803921,
#    'baseline_avg_adapter': 0.7843137254901961,
#    'baseline_closest_featural': 0.75,
#    'no_train_gain': 0.8480392156862745,
#    'reconstructed_featural_limit': 0.8578431372549019,
#    'reconstructed_morphological_limit': 0.8578431372549019,
#    'reconstructed_syntactic_limit': 0.8578431372549019,
#    'reconstructed_featural_sr': 0.8627450980392157,
#    'reconstructed_featural_threshold': 0.8627450980392157,
#    'reconstructed_morphological_threshold': 0.8627450980392157,
#    'reconstructed_syntactic_threshold': 0.8627450980392157,
#    'finetune': 0.8578431372549019}},
#  'ban': {'Latn': {'reconstructed_featural_base': 0.7647058823529411,
#    'reconstructed_syntactic_distVar': 0.7598039215686274,
#    'reconstructed_morphological_distVar': 0.7549019607843137,
#    'reconstructed_featural_eu': 0.7549019607843137,
#    'reconstructed_featural': 0.7549019607843137,
#    'baseline_en': 0.7352941176470589,
#    'baseline_task_adapter': 0.7009803921568627,
#    'baseline_avg_adapter': 0.5735294117647058,
#    'baseline_closest_featural': 0.7598039215686274,
#    'no_train_gain': 0.7745098039215687,
#    'reconstructed_featural_limit': 0.7647058823529411,
#    'reconstructed_morphological_limit': 0.7598039215686274,
#    'reconstructed_syntactic_limit': 0.75,
#    'reconstructed_featural_sr': 0.7549019607843137,
#    'reconstructed_featural_threshold': 0.7598039215686274,
#    'reconstructed_morphological_threshold': 0.7598039215686274,
#    'reconstructed_syntactic_threshold': 0.75,
#    'finetune': 0.696078431372549}},
#  'ba': {'Cyrl': {'reconstructed_featural_base': 0.5931372549019608,
#    'reconstructed_syntactic_distVar': 0.6078431372549019,
#    'reconstructed_morphological_distVar': 0.6029411764705882,
#    'reconstructed_featural_eu': 0.6029411764705882,
#    'reconstructed_featural': 0.6078431372549019,
#    'baseline_en': 0.5196078431372549,
#    'baseline_task_adapter': 0.6225490196078431,
#    'baseline_avg_adapter': 0.5,
#    'baseline_closest_featural': 0.35294117647058826,
#    'no_train_gain': 0.5294117647058824,
#    'reconstructed_featural_limit': 0.5980392156862745,
#    'reconstructed_morphological_limit': 0.5882352941176471,
#    'reconstructed_syntactic_limit': 0.6274509803921569,
#    'reconstructed_featural_sr': 0.6029411764705882,
#    'reconstructed_featural_threshold': 0.6078431372549019,
#    'reconstructed_morphological_threshold': 0.6029411764705882,
#    'reconstructed_syntactic_threshold': 0.6078431372549019,
#    'finetune': 0.5441176470588235}},
#  'bem': {'Latn': {'reconstructed_featural_base': 0.3382352941176471,
#    'reconstructed_syntactic_distVar': 0.3480392156862745,
#    'reconstructed_morphological_distVar': 0.3480392156862745,
#    'reconstructed_featural_eu': 0.3431372549019608,
#    'reconstructed_featural': 0.3480392156862745,
#    'baseline_en': 0.29411764705882354,
#    'baseline_task_adapter': 0.3284313725490196,
#    'baseline_avg_adapter': 0.20098039215686275,
#    'baseline_closest_featural': 0.29901960784313725,
#    'no_train_gain': 0.2696078431372549,
#    'reconstructed_featural_limit': 0.3627450980392157,
#    'reconstructed_morphological_limit': 0.35294117647058826,
#    'reconstructed_syntactic_limit': 0.38235294117647056,
#    'reconstructed_featural_sr': 0.3431372549019608,
#    'reconstructed_featural_threshold': 0.35294117647058826,
#    'reconstructed_morphological_threshold': 0.35784313725490197,
#    'reconstructed_syntactic_threshold': 0.35294117647058826,
#    'finetune': 0.2696078431372549}},
#  'be': {'Cyrl': {'reconstructed_featural_base': 0.8333333333333334,
#    'reconstructed_syntactic_distVar': 0.8431372549019608,
#    'reconstructed_morphological_distVar': 0.8431372549019608,
#    'reconstructed_featural_eu': 0.8333333333333334,
#    'reconstructed_featural': 0.8431372549019608,
#    'baseline_en': 0.7401960784313726,
#    'baseline_task_adapter': 0.8235294117647058,
#    'baseline_avg_adapter': 0.7647058823529411,
#    'baseline_closest_featural': 0.7892156862745098,
#    'no_train_gain': 0.8333333333333334,
#    'reconstructed_featural_limit': 0.8480392156862745,
#    'reconstructed_morphological_limit': 0.8431372549019608,
#    'reconstructed_syntactic_limit': 0.8382352941176471,
#    'reconstructed_featural_sr': 0.8333333333333334,
#    'reconstructed_featural_threshold': 0.8529411764705882,
#    'reconstructed_morphological_threshold': 0.8529411764705882,
#    'reconstructed_syntactic_threshold': 0.8529411764705882,
#    'finetune': 0.8578431372549019}},
#  'bg': {'Cyrl': {'reconstructed_featural_base': 0.8529411764705882,
#    'reconstructed_syntactic_distVar': 0.8529411764705882,
#    'reconstructed_morphological_distVar': 0.8529411764705882,
#    'reconstructed_featural_eu': 0.8529411764705882,
#    'reconstructed_featural': 0.8529411764705882,
#    'baseline_en': 0.8186274509803921,
#    'baseline_task_adapter': 0.8676470588235294,
#    'baseline_avg_adapter': 0.8284313725490197,
#    'baseline_closest_featural': 0.8529411764705882,
#    'no_train_gain': 0.8529411764705882,
#    'reconstructed_featural_limit': 0.8676470588235294,
#    'reconstructed_morphological_limit': 0.8529411764705882,
#    'reconstructed_syntactic_limit': 0.8578431372549019,
#    'reconstructed_featural_sr': 0.8529411764705882,
#    'reconstructed_featural_threshold': 0.8529411764705882,
#    'reconstructed_morphological_threshold': 0.8529411764705882,
#    'reconstructed_syntactic_threshold': 0.8529411764705882,
#    'finetune': 0.8823529411764706}},
#  'bho': {'Deva': {'reconstructed_featural_base': 0.7843137254901961,
#    'reconstructed_syntactic_distVar': 0.7745098039215687,
#    'reconstructed_morphological_distVar': 0.7794117647058824,
#    'reconstructed_featural_eu': 0.7745098039215687,
#    'reconstructed_featural': 0.7745098039215687,
#    'baseline_en': 0.7303921568627451,
#    'baseline_task_adapter': 0.75,
#    'baseline_avg_adapter': 0.6225490196078431,
#    'baseline_closest_featural': 0.5882352941176471,
#    'no_train_gain': 0.7745098039215687,
#    'reconstructed_featural_limit': 0.7745098039215687,
#    'reconstructed_morphological_limit': 0.7794117647058824,
#    'reconstructed_syntactic_limit': 0.7941176470588235,
#    'reconstructed_featural_sr': 0.7745098039215687,
#    'reconstructed_featural_threshold': 0.7647058823529411,
#    'reconstructed_morphological_threshold': 0.7745098039215687,
#    'reconstructed_syntactic_threshold': 0.7696078431372549,
#    'finetune': 0.7156862745098039}},
#  'bjn': {'Arab': {'reconstructed_featural_base': 0.1323529411764706,
#    'reconstructed_syntactic_distVar': 0.12745098039215685,
#    'reconstructed_morphological_distVar': 0.12745098039215685,
#    'reconstructed_featural_eu': 0.1323529411764706,
#    'reconstructed_featural_limit': 0.12745098039215685,
#    'reconstructed_morphological_limit': 0.12745098039215685,
#    'reconstructed_syntactic_limit': 0.12745098039215685,
#    'reconstructed_featural_sr': 0.1323529411764706,
#    'reconstructed_featural_threshold': 0.1323529411764706,
#    'reconstructed_morphological_threshold': 0.1323529411764706,
#    'reconstructed_syntactic_threshold': 0.1323529411764706,
#    'finetune': 0.1715686274509804},
#   'Latn': {'reconstructed_featural_base': 0.7156862745098039,
#    'reconstructed_syntactic_distVar': 0.7303921568627451,
#    'reconstructed_morphological_distVar': 0.7303921568627451,
#    'reconstructed_featural_eu': 0.7205882352941176,
#    'reconstructed_featural_limit': 0.7303921568627451,
#    'reconstructed_morphological_limit': 0.7303921568627451,
#    'reconstructed_syntactic_limit': 0.7303921568627451,
#    'reconstructed_featural_sr': 0.7205882352941176,
#    'reconstructed_featural_threshold': 0.7303921568627451,
#    'reconstructed_morphological_threshold': 0.7303921568627451,
#    'reconstructed_syntactic_threshold': 0.7303921568627451,
#    'finetune': 0.6568627450980392}},
#  'bm': {'Latn': {'reconstructed_featural_base': 0.21568627450980393,
#    'reconstructed_syntactic_distVar': 0.23039215686274508,
#    'reconstructed_morphological_distVar': 0.23039215686274508,
#    'reconstructed_featural_eu': 0.22549019607843138,
#    'reconstructed_featural': 0.23039215686274508,
#    'baseline_en': 0.23529411764705882,
#    'baseline_task_adapter': 0.23039215686274508,
#    'baseline_avg_adapter': 0.1715686274509804,
#    'baseline_closest_featural': 0.20588235294117646,
#    'no_train_gain': 0.23529411764705882,
#    'reconstructed_featural_limit': 0.23039215686274508,
#    'reconstructed_morphological_limit': 0.23039215686274508,
#    'reconstructed_syntactic_limit': 0.22058823529411764,
#    'reconstructed_featural_sr': 0.22549019607843138,
#    'reconstructed_featural_threshold': 0.23039215686274508,
#    'reconstructed_morphological_threshold': 0.20588235294117646,
#    'reconstructed_syntactic_threshold': 0.23039215686274508,
#    'finetune': 0.2549019607843137}},
#  'bn': {'Beng': {'reconstructed_featural_base': 0.8235294117647058,
#    'reconstructed_syntactic_distVar': 0.8186274509803921,
#    'reconstructed_morphological_distVar': 0.8186274509803921,
#    'reconstructed_featural_eu': 0.8186274509803921,
#    'reconstructed_featural': 0.8186274509803921,
#    'baseline_en': 0.7450980392156863,
#    'baseline_task_adapter': 0.8088235294117647,
#    'baseline_avg_adapter': 0.7156862745098039,
#    'baseline_closest_featural': 0.46568627450980393,
#    'no_train_gain': 0.7892156862745098,
#    'reconstructed_featural_limit': 0.8284313725490197,
#    'reconstructed_morphological_limit': 0.8186274509803921,
#    'reconstructed_syntactic_limit': 0.8186274509803921,
#    'reconstructed_featural_sr': 0.8186274509803921,
#    'reconstructed_featural_threshold': 0.8186274509803921,
#    'reconstructed_morphological_threshold': 0.8186274509803921,
#    'reconstructed_syntactic_threshold': 0.8235294117647058,
#    'finetune': 0.7794117647058824}},
#  'bo': {'Tibt': {'reconstructed_featural_base': 0.18627450980392157,
#    'reconstructed_syntactic_distVar': 0.1715686274509804,
#    'reconstructed_morphological_distVar': 0.1715686274509804,
#    'reconstructed_featural_eu': 0.17647058823529413,
#    'reconstructed_featural': 0.1715686274509804,
#    'baseline_en': 0.13725490196078433,
#    'baseline_task_adapter': 0.1323529411764706,
#    'baseline_avg_adapter': 0.1715686274509804,
#    'baseline_closest_featural': 0.18627450980392157,
#    'no_train_gain': 0.12745098039215685,
#    'reconstructed_featural_limit': 0.19607843137254902,
#    'reconstructed_morphological_limit': 0.2107843137254902,
#    'reconstructed_syntactic_limit': 0.16176470588235295,
#    'reconstructed_featural_sr': 0.17647058823529413,
#    'reconstructed_featural_threshold': 0.1715686274509804,
#    'reconstructed_morphological_threshold': 0.19117647058823528,
#    'reconstructed_syntactic_threshold': 0.19117647058823528,
#    'finetune': 0.11764705882352941}},
#  'bs': {'Latn': {'reconstructed_featural_base': 0.8578431372549019,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8627450980392157,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural': 0.8578431372549019,
#    'baseline_en': 0.8578431372549019,
#    'baseline_task_adapter': 0.8627450980392157,
#    'baseline_avg_adapter': 0.8480392156862745,
#    'baseline_closest_featural': 0.803921568627451,
#    'no_train_gain': 0.8578431372549019,
#    'reconstructed_featural_limit': 0.8627450980392157,
#    'reconstructed_morphological_limit': 0.8627450980392157,
#    'reconstructed_syntactic_limit': 0.8627450980392157,
#    'reconstructed_featural_sr': 0.8578431372549019,
#    'reconstructed_featural_threshold': 0.8578431372549019,
#    'reconstructed_morphological_threshold': 0.8627450980392157,
#    'reconstructed_syntactic_threshold': 0.8578431372549019,
#    'finetune': 0.8872549019607843}},
#  'bug': {'Latn': {'reconstructed_featural_base': 0.5392156862745098,
#    'reconstructed_syntactic_distVar': 0.5294117647058824,
#    'reconstructed_morphological_distVar': 0.5294117647058824,
#    'reconstructed_featural_eu': 0.5294117647058824,
#    'reconstructed_featural': 0.5294117647058824,
#    'baseline_en': 0.5196078431372549,
#    'baseline_task_adapter': 0.5490196078431373,
#    'baseline_avg_adapter': 0.3872549019607843,
#    'baseline_closest_featural': 0.5686274509803921,
#    'no_train_gain': 0.5686274509803921,
#    'reconstructed_featural_limit': 0.5196078431372549,
#    'reconstructed_morphological_limit': 0.5049019607843137,
#    'reconstructed_syntactic_limit': 0.553921568627451,
#    'reconstructed_featural_sr': 0.5294117647058824,
#    'reconstructed_featural_threshold': 0.5294117647058824,
#    'reconstructed_morphological_threshold': 0.5343137254901961,
#    'reconstructed_syntactic_threshold': 0.5294117647058824,
#    'finetune': 0.46568627450980393}},
#  'ca': {'Latn': {'reconstructed_featural_base': 0.8921568627450981,
#    'reconstructed_syntactic_distVar': 0.9019607843137255,
#    'reconstructed_morphological_distVar': 0.8970588235294118,
#    'reconstructed_featural_eu': 0.8970588235294118,
#    'reconstructed_featural': 0.9019607843137255,
#    'baseline_en': 0.8627450980392157,
#    'baseline_task_adapter': 0.8970588235294118,
#    'baseline_avg_adapter': 0.8284313725490197,
#    'baseline_closest_featural': 0.8725490196078431,
#    'no_train_gain': 0.8774509803921569,
#    'reconstructed_featural_limit': 0.9068627450980392,
#    'reconstructed_morphological_limit': 0.8921568627450981,
#    'reconstructed_syntactic_limit': 0.8921568627450981,
#    'reconstructed_featural_sr': 0.8970588235294118,
#    'reconstructed_featural_threshold': 0.9019607843137255,
#    'reconstructed_morphological_threshold': 0.8823529411764706,
#    'reconstructed_syntactic_threshold': 0.8970588235294118,
#    'finetune': 0.8774509803921569}},
#  'ceb': {'Latn': {'reconstructed_featural_base': 0.7107843137254902,
#    'reconstructed_syntactic_distVar': 0.7205882352941176,
#    'reconstructed_morphological_distVar': 0.7156862745098039,
#    'reconstructed_featural_eu': 0.7058823529411765,
#    'reconstructed_featural': 0.7156862745098039,
#    'baseline_en': 0.6911764705882353,
#    'baseline_task_adapter': 0.7352941176470589,
#    'baseline_avg_adapter': 0.5686274509803921,
#    'baseline_closest_featural': 0.6176470588235294,
#    'no_train_gain': 0.7107843137254902,
#    'reconstructed_featural_limit': 0.7107843137254902,
#    'reconstructed_morphological_limit': 0.7009803921568627,
#    'reconstructed_syntactic_limit': 0.7205882352941176,
#    'reconstructed_featural_sr': 0.7107843137254902,
#    'reconstructed_featural_threshold': 0.7205882352941176,
#    'reconstructed_morphological_threshold': 0.7107843137254902,
#    'reconstructed_syntactic_threshold': 0.7205882352941176,
#    'finetune': 0.6764705882352942}},
#  'cjk': {'Latn': {'reconstructed_featural_base': 0.29411764705882354,
#    'reconstructed_syntactic_distVar': 0.28921568627450983,
#    'reconstructed_morphological_distVar': 0.28921568627450983,
#    'reconstructed_featural_eu': 0.29901960784313725,
#    'reconstructed_featural_limit': 0.28921568627450983,
#    'reconstructed_morphological_limit': 0.28921568627450983,
#    'reconstructed_syntactic_limit': 0.28921568627450983,
#    'reconstructed_featural_sr': 0.29901960784313725,
#    'reconstructed_featural_threshold': 0.28921568627450983,
#    'reconstructed_morphological_threshold': 0.28921568627450983,
#    'reconstructed_syntactic_threshold': 0.28921568627450983,
#    'finetune': 0.30392156862745096}},
#  'ckb': {'Arab': {'reconstructed_featural_base': 0.20098039215686275,
#    'reconstructed_syntactic_distVar': 0.19607843137254902,
#    'reconstructed_morphological_distVar': 0.19607843137254902,
#    'reconstructed_featural_eu': 0.20098039215686275,
#    'reconstructed_featural': 0.19607843137254902,
#    'baseline_en': 0.12254901960784313,
#    'baseline_task_adapter': 0.1715686274509804,
#    'baseline_avg_adapter': 0.22058823529411764,
#    'baseline_closest_featural': 0.25,
#    'no_train_gain': 0.17647058823529413,
#    'reconstructed_featural_limit': 0.18137254901960784,
#    'reconstructed_morphological_limit': 0.17647058823529413,
#    'reconstructed_syntactic_limit': 0.18627450980392157,
#    'reconstructed_featural_sr': 0.20098039215686275,
#    'reconstructed_featural_threshold': 0.19607843137254902,
#    'reconstructed_morphological_threshold': 0.18137254901960784,
#    'reconstructed_syntactic_threshold': 0.18627450980392157,
#    'finetune': 0.27450980392156865}},
#  'crh': {'Latn': {'reconstructed_featural_base': 0.75,
#    'reconstructed_syntactic_distVar': 0.7352941176470589,
#    'reconstructed_morphological_distVar': 0.7401960784313726,
#    'reconstructed_featural_eu': 0.7450980392156863,
#    'reconstructed_featural': 0.7352941176470589,
#    'baseline_en': 0.7107843137254902,
#    'baseline_task_adapter': 0.696078431372549,
#    'baseline_avg_adapter': 0.6176470588235294,
#    'baseline_closest_featural': 0.6568627450980392,
#    'no_train_gain': 0.7450980392156863,
#    'reconstructed_featural_limit': 0.7401960784313726,
#    'reconstructed_morphological_limit': 0.7549019607843137,
#    'reconstructed_syntactic_limit': 0.7303921568627451,
#    'reconstructed_featural_sr': 0.7450980392156863,
#    'reconstructed_featural_threshold': 0.7401960784313726,
#    'reconstructed_morphological_threshold': 0.7549019607843137,
#    'reconstructed_syntactic_threshold': 0.7450980392156863,
#    'finetune': 0.7156862745098039}},
#  'cs': {'Latn': {'reconstructed_featural_base': 0.8921568627450981,
#    'reconstructed_syntactic_distVar': 0.8970588235294118,
#    'reconstructed_morphological_distVar': 0.9019607843137255,
#    'reconstructed_featural_eu': 0.8970588235294118,
#    'reconstructed_featural': 0.8970588235294118,
#    'baseline_en': 0.8627450980392157,
#    'baseline_task_adapter': 0.8774509803921569,
#    'baseline_avg_adapter': 0.8529411764705882,
#    'baseline_closest_featural': 0.8627450980392157,
#    'no_train_gain': 0.8823529411764706,
#    'reconstructed_featural_limit': 0.8872549019607843,
#    'reconstructed_morphological_limit': 0.8921568627450981,
#    'reconstructed_syntactic_limit': 0.8921568627450981,
#    'reconstructed_featural_sr': 0.8970588235294118,
#    'reconstructed_featural_threshold': 0.9019607843137255,
#    'reconstructed_morphological_threshold': 0.9019607843137255,
#    'reconstructed_syntactic_threshold': 0.8970588235294118,
#    'finetune': 0.9019607843137255}},
#  'cy': {'Latn': {'reconstructed_featural_base': 0.75,
#    'reconstructed_syntactic_distVar': 0.7745098039215687,
#    'reconstructed_morphological_distVar': 0.7745098039215687,
#    'reconstructed_featural_eu': 0.7696078431372549,
#    'reconstructed_featural': 0.7745098039215687,
#    'baseline_en': 0.7450980392156863,
#    'baseline_task_adapter': 0.8088235294117647,
#    'baseline_avg_adapter': 0.6470588235294118,
#    'baseline_closest_featural': 0.6176470588235294,
#    'no_train_gain': 0.7647058823529411,
#    'reconstructed_featural_limit': 0.7794117647058824,
#    'reconstructed_morphological_limit': 0.7647058823529411,
#    'reconstructed_syntactic_limit': 0.7794117647058824,
#    'reconstructed_featural_sr': 0.7745098039215687,
#    'reconstructed_featural_threshold': 0.7794117647058824,
#    'reconstructed_morphological_threshold': 0.7696078431372549,
#    'reconstructed_syntactic_threshold': 0.7745098039215687,
#    'finetune': 0.7647058823529411}},
#  'da': {'Latn': {'reconstructed_featural_base': 0.8872549019607843,
#    'reconstructed_syntactic_distVar': 0.8872549019607843,
#    'reconstructed_morphological_distVar': 0.8872549019607843,
#    'reconstructed_featural_eu': 0.8872549019607843,
#    'reconstructed_featural': 0.8872549019607843,
#    'baseline_en': 0.8970588235294118,
#    'baseline_task_adapter': 0.8725490196078431,
#    'baseline_avg_adapter': 0.8382352941176471,
#    'baseline_closest_featural': 0.8235294117647058,
#    'no_train_gain': 0.8872549019607843,
#    'reconstructed_featural_limit': 0.8774509803921569,
#    'reconstructed_morphological_limit': 0.8872549019607843,
#    'reconstructed_syntactic_limit': 0.8774509803921569,
#    'reconstructed_featural_sr': 0.8872549019607843,
#    'reconstructed_featural_threshold': 0.8823529411764706,
#    'reconstructed_morphological_threshold': 0.8872549019607843,
#    'reconstructed_syntactic_threshold': 0.8823529411764706,
#    'finetune': 0.8725490196078431}},
#  'de': {'Latn': {'reconstructed_featural_base': 0.8872549019607843,
#    'reconstructed_syntactic_distVar': 0.8872549019607843,
#    'reconstructed_morphological_distVar': 0.8872549019607843,
#    'reconstructed_featural_eu': 0.8872549019607843,
#    'reconstructed_featural': 0.8872549019607843,
#    'baseline_en': 0.8676470588235294,
#    'baseline_task_adapter': 0.8872549019607843,
#    'baseline_avg_adapter': 0.8235294117647058,
#    'baseline_closest_featural': 0.8725490196078431,
#    'no_train_gain': 0.8872549019607843,
#    'reconstructed_featural_limit': 0.8872549019607843,
#    'reconstructed_morphological_limit': 0.8872549019607843,
#    'reconstructed_syntactic_limit': 0.8872549019607843,
#    'reconstructed_featural_sr': 0.8872549019607843,
#    'reconstructed_featural_threshold': 0.8872549019607843,
#    'reconstructed_morphological_threshold': 0.8872549019607843,
#    'reconstructed_syntactic_threshold': 0.8872549019607843,
#    'finetune': 0.8970588235294118}},
#  'dik': {'Latn': {'reconstructed_featural_base': 0.3480392156862745,
#    'reconstructed_syntactic_distVar': 0.3431372549019608,
#    'reconstructed_morphological_distVar': 0.3431372549019608,
#    'reconstructed_featural_eu': 0.3431372549019608,
#    'reconstructed_featural_limit': 0.3431372549019608,
#    'reconstructed_morphological_limit': 0.3431372549019608,
#    'reconstructed_syntactic_limit': 0.3431372549019608,
#    'reconstructed_featural_sr': 0.3431372549019608,
#    'reconstructed_featural_threshold': 0.3431372549019608,
#    'reconstructed_morphological_threshold': 0.3431372549019608,
#    'reconstructed_syntactic_threshold': 0.3431372549019608,
#    'finetune': 0.3088235294117647}},
#  'dyu': {'Latn': {'reconstructed_featural_base': 0.29901960784313725,
#    'reconstructed_syntactic_distVar': 0.30392156862745096,
#    'reconstructed_morphological_distVar': 0.29901960784313725,
#    'reconstructed_featural_eu': 0.29901960784313725,
#    'reconstructed_featural': 0.29901960784313725,
#    'baseline_en': 0.29411764705882354,
#    'baseline_task_adapter': 0.3137254901960784,
#    'baseline_avg_adapter': 0.21568627450980393,
#    'baseline_closest_featural': 0.24509803921568626,
#    'no_train_gain': 0.28921568627450983,
#    'reconstructed_featural_limit': 0.30392156862745096,
#    'reconstructed_morphological_limit': 0.29901960784313725,
#    'reconstructed_syntactic_limit': 0.3137254901960784,
#    'reconstructed_featural_sr': 0.29901960784313725,
#    'reconstructed_featural_threshold': 0.3088235294117647,
#    'reconstructed_morphological_threshold': 0.3137254901960784,
#    'reconstructed_syntactic_threshold': 0.3088235294117647,
#    'finetune': 0.28431372549019607}},
#  'dz': {'Tibt': {'reconstructed_featural_base': 0.24019607843137256,
#    'reconstructed_syntactic_distVar': 0.23529411764705882,
#    'reconstructed_morphological_distVar': 0.23529411764705882,
#    'reconstructed_featural_eu': 0.24019607843137256,
#    'reconstructed_featural': 0.23529411764705882,
#    'baseline_en': 0.09803921568627451,
#    'baseline_task_adapter': 0.1715686274509804,
#    'baseline_avg_adapter': 0.23529411764705882,
#    'baseline_closest_featural': 0.25,
#    'no_train_gain': 0.16666666666666666,
#    'reconstructed_featural_limit': 0.21568627450980393,
#    'reconstructed_morphological_limit': 0.23529411764705882,
#    'reconstructed_syntactic_limit': 0.24509803921568626,
#    'reconstructed_featural_sr': 0.23529411764705882,
#    'reconstructed_featural_threshold': 0.23529411764705882,
#    'reconstructed_morphological_threshold': 0.24509803921568626,
#    'reconstructed_syntactic_threshold': 0.21568627450980393,
#    'finetune': 0.11764705882352941}},
#  'ee': {'Latn': {'reconstructed_featural_base': 0.22058823529411764,
#    'reconstructed_syntactic_distVar': 0.23039215686274508,
#    'reconstructed_morphological_distVar': 0.22058823529411764,
#    'reconstructed_featural_eu': 0.22058823529411764,
#    'reconstructed_featural': 0.23039215686274508,
#    'baseline_en': 0.22549019607843138,
#    'baseline_task_adapter': 0.24019607843137256,
#    'baseline_avg_adapter': 0.23039215686274508,
#    'baseline_closest_featural': 0.15196078431372548,
#    'no_train_gain': 0.21568627450980393,
#    'reconstructed_featural_limit': 0.24019607843137256,
#    'reconstructed_morphological_limit': 0.23039215686274508,
#    'reconstructed_syntactic_limit': 0.24019607843137256,
#    'reconstructed_featural_sr': 0.22549019607843138,
#    'reconstructed_featural_threshold': 0.22058823529411764,
#    'reconstructed_morphological_threshold': 0.22549019607843138,
#    'reconstructed_syntactic_threshold': 0.22549019607843138,
#    'finetune': 0.25980392156862747}},
#  'el': {'Grek': {'reconstructed_featural_base': 0.8333333333333334,
#    'reconstructed_syntactic_distVar': 0.8333333333333334,
#    'reconstructed_morphological_distVar': 0.8333333333333334,
#    'reconstructed_featural_eu': 0.8333333333333334,
#    'reconstructed_featural': 0.8333333333333334,
#    'baseline_en': 0.8088235294117647,
#    'baseline_task_adapter': 0.8137254901960784,
#    'baseline_avg_adapter': 0.7794117647058824,
#    'baseline_closest_featural': 0.8480392156862745,
#    'no_train_gain': 0.8235294117647058,
#    'reconstructed_featural_limit': 0.8333333333333334,
#    'reconstructed_morphological_limit': 0.8382352941176471,
#    'reconstructed_syntactic_limit': 0.8333333333333334,
#    'reconstructed_featural_sr': 0.8333333333333334,
#    'reconstructed_featural_threshold': 0.8333333333333334,
#    'reconstructed_morphological_threshold': 0.8333333333333334,
#    'reconstructed_syntactic_threshold': 0.8333333333333334,
#    'finetune': 0.8480392156862745}},
#  'en': {'Latn': {'reconstructed_featural_base': 0.9068627450980392,
#    'reconstructed_syntactic_distVar': 0.9068627450980392,
#    'reconstructed_morphological_distVar': 0.9068627450980392,
#    'reconstructed_featural_eu': 0.9019607843137255,
#    'reconstructed_featural': 0.9068627450980392,
#    'baseline_en': 0.9166666666666666,
#    'baseline_task_adapter': 0.8823529411764706,
#    'baseline_avg_adapter': 0.8480392156862745,
#    'baseline_closest_featural': 0.9166666666666666,
#    'no_train_gain': 0.8921568627450981,
#    'reconstructed_featural_limit': 0.9019607843137255,
#    'reconstructed_morphological_limit': 0.9068627450980392,
#    'reconstructed_syntactic_limit': 0.9019607843137255,
#    'reconstructed_featural_sr': 0.9068627450980392,
#    'reconstructed_featural_threshold': 0.9068627450980392,
#    'reconstructed_morphological_threshold': 0.9068627450980392,
#    'reconstructed_syntactic_threshold': 0.9068627450980392,
#    'finetune': 0.9019607843137255}},
#  'eo': {'Latn': {'reconstructed_featural_base': 0.8333333333333334,
#    'reconstructed_syntactic_distVar': 0.8529411764705882,
#    'reconstructed_morphological_distVar': 0.8529411764705882,
#    'reconstructed_featural_eu': 0.8431372549019608,
#    'reconstructed_featural': 0.8529411764705882,
#    'baseline_en': 0.8186274509803921,
#    'baseline_task_adapter': 0.8382352941176471,
#    'baseline_avg_adapter': 0.7941176470588235,
#    'baseline_closest_featural': 0.5686274509803921,
#    'no_train_gain': 0.8235294117647058,
#    'reconstructed_featural_limit': 0.8284313725490197,
#    'reconstructed_morphological_limit': 0.8529411764705882,
#    'reconstructed_syntactic_limit': 0.8333333333333334,
#    'reconstructed_featural_sr': 0.8431372549019608,
#    'reconstructed_featural_threshold': 0.8529411764705882,
#    'reconstructed_morphological_threshold': 0.8529411764705882,
#    'reconstructed_syntactic_threshold': 0.8578431372549019,
#    'finetune': 0.8480392156862745}},
#  'es': {'Latn': {'reconstructed_featural_base': 0.8725490196078431,
#    'reconstructed_syntactic_distVar': 0.8774509803921569,
#    'reconstructed_morphological_distVar': 0.8725490196078431,
#    'reconstructed_featural_eu': 0.8725490196078431,
#    'reconstructed_featural': 0.8774509803921569,
#    'baseline_en': 0.8872549019607843,
#    'baseline_task_adapter': 0.8676470588235294,
#    'baseline_avg_adapter': 0.8382352941176471,
#    'baseline_closest_featural': 0.8823529411764706,
#    'no_train_gain': 0.8774509803921569,
#    'reconstructed_featural_limit': 0.8774509803921569,
#    'reconstructed_morphological_limit': 0.8725490196078431,
#    'reconstructed_syntactic_limit': 0.8823529411764706,
#    'reconstructed_featural_sr': 0.8725490196078431,
#    'reconstructed_featural_threshold': 0.8774509803921569,
#    'reconstructed_morphological_threshold': 0.8725490196078431,
#    'reconstructed_syntactic_threshold': 0.8774509803921569,
#    'finetune': 0.8823529411764706}},
#  'et': {'Latn': {'reconstructed_featural_base': 0.8529411764705882,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
# ...
#    'finetune': 0.25}},
#  'ug': {'Arab': {'reconstructed_featural_base': 0.7450980392156863,
#    'reconstructed_syntactic_distVar': 0.7549019607843137,
#    'reconstructed_morphological_distVar': 0.7401960784313726,
#    'reconstructed_featural_eu': 0.75,
#    'reconstructed_featural': 0.75,
#    'baseline_en': 0.46078431372549017,
#    'baseline_task_adapter': 0.7352941176470589,
#    'baseline_avg_adapter': 0.6225490196078431,
#    'baseline_closest_featural': 0.5588235294117647,
#    'no_train_gain': 0.6617647058823529,
#    'reconstructed_featural_limit': 0.75,
#    'reconstructed_morphological_limit': 0.7401960784313726,
#    'reconstructed_syntactic_limit': 0.7549019607843137,
#    'reconstructed_featural_sr': 0.75,
#    'reconstructed_featural_threshold': 0.75,
#    'reconstructed_morphological_threshold': 0.7450980392156863,
#    'reconstructed_syntactic_threshold': 0.75,
#    'finetune': 0.7450980392156863}},
#  'uk': {'Cyrl': {'reconstructed_featural_base': 0.8774509803921569,
#    'reconstructed_syntactic_distVar': 0.8774509803921569,
#    'reconstructed_morphological_distVar': 0.8774509803921569,
#    'reconstructed_featural_eu': 0.8774509803921569,
#    'reconstructed_featural': 0.8725490196078431,
#    'baseline_en': 0.8578431372549019,
#    'baseline_task_adapter': 0.8627450980392157,
#    'baseline_avg_adapter': 0.8480392156862745,
#    'baseline_closest_featural': 0.8333333333333334,
#    'no_train_gain': 0.8578431372549019,
#    'reconstructed_featural_limit': 0.8774509803921569,
#    'reconstructed_morphological_limit': 0.8725490196078431,
#    'reconstructed_syntactic_limit': 0.8725490196078431,
#    'reconstructed_featural_sr': 0.8774509803921569,
#    'reconstructed_featural_threshold': 0.8725490196078431,
#    'reconstructed_morphological_threshold': 0.8823529411764706,
#    'reconstructed_syntactic_threshold': 0.8725490196078431,
#    'finetune': 0.8774509803921569}},
#  'umb': {'Latn': {'reconstructed_featural_base': 0.27450980392156865,
#    'reconstructed_syntactic_distVar': 0.2696078431372549,
#    'reconstructed_morphological_distVar': 0.2696078431372549,
#    'reconstructed_featural_eu': 0.27941176470588236,
#    'reconstructed_featural': 0.2696078431372549,
#    'baseline_en': 0.25980392156862747,
#    'baseline_task_adapter': 0.2647058823529412,
#    'baseline_avg_adapter': 0.2107843137254902,
#    'baseline_closest_featural': 0.29411764705882354,
#    'no_train_gain': 0.25980392156862747,
#    'reconstructed_featural_limit': 0.29411764705882354,
#    'reconstructed_morphological_limit': 0.2696078431372549,
#    'reconstructed_syntactic_limit': 0.25,
#    'reconstructed_featural_sr': 0.27941176470588236,
#    'reconstructed_featural_threshold': 0.2696078431372549,
#    'reconstructed_morphological_threshold': 0.2549019607843137,
#    'reconstructed_syntactic_threshold': 0.27450980392156865,
#    'finetune': 0.2549019607843137}},
#  'ur': {'Arab': {'reconstructed_featural_base': 0.8382352941176471,
#    'reconstructed_syntactic_distVar': 0.8431372549019608,
#    'reconstructed_morphological_distVar': 0.8382352941176471,
#    'reconstructed_featural_eu': 0.8382352941176471,
#    'reconstructed_featural': 0.8431372549019608,
#    'baseline_en': 0.6911764705882353,
#    'baseline_task_adapter': 0.8186274509803921,
#    'baseline_avg_adapter': 0.7598039215686274,
#    'baseline_closest_featural': 0.5,
#    'no_train_gain': 0.7941176470588235,
#    'reconstructed_featural_limit': 0.8382352941176471,
#    'reconstructed_morphological_limit': 0.8382352941176471,
#    'reconstructed_syntactic_limit': 0.8284313725490197,
#    'reconstructed_featural_sr': 0.8382352941176471,
#    'reconstructed_featural_threshold': 0.8431372549019608,
#    'reconstructed_morphological_threshold': 0.8382352941176471,
#    'reconstructed_syntactic_threshold': 0.8431372549019608,
#    'finetune': 0.7843137254901961}},
#  'uzn': {'Latn': {'reconstructed_featural_base': 0.7941176470588235,
#    'reconstructed_syntactic_distVar': 0.803921568627451,
#    'reconstructed_morphological_distVar': 0.803921568627451,
#    'reconstructed_featural_eu': 0.7990196078431373,
#    'reconstructed_featural': 0.803921568627451,
#    'baseline_en': 0.7303921568627451,
#    'baseline_task_adapter': 0.7843137254901961,
#    'baseline_avg_adapter': 0.696078431372549,
#    'baseline_closest_featural': 0.6911764705882353,
#    'no_train_gain': 0.7843137254901961,
#    'reconstructed_featural_limit': 0.7990196078431373,
#    'reconstructed_morphological_limit': 0.7990196078431373,
#    'reconstructed_syntactic_limit': 0.7892156862745098,
#    'reconstructed_featural_sr': 0.803921568627451,
#    'reconstructed_featural_threshold': 0.803921568627451,
#    'reconstructed_morphological_threshold': 0.7941176470588235,
#    'reconstructed_syntactic_threshold': 0.8088235294117647,
#    'finetune': 0.803921568627451}},
#  'vec': {'Latn': {'reconstructed_featural_base': 0.7647058823529411,
#    'reconstructed_syntactic_distVar': 0.7598039215686274,
#    'reconstructed_morphological_distVar': 0.7598039215686274,
#    'reconstructed_featural_eu': 0.7598039215686274,
#    'reconstructed_featural_limit': 0.7598039215686274,
#    'reconstructed_morphological_limit': 0.7598039215686274,
#    'reconstructed_syntactic_limit': 0.7598039215686274,
#    'reconstructed_featural_sr': 0.7598039215686274,
#    'reconstructed_featural_threshold': 0.7598039215686274,
#    'reconstructed_morphological_threshold': 0.7598039215686274,
#    'reconstructed_syntactic_threshold': 0.7598039215686274,
#    'finetune': 0.7058823529411765}},
#  'vi': {'Latn': {'reconstructed_featural_base': 0.9019607843137255,
#    'reconstructed_syntactic_distVar': 0.8970588235294118,
#    'reconstructed_morphological_distVar': 0.8970588235294118,
#    'reconstructed_featural_eu': 0.8970588235294118,
#    'reconstructed_featural': 0.8970588235294118,
#    'baseline_en': 0.8774509803921569,
#    'baseline_task_adapter': 0.8970588235294118,
#    'baseline_avg_adapter': 0.8480392156862745,
#    'baseline_closest_featural': 0.8970588235294118,
#    'no_train_gain': 0.8970588235294118,
#    'reconstructed_featural_limit': 0.8921568627450981,
#    'reconstructed_morphological_limit': 0.8970588235294118,
#    'reconstructed_syntactic_limit': 0.8921568627450981,
#    'reconstructed_featural_sr': 0.8970588235294118,
#    'reconstructed_featural_threshold': 0.8970588235294118,
#    'reconstructed_morphological_threshold': 0.9019607843137255,
#    'reconstructed_syntactic_threshold': 0.8921568627450981,
#    'finetune': 0.8872549019607843}},
#  'war': {'Latn': {'reconstructed_featural_base': 0.7107843137254902,
#    'reconstructed_syntactic_distVar': 0.7058823529411765,
#    'reconstructed_morphological_distVar': 0.7058823529411765,
#    'reconstructed_featural_eu': 0.7107843137254902,
#    'reconstructed_featural': 0.7058823529411765,
#    'baseline_en': 0.6617647058823529,
#    'baseline_task_adapter': 0.7009803921568627,
#    'baseline_avg_adapter': 0.5343137254901961,
#    'baseline_closest_featural': 0.6029411764705882,
#    'no_train_gain': 0.6862745098039216,
#    'reconstructed_featural_limit': 0.6764705882352942,
#    'reconstructed_morphological_limit': 0.6617647058823529,
#    'reconstructed_syntactic_limit': 0.6862745098039216,
#    'reconstructed_featural_sr': 0.7107843137254902,
#    'reconstructed_featural_threshold': 0.6911764705882353,
#    'reconstructed_morphological_threshold': 0.6862745098039216,
#    'reconstructed_syntactic_threshold': 0.6862745098039216,
#    'finetune': 0.6029411764705882}},
#  'wo': {'Latn': {'reconstructed_featural_base': 0.37254901960784315,
#    'reconstructed_syntactic_distVar': 0.37254901960784315,
#    'reconstructed_morphological_distVar': 0.36764705882352944,
#    'reconstructed_featural_eu': 0.36764705882352944,
#    'reconstructed_featural': 0.37254901960784315,
#    'baseline_en': 0.39215686274509803,
#    'baseline_task_adapter': 0.35294117647058826,
#    'baseline_avg_adapter': 0.2696078431372549,
#    'baseline_closest_featural': 0.27941176470588236,
#    'no_train_gain': 0.3431372549019608,
#    'reconstructed_featural_limit': 0.3333333333333333,
#    'reconstructed_morphological_limit': 0.3480392156862745,
#    'reconstructed_syntactic_limit': 0.3627450980392157,
#    'reconstructed_featural_sr': 0.36764705882352944,
#    'reconstructed_featural_threshold': 0.37254901960784315,
#    'reconstructed_morphological_threshold': 0.3382352941176471,
#    'reconstructed_syntactic_threshold': 0.35294117647058826,
#    'finetune': 0.3235294117647059}},
#  'xh': {'Latn': {'reconstructed_featural_base': 0.46568627450980393,
#    'reconstructed_syntactic_distVar': 0.46078431372549017,
#    'reconstructed_morphological_distVar': 0.46078431372549017,
#    'reconstructed_featural_eu': 0.47058823529411764,
#    'reconstructed_featural': 0.46078431372549017,
#    'baseline_en': 0.43137254901960786,
#    'baseline_task_adapter': 0.44607843137254904,
#    'baseline_avg_adapter': 0.3627450980392157,
#    'baseline_closest_featural': 0.3627450980392157,
#    'no_train_gain': 0.46078431372549017,
#    'reconstructed_featural_limit': 0.46568627450980393,
#    'reconstructed_morphological_limit': 0.4411764705882353,
#    'reconstructed_syntactic_limit': 0.4411764705882353,
#    'reconstructed_featural_sr': 0.46078431372549017,
#    'reconstructed_featural_threshold': 0.46078431372549017,
#    'reconstructed_morphological_threshold': 0.47058823529411764,
#    'reconstructed_syntactic_threshold': 0.46078431372549017,
#    'finetune': 0.4264705882352941}},
#  'ydd': {'Hebr': {'reconstructed_featural_base': 0.4803921568627451,
#    'reconstructed_syntactic_distVar': 0.4852941176470588,
#    'reconstructed_morphological_distVar': 0.4852941176470588,
#    'reconstructed_featural_eu': 0.4852941176470588,
#    'reconstructed_featural': 0.4852941176470588,
#    'baseline_en': 0.3627450980392157,
#    'baseline_task_adapter': 0.4411764705882353,
#    'baseline_avg_adapter': 0.3088235294117647,
#    'baseline_closest_featural': 0.2696078431372549,
#    'no_train_gain': 0.46078431372549017,
#    'reconstructed_featural_limit': 0.45098039215686275,
#    'reconstructed_morphological_limit': 0.4852941176470588,
#    'reconstructed_syntactic_limit': 0.47058823529411764,
#    'reconstructed_featural_sr': 0.4803921568627451,
#    'reconstructed_featural_threshold': 0.4852941176470588,
#    'reconstructed_morphological_threshold': 0.4852941176470588,
#    'reconstructed_syntactic_threshold': 0.4852941176470588,
#    'finetune': 0.46078431372549017}},
#  'yo': {'Latn': {'reconstructed_featural_base': 0.2647058823529412,
#    'reconstructed_syntactic_distVar': 0.2549019607843137,
#    'reconstructed_morphological_distVar': 0.2647058823529412,
#    'reconstructed_featural_eu': 0.2696078431372549,
#    'reconstructed_featural': 0.2647058823529412,
#    'baseline_en': 0.23039215686274508,
#    'baseline_task_adapter': 0.2696078431372549,
#    'baseline_avg_adapter': 0.22549019607843138,
#    'baseline_closest_featural': 0.18137254901960784,
#    'no_train_gain': 0.2107843137254902,
#    'reconstructed_featural_limit': 0.25980392156862747,
#    'reconstructed_morphological_limit': 0.2647058823529412,
#    'reconstructed_syntactic_limit': 0.25980392156862747,
#    'reconstructed_featural_sr': 0.2696078431372549,
#    'reconstructed_featural_threshold': 0.25980392156862747,
#    'reconstructed_morphological_threshold': 0.2647058823529412,
#    'reconstructed_syntactic_threshold': 0.2549019607843137,
#    'finetune': 0.24509803921568626}},
#  'yue': {'Hant': {'reconstructed_featural_base': 0.8578431372549019,
#    'reconstructed_syntactic_distVar': 0.8578431372549019,
#    'reconstructed_morphological_distVar': 0.8578431372549019,
#    'reconstructed_featural_eu': 0.8578431372549019,
#    'reconstructed_featural': 0.8578431372549019,
#    'baseline_en': 0.8333333333333334,
#    'baseline_task_adapter': 0.8480392156862745,
#    'baseline_avg_adapter': 0.8186274509803921,
#    'baseline_closest_featural': 0.8676470588235294,
#    'no_train_gain': 0.8823529411764706,
#    'reconstructed_featural_limit': 0.8627450980392157,
#    'reconstructed_morphological_limit': 0.8627450980392157,
#    'reconstructed_syntactic_limit': 0.8725490196078431,
#    'reconstructed_featural_sr': 0.8578431372549019,
#    'reconstructed_featural_threshold': 0.8578431372549019,
#    'reconstructed_morphological_threshold': 0.8627450980392157,
#    'reconstructed_syntactic_threshold': 0.8578431372549019,
#    'finetune': 0.8725490196078431}},
#  'zh': {'Hans': {'reconstructed_featural_base': 0.8823529411764706,
#    'reconstructed_syntactic_distVar': 0.8823529411764706,
#    'reconstructed_morphological_distVar': 0.8823529411764706,
#    'reconstructed_featural_eu': 0.8823529411764706,
#    'reconstructed_featural': 0.8774509803921569,
#    'baseline_en': 0.8627450980392157,
#    'baseline_task_adapter': 0.8774509803921569,
#    'baseline_avg_adapter': 0.8431372549019608,
#    'baseline_closest_featural': 0.8872549019607843,
#    'no_train_gain': 0.8872549019607843,
#    'reconstructed_featural_limit': 0.8823529411764706,
#    'reconstructed_morphological_limit': 0.8872549019607843,
#    'reconstructed_syntactic_limit': 0.8774509803921569,
#    'reconstructed_featural_sr': 0.8774509803921569,
#    'reconstructed_featural_threshold': 0.8774509803921569,
#    'reconstructed_morphological_threshold': 0.8872549019607843,
#    'reconstructed_syntactic_threshold': 0.8725490196078431,
#    'finetune': 0.8823529411764706},
#   'Hant': {'reconstructed_featural_base': 0.8921568627450981,
#    'reconstructed_syntactic_distVar': 0.8921568627450981,
#    'reconstructed_morphological_distVar': 0.8921568627450981,
#    'reconstructed_featural_eu': 0.8921568627450981,
#    'reconstructed_featural': 0.8921568627450981,
#    'baseline_en': 0.8823529411764706,
#    'baseline_task_adapter': 0.8823529411764706,
#    'baseline_avg_adapter': 0.8382352941176471,
#    'baseline_closest_featural': 0.8774509803921569,
#    'no_train_gain': 0.8725490196078431,
#    'reconstructed_featural_limit': 0.8872549019607843,
#    'reconstructed_morphological_limit': 0.8970588235294118,
#    'reconstructed_syntactic_limit': 0.8872549019607843,
#    'reconstructed_featural_sr': 0.8921568627450981,
#    'reconstructed_featural_threshold': 0.8921568627450981,
#    'reconstructed_morphological_threshold': 0.8970588235294118,
#    'reconstructed_syntactic_threshold': 0.8921568627450981,
#    'finetune': 0.8823529411764706}},
#  'zsm': {'Latn': {'reconstructed_featural_base': 0.8921568627450981,
#    'reconstructed_syntactic_distVar': 0.9117647058823529,
#    'reconstructed_morphological_distVar': 0.9019607843137255,
#    'reconstructed_featural_eu': 0.8921568627450981,
#    'reconstructed_featural': 0.9019607843137255,
#    'baseline_en': 0.8627450980392157,
#    'baseline_task_adapter': 0.9019607843137255,
#    'baseline_avg_adapter': 0.8578431372549019,
#    'baseline_closest_featural': 0.8970588235294118,
#    'no_train_gain': 0.8872549019607843,
#    'reconstructed_featural_limit': 0.9019607843137255,
#    'reconstructed_morphological_limit': 0.8676470588235294,
#    'reconstructed_syntactic_limit': 0.9068627450980392,
#    'reconstructed_featural_sr': 0.8921568627450981,
#    'reconstructed_featural_threshold': 0.9117647058823529,
#    'reconstructed_morphological_threshold': 0.8921568627450981,
#    'reconstructed_syntactic_threshold': 0.9019607843137255,
#    'finetune': 0.8725490196078431}},
#  'zu': {'Latn': {'reconstructed_featural_base': 0.4362745098039216,
#    'reconstructed_syntactic_distVar': 0.4264705882352941,
#    'reconstructed_morphological_distVar': 0.43137254901960786,
#    'reconstructed_featural_eu': 0.4264705882352941,
#    'reconstructed_featural': 0.4264705882352941,
#    'baseline_en': 0.45098039215686275,
#    'baseline_task_adapter': 0.37254901960784315,
#    'baseline_avg_adapter': 0.3088235294117647,
#    'baseline_closest_featural': 0.3235294117647059,
#    'no_train_gain': 0.4411764705882353,
#    'reconstructed_featural_limit': 0.4264705882352941,
#    'reconstructed_morphological_limit': 0.4117647058823529,
#    'reconstructed_syntactic_limit': 0.4117647058823529,
#    'reconstructed_featural_sr': 0.4264705882352941,
#    'reconstructed_featural_threshold': 0.43137254901960786,
#    'reconstructed_morphological_threshold': 0.4362745098039216,
#    'reconstructed_syntactic_threshold': 0.4215686274509804,
#    'finetune': 0.4068627450980392}}}

# %%
"_".join(["One element"])
# Out:
# 'One element'
