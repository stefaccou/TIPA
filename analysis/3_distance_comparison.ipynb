# %%
import os
import json
import math
import numpy as np
import scipy.stats as stats

# From huggingface api, with our trained adapters (eu, sr)
existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
# scraped from cc-100 website
xlm_included_langs = [
    "af",
    "am",
    "ar",
    "as",
    "az",
    "be",
    "bg",
    "bn",
    "br",
    "bs",
    "ca",
    "cs",
    "cy",
    "da",
    "de",
    "el",
    "en",
    "eo",
    "es",
    "et",
    "eu",
    "fa",
    "ff",
    "fi",
    "fr",
    "fy",
    "ga",
    "gd",
    "gl",
    "gn",
    "gu",
    "ha",
    "he",
    "hi",
    "hr",
    "ht",
    "hu",
    "hy",
    "id",
    "ig",
    "is",
    "it",
    "ja",
    "jv",
    "ka",
    "kk",
    "km",
    "kn",
    "ko",
    "ku",
    "ky",
    "la",
    "lg",
    "li",
    "ln",
    "lo",
    "lt",
    "lv",
    "mg",
    "mk",
    "ml",
    "mn",
    "mr",
    "ms",
    "my",
    "ne",
    "nl",
    "no",
    "ns",
    "om",
    "or",
    "pa",
    "pl",
    "ps",
    "pt",
    "qu",
    "rm",
    "ro",
    "ru",
    "sa",
    "si",
    "sc",
    "sd",
    "sk",
    "sl",
    "so",
    "sq",
    "sr",
    "ss",
    "su",
    "sv",
    "sw",
    "ta",
    "te",
    "th",
    "tl",
    "tn",
    "tr",
    "ug",
    "uk",
    "ur",
    "uz",
    "vi",
    "wo",
    "xh",
    "yi",
    "yo",
    "zu",
    "zh",
]
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1", "sib": "eval_accuracy"}
tasks = f1.keys()
scores = {task: {} for task in tasks}

inf = math.inf
for file in os.listdir("../eval_scores/selected"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/selected", file), "r") as f:
                data = json.load(f)
                task_name = file.split(".")[0]

                scores[task_name] = data

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# we make a subset consisting of only the languages for which an adapter exists
scores_subset = {}
no_adapter = {}
for task_name in scores:
    scores_subset[task_name] = {}
    no_adapter[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name in existing_adapters:
            scores_subset[task_name][lang_name] = scores[task_name][lang_name]
        else:
            no_adapter[task_name][lang_name] = scores[task_name][lang_name]
# We prepare a subset of the scores where all distance types are included
scores_dist = {}
to_include = [
    "reconstructed_featural",
    "reconstructed_morphological_distVar",
    "reconstructed_syntactic_distVar",
    "baseline_en",
    "baseline_avg_adapter",
    "baseline_closest_featural",
    "no_train_gain",
]
# for each key, if not ALL of the to_include keys are in the list, we skip the language
langs = set()
for task_name in scores:
    scores_dist[task_name] = {}
    for lang_name in scores[task_name]:
        if all(col in scores[task_name][lang_name] for col in to_include):
            langs.add(lang_name)
            scores_dist[task_name][lang_name] = {col: scores[task_name][lang_name][col] for col in to_include}
        else:
            # print(f"skipping {lang_name} for {task_name}")
            continue
print("len(scores_dist)", len(scores_dist["sib"]))
print("og len(scores)", len(scores["sib"]))
# Out:
# len(scores_dist) 176
# og len(scores) 195

# %%
def get_significance(task_name, option1, option2, alternative="two-sided", data=scores):
    all_scores1 = []
    all_scores2 = []
    if task_name == "all":
        task_names = data.keys()
    elif type(task_name) is str:
        task_names = [task_name]
    else:
        task_names = task_name
    for task_name in task_names:
        for lang_name in data[task_name]:
            if option1 in data[task_name][lang_name] and option2 in data[task_name][lang_name]:
                score1 = data[task_name][lang_name][option1]
                score2 = data[task_name][lang_name][option2]
                all_scores1.append(score1)
                all_scores2.append(score2)
    print("average scores")
    print(f"{option1}: {np.mean(all_scores1)}")
    print(f"{option2}: {np.mean(all_scores2)}")
    t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)
    print(f"t-statistic: {t_stat}")
    print(f"p-value: {p_val}")
    return t_stat, p_val

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "pos"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = ["baseline_en", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: 0.5676548287326185
# baseline_en: 0.5350230613232024
# t-statistic: 11.52057296931363
# p-value: 2.1940815528850423e-26
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: 0.5677830961241888
# baseline_en: 0.5350230613232024
# t-statistic: 11.536021706946196
# p-value: 1.9298096666946395e-26
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: 0.5678031066352571
# baseline_en: 0.5350230613232024
# t-statistic: 11.564743838984809
# p-value: 1.5198614712944096e-26
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: 0.5676548287326185
# baseline_closest_featural: 0.515830715988038
# t-statistic: 9.756051394362068
# p-value: 2.993026185988376e-20
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: 0.5677830961241888
# baseline_closest_featural: 0.515830715988038
# t-statistic: 9.788802575533314
# p-value: 2.3276344144179515e-20
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: 0.5678031066352571
# baseline_closest_featural: 0.515830715988038
# t-statistic: 9.805912493899557
# p-value: 2.0407546477626732e-20
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: 0.5676548287326185
# no_train_gain: 0.5582357922617451
# t-statistic: 6.904872335498588
# p-value: 1.2710312025201324e-11
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: 0.5677830961241888
# no_train_gain: 0.5582357922617451
# t-statistic: 7.0147552629973635
# p-value: 6.432212174366754e-12
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: 0.5678031066352571
# no_train_gain: 0.5582357922617451
# t-statistic: 6.939468599333008
# p-value: 1.0265579388500574e-11
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_featural_baseline_en', 'reconstructed_morphological_distVar_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural', 'reconstructed_featural_no_train_gain', 'reconstructed_morphological_distVar_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain']
#
# notsign []

# %% [markdown]
# ## POS comparison

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "pos"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = ["baseline_en", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: 0.4485338790223098
# baseline_en: 0.4443287769237761
# t-statistic: 1.471682968258695
# p-value: 0.07312353162482992
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: 0.4495814021381374
# baseline_en: 0.4443287769237761
# t-statistic: 1.745247538164272
# p-value: 0.042988729413020815
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: 0.44801410251010987
# baseline_en: 0.4443287769237761
# t-statistic: 1.3395865924575125
# p-value: 0.09267468908885493
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: 0.4485338790223098
# baseline_closest_featural: 0.42862365214333215
# t-statistic: 3.9685919781387953
# p-value: 9.649863824993798e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: 0.4495814021381374
# baseline_closest_featural: 0.42862365214333215
# t-statistic: 4.294266902644133
# p-value: 3.194412763878909e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: 0.44801410251010987
# baseline_closest_featural: 0.42862365214333215
# t-statistic: 3.9226731677678046
# p-value: 0.00011239316255391107
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: 0.4485338790223098
# no_train_gain: 0.4490273136387065
# t-statistic: -0.2852648105649219
# p-value: 0.6117961840375883
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: 0.4495814021381374
# no_train_gain: 0.4490273136387065
# t-statistic: 0.36520772338361185
# p-value: 0.35810980874558573
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: 0.44801410251010987
# no_train_gain: 0.4490273136387065
# t-statistic: -0.5956335826359648
# p-value: 0.7231881765677382
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_morphological_distVar_baseline_en', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural']
#
# notsign ['reconstructed_featural_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_no_train_gain', 'reconstructed_morphological_distVar_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain']

# %%
# we check if
task = "pos"
test_columns = [
    "reconstructed_morphological_distVar",
]
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")
print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_morphological_distVar, baseline reconstructed_featural
# average scores
# reconstructed_morphological_distVar: 0.4495814021381374
# reconstructed_featural: 0.4485338790223098
# t-statistic: 1.2566139823269367
# p-value: 0.10684215706420998
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_morphological_distVar: 0.4495814021381374
# reconstructed_syntactic_distVar: 0.44801410251010987
# t-statistic: 1.7033909635405693
# p-value: 0.04679257582016358
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_morphological_distVar_reconstructed_syntactic_distVar']
#
# notsign ['reconstructed_morphological_distVar_reconstructed_featural']

# %% [markdown]
# ## Results POS distance comparison
# As different languages lack some distance types, the evaluation is slightly different.
# We retain only the languages which have full coverage of all distance type evaluations.
# Our inspection of the dropped languages shows that they are mostly low-resource languages, which is not surprising but has some implications:
# Our method has been shown in section [SECTION ANALYSIS RESOURCEDNESS] to have a higher impact on lower-resourced languages.
#
# -> We see that morphological distance is most beneficial for POS, only one that outperforms all baselines. (Significantly for all but no_train_gain), followed by featural distance and syntactic distance (slightly less performant). These two still outperform all baselines significantly BUT the english source adapter setting, and slightly underperform compared to no_train_gain
#
# Morphological distance significantly outperforms syntactic distance on POS
#
# # NER comparison

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "ner"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = ["baseline_en", "baseline_avg_adapter", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: 0.49947934356251256
# baseline_en: 0.4647875590055643
# t-statistic: 5.319830048696973
# p-value: 4.2321140086576374e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# baseline_en: 0.4647875590055643
# t-statistic: 5.329260470386214
# p-value: 4.0712127039246156e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: 0.49944428243953554
# baseline_en: 0.4647875590055643
# t-statistic: 5.299914249860668
# p-value: 4.5926651828571e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_avg_adapter
# average scores
# reconstructed_featural: 0.49947934356251256
# baseline_avg_adapter: 0.39531346179447296
# t-statistic: 16.956971283519238
# p-value: 3.725799748928849e-29
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# baseline_avg_adapter: 0.39531346179447296
# t-statistic: 16.79818336412227
# p-value: 6.873516967974845e-29
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_syntactic_distVar: 0.49944428243953554
# baseline_avg_adapter: 0.39531346179447296
# t-statistic: 17.022079187038834
# p-value: 2.9011246358673384e-29
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: 0.49947934356251256
# baseline_closest_featural: 0.44823662361065447
# t-statistic: 5.34661197014957
# p-value: 3.79067920230072e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# baseline_closest_featural: 0.44823662361065447
# t-statistic: 5.396113188509967
# p-value: 3.090442910407302e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: 0.49944428243953554
# baseline_closest_featural: 0.44823662361065447
# t-statistic: 5.351602488373623
# p-value: 3.713564695348244e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: 0.49947934356251256
# no_train_gain: 0.4949850563321412
# t-statistic: 1.5131165957598491
# p-value: 0.06700178080203144
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# no_train_gain: 0.4949850563321412
# t-statistic: 1.6689820446978803
# p-value: 0.049422082250862184
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: 0.49944428243953554
# no_train_gain: 0.4949850563321412
# t-statistic: 1.4872775795406616
# p-value: 0.07034288376940702
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_featural_baseline_en', 'reconstructed_morphological_distVar_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_baseline_avg_adapter', 'reconstructed_morphological_distVar_baseline_avg_adapter', 'reconstructed_syntactic_distVar_baseline_avg_adapter', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural', 'reconstructed_morphological_distVar_no_train_gain']
#
# notsign ['reconstructed_featural_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain']

# %%
# we check if
task = "ner"
test_columns = [
    "reconstructed_morphological_distVar",
]
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")
# Out:
# test_column: reconstructed_morphological_distVar, baseline reconstructed_featural
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# reconstructed_featural: 0.49947934356251256
# t-statistic: 1.3028120039229474
# p-value: 0.09809962112247249
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_morphological_distVar: 0.5001237474726075
# reconstructed_syntactic_distVar: 0.49944428243953554
# t-statistic: 1.3288125640435824
# p-value: 0.09375411005382189
# The difference is not statistically significant
# -----------------------------------

# %% [markdown]
# ## Results NER distance comparison
# Again, morphological distance seems to be most informative, only one to significantly outperform all baselines. Other two methods are almost identical in score, outperforming all baselines significantly except for no_train_gain (which they still outperform)
#
# # QA comparison

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "qa"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = ["baseline_en", "baseline_avg_adapter", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: 0.7271252762822759
# baseline_en: 0.7210740878836793
# t-statistic: 2.4633369914457828
# p-value: 0.015745852365037824
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: 0.7272652915477485
# baseline_en: 0.7210740878836793
# t-statistic: 2.609570550253358
# p-value: 0.012138048056661924
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: 0.7270498698545946
# baseline_en: 0.7210740878836793
# t-statistic: 2.4029050957563642
# p-value: 0.017525950911712523
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_avg_adapter
# average scores
# reconstructed_featural: 0.7271252762822759
# baseline_avg_adapter: 0.6859815065016108
# t-statistic: 11.226294026135626
# p-value: 1.1503535772676353e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_morphological_distVar: 0.7272652915477485
# baseline_avg_adapter: 0.6859815065016108
# t-statistic: 10.937419649321486
# p-value: 1.4993641648860497e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_syntactic_distVar: 0.7270498698545946
# baseline_avg_adapter: 0.6859815065016108
# t-statistic: 11.127083162320574
# p-value: 1.259117844339227e-07
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: 0.7271252762822759
# baseline_closest_featural: 0.7210850183435054
# t-statistic: 2.8511699779448194
# p-value: 0.007881850372607541
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: 0.7272652915477485
# baseline_closest_featural: 0.7210850183435054
# t-statistic: 2.929521518241172
# p-value: 0.006851069307820161
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: 0.7270498698545946
# baseline_closest_featural: 0.7210850183435054
# t-statistic: 2.7878711597563965
# p-value: 0.008826814039345963
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: 0.7271252762822759
# no_train_gain: 0.7252841925923107
# t-statistic: 1.351322008166783
# p-value: 0.10186467852268974
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: 0.7272652915477485
# no_train_gain: 0.7252841925923107
# t-statistic: 1.4822475064746685
# p-value: 0.08317308033506798
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: 0.7270498698545946
# no_train_gain: 0.7252841925923107
# t-statistic: 1.3615872896433299
# p-value: 0.1002819804545461
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_featural_baseline_en', 'reconstructed_morphological_distVar_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_baseline_avg_adapter', 'reconstructed_morphological_distVar_baseline_avg_adapter', 'reconstructed_syntactic_distVar_baseline_avg_adapter', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural']
#
# notsign ['reconstructed_featural_no_train_gain', 'reconstructed_morphological_distVar_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain']

# %% [markdown]
# ## Results QA distance comparison
# All distance types are very, very similar. All outperform all baselines, significantly in all cases but no_train_gain (smaller difference, less than 0,25% relative improvement compared to 36% relative to finetune baseline).
# # SIB comparison

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "sib"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = [
    "baseline_en",
    "baseline_avg_adapter",
    "baseline_closest_featural",
    "no_train_gain",
    "reconstructed_featural",
]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: 0.6316705659536542
# baseline_en: 0.5882074420677362
# t-statistic: 10.977894928915193
# p-value: 5.7580224876135305e-22
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: 0.6312249331550802
# baseline_en: 0.5882074420677362
# t-statistic: 10.908649054027412
# p-value: 9.062557834898598e-22
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: 0.6321579768270945
# baseline_en: 0.5882074420677362
# t-statistic: 11.123398927090108
# p-value: 2.2166568576901843e-22
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_avg_adapter
# average scores
# reconstructed_featural: 0.6316705659536542
# baseline_avg_adapter: 0.5429060828877006
# t-statistic: 20.34152739293072
# p-value: 2.8145865484888316e-48
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_morphological_distVar: 0.6312249331550802
# baseline_avg_adapter: 0.5429060828877006
# t-statistic: 20.2129215732612
# p-value: 6.142480934966392e-48
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_syntactic_distVar: 0.6321579768270945
# baseline_avg_adapter: 0.5429060828877006
# t-statistic: 20.472007518761522
# p-value: 1.2777418408359323e-48
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: 0.6316705659536542
# baseline_closest_featural: 0.5652016488413547
# t-statistic: 7.726307438946427
# p-value: 4.1280106089606804e-13
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: 0.6312249331550802
# baseline_closest_featural: 0.5652016488413547
# t-statistic: 7.671517649588912
# p-value: 5.685892481969278e-13
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: 0.6321579768270945
# baseline_closest_featural: 0.5652016488413547
# t-statistic: 7.80686910793212
# p-value: 2.573054169483757e-13
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: 0.6316705659536542
# no_train_gain: 0.6158645276292334
# t-statistic: 8.087888071789674
# p-value: 4.863411113862717e-14
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: 0.6312249331550802
# no_train_gain: 0.6158645276292334
# t-statistic: 7.869730404705653
# p-value: 1.7766118609334024e-13
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: 0.6321579768270945
# no_train_gain: 0.6158645276292334
# t-statistic: 8.27277589157143
# p-value: 1.6031282212870337e-14
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline reconstructed_featural
# average scores
# reconstructed_featural: 0.6316705659536542
# reconstructed_featural: 0.6316705659536542
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline reconstructed_featural
# average scores
# reconstructed_morphological_distVar: 0.6312249331550802
# reconstructed_featural: 0.6316705659536542
# t-statistic: -1.6584604786173036
# p-value: 0.9504920743589069
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline reconstructed_featural
# average scores
# reconstructed_syntactic_distVar: 0.6321579768270945
# reconstructed_featural: 0.6316705659536542
# t-statistic: 2.216001614231786
# p-value: 0.013990471853634414
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_featural_baseline_en', 'reconstructed_morphological_distVar_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_baseline_avg_adapter', 'reconstructed_morphological_distVar_baseline_avg_adapter', 'reconstructed_syntactic_distVar_baseline_avg_adapter', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural', 'reconstructed_featural_no_train_gain', 'reconstructed_morphological_distVar_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain', 'reconstructed_syntactic_distVar_reconstructed_featural']
#
# notsign ['reconstructed_featural_reconstructed_featural', 'reconstructed_morphological_distVar_reconstructed_featural']

# %% [markdown]
# ## SIB results
# All distance types outperform all baselines.
# Morphological gets slightly lower results than featural ==> LOGIC in a HIHG-level task!
# Syntactic outperforms featural, not a large margin but something!

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "copa"
test_columns = ["reconstructed_featural", "reconstructed_morphological_distVar", "reconstructed_syntactic_distVar"]
baselines = ["baseline_en", "baseline_avg_adapter", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_dist)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural, baseline baseline_en
# average scores
# reconstructed_featural: nan
# baseline_en: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_en
# average scores
# reconstructed_morphological_distVar: nan
# baseline_en: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_en
# average scores
# reconstructed_syntactic_distVar: nan
# baseline_en: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_avg_adapter
# average scores
# reconstructed_featural: nan
# baseline_avg_adapter: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_morphological_distVar: nan
# baseline_avg_adapter: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_avg_adapter
# average scores
# reconstructed_syntactic_distVar: nan
# baseline_avg_adapter: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline baseline_closest_featural
# average scores
# reconstructed_featural: nan
# baseline_closest_featural: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_morphological_distVar: nan
# baseline_closest_featural: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_distVar: nan
# baseline_closest_featural: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural, baseline no_train_gain
# average scores
# reconstructed_featural: nan
# no_train_gain: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_distVar, baseline no_train_gain
# average scores
# reconstructed_morphological_distVar: nan
# no_train_gain: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_distVar, baseline no_train_gain
# average scores
# reconstructed_syntactic_distVar: nan
# no_train_gain: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# sign []
#
# notsign ['reconstructed_featural_baseline_en', 'reconstructed_morphological_distVar_baseline_en', 'reconstructed_syntactic_distVar_baseline_en', 'reconstructed_featural_baseline_avg_adapter', 'reconstructed_morphological_distVar_baseline_avg_adapter', 'reconstructed_syntactic_distVar_baseline_avg_adapter', 'reconstructed_featural_baseline_closest_featural', 'reconstructed_morphological_distVar_baseline_closest_featural', 'reconstructed_syntactic_distVar_baseline_closest_featural', 'reconstructed_featural_no_train_gain', 'reconstructed_morphological_distVar_no_train_gain', 'reconstructed_syntactic_distVar_no_train_gain']
# C:\Users\stefa\AppData\Local\Temp\ipykernel_48456\2036528169.py:20: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)

# %% [markdown]
# ## Results COPA distance comparison
# Outperforms baseline_en in all cases. Featural is best, but small difference.
# --> Does not have to be analysed as this is done in main experiment
# # Limit analysis

# %%
# we will now investigate if using limits and thresholds can further improve results
scores_limit = [
    "reconstructed_featural_limit",
    "reconstructed_syntactic_limit",
    "reconstructed_morphological_limit",
    "reconstructed_featural_threshold",
    "reconstructed_syntactic_threshold",
    "reconstructed_morphological_threshold",
    "reconstructed_featural",
    "reconstructed_syntactic_distVar",
    "reconstructed_morphological_distVar",
]
# we refine the subset to only include the languages that have all relevant columns
scores_limit_subset = {}
for task_name in scores:
    scores_limit_subset[task_name] = {}
    for lang_name in scores[task_name]:
        if all(col in scores[task_name][lang_name] for col in scores_limit):
            scores_limit_subset[task_name][lang_name] = {col: scores[task_name][lang_name][col] for col in scores_limit}
        else:
            print(f"skipping {lang_name} for {task_name}")
            missing = [col for col in scores_limit if col not in scores[task_name][lang_name].keys()]
            print(missing)
            continue
with_adapters_limit_subset = {}
no_adapters_limit_subset = {}
xlm_included_limit_subset = {}
xlm_excluded_limit_subset = {}
for task_name in scores_limit_subset:
    with_adapters_limit_subset[task_name] = {}
    no_adapters_limit_subset[task_name] = {}
    xlm_included_limit_subset[task_name] = {}
    xlm_excluded_limit_subset[task_name] = {}

    for lang_name in scores_limit_subset[task_name]:
        if lang_name in existing_adapters:
            with_adapters_limit_subset[task_name][lang_name] = scores_limit_subset[task_name][lang_name]
        else:
            no_adapters_limit_subset[task_name][lang_name] = scores_limit_subset[task_name][lang_name]
        if lang_name in xlm_included_langs:
            xlm_included_limit_subset[task_name][lang_name] = scores_limit_subset[task_name][lang_name]
        else:
            xlm_excluded_limit_subset[task_name][lang_name] = scores_limit_subset[task_name][lang_name]
# Out:
# skipping af for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping an for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ast for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping as for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ay for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping az for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping bar for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping bg for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping bn for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping bs for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping cdo for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping csb for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping de for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping diq for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping dv for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping eo for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping es for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ext for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping fa for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping fo for ner
# ['reconstructed_featural']
# skipping frr for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping fur for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gan for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gd for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gu for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping hr for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping hsb for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping kk for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ksh for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ku for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ky for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping lb for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping lij for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping mg for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping mhr for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ml for ner
# ['reconstructed_featural']
# skipping mn for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ms for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping mwl for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping mzn for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping nap for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping nds for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ne for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping nn for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping no for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping or for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping pdc for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping pms for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ps for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ro for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping rw for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sco for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sd for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping si for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sk for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sq for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sr for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping szl for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping tg for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping tk for ner
# ['reconstructed_featural']
# skipping ug for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ur for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping uz for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping vec for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping vls for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping wa for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping xmf for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping yi for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping yo for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping zea for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping li for ner
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural_threshold', 'reconstructed_syntactic_threshold', 'reconstructed_morphological_threshold', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping et for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ht for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping id for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping it for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping qu for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sw for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ta for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping th for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping tr for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping vi for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping zh for copa
# ['reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping af for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping aii for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ajp for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping bg for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping de for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping es for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping fa for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gd for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gsw for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping gv for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping hr for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping hsb for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping kfm for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping kk for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping kmr for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping koi for pos
# ['reconstructed_featural']
# skipping krl for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping no for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping nyq for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping pcm for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ro for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sk for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping soj for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_featural', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sq for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping sr for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ug for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping ur for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping yo for pos
# ['reconstructed_featural_limit', 'reconstructed_syntactic_limit', 'reconstructed_morphological_limit', 'reconstructed_syntactic_distVar', 'reconstructed_morphological_distVar']
# skipping acq for sib
# ['reconstructed_featural']
# skipping ajp for sib
# ['reconstructed_featural']
# skipping ast for sib
# ['reconstructed_featural']
# skipping bjn for sib
# ['reconstructed_featural']
# skipping cjk for sib
# ['reconstructed_featural']
# skipping dik for sib
# ['reconstructed_featural']
# skipping hne for sib
# ['reconstructed_featural']
# skipping kg for sib
# ['reconstructed_featural']
# skipping kmb for sib
# ['reconstructed_featural']
# skipping lij for sib
# ['reconstructed_featural']
# skipping li for sib
# ['reconstructed_featural']
# skipping ltg for sib
# ['reconstructed_featural']
# skipping lvs for sib
# ['reconstructed_featural']
# skipping nn for sib
# ['reconstructed_featural']
# skipping sc for sib
# ['reconstructed_featural']
# skipping sk for sib
# ['reconstructed_featural']
# skipping szl for sib
# ['reconstructed_featural']
# skipping tum for sib
# ['reconstructed_featural']
# skipping vec for sib
# ['reconstructed_featural']

# %%
task = "all"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: 0.5696541806173965
# reconstructed_featural: 0.5676548287326185
# t-statistic: 3.8568643941809024
# p-value: 6.890033187957171e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: 0.571571979275728
# reconstructed_featural: 0.5676548287326185
# t-statistic: 3.6108327183199282
# p-value: 0.00017601762110295747
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: 0.570094537188873
# reconstructed_syntactic_distVar: 0.5678031066352571
# t-statistic: 3.5412154712955104
# p-value: 0.00022743182215600902
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: 0.5723469807609269
# reconstructed_syntactic_distVar: 0.5678031066352571
# t-statistic: 3.397061671424432
# p-value: 0.00038168985977344823
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: 0.5696086234618577
# reconstructed_morphological_distVar: 0.5677830961241888
# t-statistic: 2.2007225675249154
# p-value: 0.0142198196237988
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: 0.5698025836294178
# reconstructed_morphological_distVar: 0.5677830961241888
# t-statistic: 1.8844307457984777
# p-value: 0.03018746521223906
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']
#
# notsign []

# %%
task = "ner"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: 0.5052744017684326
# reconstructed_featural: 0.49947934356251256
# t-statistic: 3.866540224747911
# p-value: 0.00010845627027128958
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: 0.5140822727352715
# reconstructed_featural: 0.49947934356251256
# t-statistic: 5.099558384560621
# p-value: 1.0373958885215319e-06
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: 0.5062823157986861
# reconstructed_syntactic_distVar: 0.49944428243953554
# t-statistic: 3.704583025826268
# p-value: 0.00018907176248542088
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: 0.5128287038566253
# reconstructed_syntactic_distVar: 0.49944428243953554
# t-statistic: 3.1900068580336387
# p-value: 0.0010003195865542318
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: 0.507556980868529
# reconstructed_morphological_distVar: 0.5001237474726075
# t-statistic: 4.397114034408046
# p-value: 1.59628009301921e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: 0.5103470683872087
# reconstructed_morphological_distVar: 0.5001237474726075
# t-statistic: 3.7617543154024067
# p-value: 0.00015564491371280453
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']
#
# notsign []

# %%
task = "ner"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
method = "limit"
subsets = {
    "with_adapters": with_adapters_limit_subset,
    "no_adapters": no_adapters_limit_subset,
    "xlm_included": xlm_included_limit_subset,
    "xlm_excluded": xlm_excluded_limit_subset,
}
sign = []
not_sign = []
for baseline in baselines:
    for subset_name, scores_subset in subsets.items():
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}, subset {subset_name}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset with_adapters
# average scores
# reconstructed_featural_limit: 0.5093842699323033
# reconstructed_featural: 0.4885533570818925
# t-statistic: 5.073764356273462
# p-value: 2.2037111564045107e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset no_adapters
# average scores
# reconstructed_featural_limit: 0.5158250802266954
# reconstructed_featural: 0.5035325320956457
# t-statistic: 3.422244374811933
# p-value: 0.0005571769981067983
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset xlm_included
# average scores
# reconstructed_featural_limit: 0.564280790165681
# reconstructed_featural: 0.5523855837939105
# t-statistic: 4.921674298394184
# p-value: 3.841385892524253e-06
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset xlm_excluded
# average scores
# reconstructed_featural_limit: 0.40624842047735527
# reconstructed_featural: 0.385828901583954
# t-statistic: 2.7791228824772634
# p-value: 0.0049951804164788585
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset with_adapters
# average scores
# reconstructed_syntactic_limit: 0.514753155724369
# reconstructed_syntactic_distVar: 0.48847769500914007
# t-statistic: 2.439601112358019
# p-value: 0.011612460716921376
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset no_adapters
# average scores
# reconstructed_syntactic_limit: 0.5121147942927851
# reconstructed_syntactic_distVar: 0.5035125326153276
# t-statistic: 2.128773981475069
# p-value: 0.018659654610285795
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset xlm_included
# average scores
# reconstructed_syntactic_limit: 0.5609474774467984
# reconstructed_syntactic_distVar: 0.5526515005567276
# t-statistic: 3.210971894065606
# p-value: 0.0010876787153533093
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset xlm_excluded
# average scores
# reconstructed_syntactic_limit: 0.40946244947773497
# reconstructed_syntactic_distVar: 0.385147295372975
# t-statistic: 2.0485741871361993
# p-value: 0.02536222457927527
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset with_adapters
# average scores
# reconstructed_morphological_limit: 0.5106199489402286
# reconstructed_morphological_distVar: 0.48986670641128094
# t-statistic: 5.398327342112725
# p-value: 1.009719168524455e-05
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset no_adapters
# average scores
# reconstructed_morphological_limit: 0.5102458385046368
# reconstructed_morphological_distVar: 0.5039287788340675
# t-statistic: 1.9010426762169428
# p-value: 0.03101169421988161
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset xlm_included
# average scores
# reconstructed_morphological_limit: 0.5637844289840493
# reconstructed_morphological_distVar: 0.5527681662948912
# t-statistic: 4.6633951584196796
# p-value: 9.60821384852813e-06
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset xlm_excluded
# average scores
# reconstructed_morphological_limit: 0.3955557011791804
# reconstructed_morphological_distVar: 0.38703573666918356
# t-statistic: 1.2211607613014794
# p-value: 0.11649174983428576
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']
#
# notsign ['reconstructed_morphological_limit_reconstructed_morphological_distVar']

# %% [markdown]
# ## Results NER distance comparison with limits
# Both Limit and Thresholds significantly outperform their relative counterparts (no limitation).
# best performing = limit, especially featural (0.514 vs 0.499 for overall NER)
# ==> Shows that our method has more potential, and can be further refined by looking for better limit and threshold values

# %%
task = "pos"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: 0.4483538634919548
# reconstructed_featural: 0.4485338790223098
# t-statistic: -0.12885942222239558
# p-value: 0.5510535925349446
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: 0.4484558278153162
# reconstructed_featural: 0.4485338790223098
# t-statistic: -0.05020410696226338
# p-value: 0.5199381152963118
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: 0.44867461361811517
# reconstructed_syntactic_distVar: 0.44801410251010987
# t-statistic: 0.44166442528108035
# p-value: 0.33014690506025063
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: 0.44966046920853453
# reconstructed_syntactic_distVar: 0.44801410251010987
# t-statistic: 1.2293117189837717
# p-value: 0.11183790344761589
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: 0.4500689529865086
# reconstructed_morphological_distVar: 0.4495814021381374
# t-statistic: 0.29756124682819307
# p-value: 0.3835245553549905
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: 0.4481551406768528
# reconstructed_morphological_distVar: 0.4495814021381374
# t-statistic: -0.7243385823168748
# p-value: 0.7641865009909189
# The difference is not statistically significant
# -----------------------------------
# sign []
#
# notsign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']

# %%
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["limit", "threshold"]
subsets = {
    "with_adapters": with_adapters_limit_subset,
    "no_adapters": no_adapters_limit_subset,
    "xlm_included": xlm_included_limit_subset,
    "xlm_excluded": xlm_excluded_limit_subset,
}
sign = []
not_sign = []
for subset_name, scores_subset in subsets.items():
    for baseline in baselines:
        for method in methods:
            if baseline == "reconstructed_featural":
                test_column = baseline + f"_{method}"
            else:
                # we replace "distVar" with "threshold"
                test_column = baseline.replace("distVar", method)

            print(f"test_column: {test_column}, baseline {baseline}, subset {subset_name}")
            t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_subset)
            if p_val < 0.05:
                print("The difference is statistically significant")
                sign.append(test_column + "_" + baseline)
            else:
                print("The difference is not statistically significant")
                not_sign.append(test_column + "_" + baseline)
            print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset with_adapters
# average scores
# reconstructed_featural_limit: 0.5343047506476772
# reconstructed_featural: 0.5303411521074455
# t-statistic: 1.0319280309615306
# p-value: 0.1592290797516526
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural, subset with_adapters
# average scores
# reconstructed_featural_threshold: 0.5363598307162523
# reconstructed_featural: 0.5303411521074455
# t-statistic: 1.7671601981997402
# p-value: 0.048767187580653654
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset with_adapters
# average scores
# reconstructed_syntactic_limit: 0.5326257072297398
# reconstructed_syntactic_distVar: 0.5305344422155532
# t-statistic: 0.5112029403063311
# p-value: 0.3083253702864398
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar, subset with_adapters
# average scores
# reconstructed_syntactic_threshold: 0.536429831786578
# reconstructed_syntactic_distVar: 0.5305344422155532
# t-statistic: 1.7059328507819664
# p-value: 0.054317088952611066
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset with_adapters
# average scores
# reconstructed_morphological_limit: 0.5324743198114654
# reconstructed_morphological_distVar: 0.5350088785760843
# t-statistic: -0.568012036684781
# p-value: 0.7107845026513682
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar, subset with_adapters
# average scores
# reconstructed_morphological_threshold: 0.5395662276942985
# reconstructed_morphological_distVar: 0.5350088785760843
# t-statistic: 1.1460468110175481
# p-value: 0.13486528022221514
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset no_adapters
# average scores
# reconstructed_featural_limit: 0.41859533291710366
# reconstructed_featural: 0.4200791753405234
# t-statistic: -0.9318973331640517
# p-value: 0.8218186741252047
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural, subset no_adapters
# average scores
# reconstructed_featural_threshold: 0.4177430922835035
# reconstructed_featural: 0.4200791753405234
# t-statistic: -1.7314069879814056
# p-value: 0.9548846084630627
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset no_adapters
# average scores
# reconstructed_syntactic_limit: 0.42080299511420227
# reconstructed_syntactic_distVar: 0.41931137565604265
# t-statistic: 1.2911423254011347
# p-value: 0.10162390556229026
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar, subset no_adapters
# average scores
# reconstructed_syntactic_threshold: 0.41815105947256276
# reconstructed_syntactic_distVar: 0.41931137565604265
# t-statistic: -0.7464788776372362
# p-value: 0.7703697431366916
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset no_adapters
# average scores
# reconstructed_morphological_limit: 0.41882673054307457
# reconstructed_morphological_distVar: 0.41986749729015577
# t-statistic: -0.4769094888372884
# p-value: 0.6821327449320969
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar, subset no_adapters
# average scores
# reconstructed_morphological_threshold: 0.41893946613162514
# reconstructed_morphological_distVar: 0.41986749729015577
# t-statistic: -0.5450506722258288
# p-value: 0.705794977185418
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset xlm_included
# average scores
# reconstructed_featural_limit: 0.5545083551915915
# reconstructed_featural: 0.5545115938687065
# t-statistic: -0.0016537152227054232
# p-value: 0.5006558216434954
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural, subset xlm_included
# average scores
# reconstructed_featural_threshold: 0.5543833309244328
# reconstructed_featural: 0.5545115938687065
# t-statistic: -0.06444452497483692
# p-value: 0.5255389817808512
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset xlm_included
# average scores
# reconstructed_syntactic_limit: 0.555332912782091
# reconstructed_syntactic_distVar: 0.5539409292215323
# t-statistic: 0.7896318868352599
# p-value: 0.217089123627544
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar, subset xlm_included
# average scores
# reconstructed_syntactic_threshold: 0.55414599951804
# reconstructed_syntactic_distVar: 0.5539409292215323
# t-statistic: 0.09811645665986626
# p-value: 0.461153294562034
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset xlm_included
# average scores
# reconstructed_morphological_limit: 0.5516458032432682
# reconstructed_morphological_distVar: 0.5562120860138511
# t-statistic: -1.8800833632007004
# p-value: 0.9664777636662384
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar, subset xlm_included
# average scores
# reconstructed_morphological_threshold: 0.555521325484253
# reconstructed_morphological_distVar: 0.5562120860138511
# t-statistic: -0.32763944377418824
# p-value: 0.6275940346422353
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural, subset xlm_excluded
# average scores
# reconstructed_featural_limit: 0.20844221322690384
# reconstructed_featural: 0.20868957700151705
# t-statistic: -0.09722958432047213
# p-value: 0.538190735589636
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural, subset xlm_excluded
# average scores
# reconstructed_featural_threshold: 0.20839243719739922
# reconstructed_featural: 0.20868957700151705
# t-statistic: -0.36509578104496626
# p-value: 0.640352751315025
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar, subset xlm_excluded
# average scores
# reconstructed_syntactic_limit: 0.21050704427890704
# reconstructed_syntactic_distVar: 0.20828496837373303
# t-statistic: 1.2054396439329744
# p-value: 0.12182097054940365
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar, subset xlm_excluded
# average scores
# reconstructed_syntactic_threshold: 0.20997621394986402
# reconstructed_syntactic_distVar: 0.20828496837373303
# t-statistic: 1.3457505643467322
# p-value: 0.09754512782992876
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar, subset xlm_excluded
# average scores
# reconstructed_morphological_limit: 0.21393943065812332
# reconstructed_morphological_distVar: 0.20825932810362752
# t-statistic: 2.0496282573597884
# p-value: 0.027630332673542268
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar, subset xlm_excluded
# average scores
# reconstructed_morphological_threshold: 0.2114135836495081
# reconstructed_morphological_distVar: 0.20825932810362752
# t-statistic: 1.3274470982964943
# p-value: 0.10047604861663405
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']
#
# notsign ['reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar']

# %% [markdown]
# F## Results POS distance comparison with limits
# For POS, limiting or putting a threshold has no demonstrable positive effect on the results

# %%
task = "qa"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: 0.7266866467655285
# reconstructed_featural: 0.7271252762822759
# t-statistic: -1.2504480934463686
# p-value: 0.8814591421280972
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: 0.7281344543568334
# reconstructed_featural: 0.7271252762822759
# t-statistic: 1.0506349044006917
# p-value: 0.15798021009887603
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: 0.7271196088629276
# reconstructed_syntactic_distVar: 0.7270498698545946
# t-statistic: 0.19561002530779972
# p-value: 0.42424096051585775
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: 0.7281198226218644
# reconstructed_syntactic_distVar: 0.7270498698545946
# t-statistic: 1.3573737047537158
# p-value: 0.10092913830656992
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: 0.7285715530023293
# reconstructed_morphological_distVar: 0.7272652915477485
# t-statistic: 1.8793992384607006
# p-value: 0.04346244852060304
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: 0.7284004003755643
# reconstructed_morphological_distVar: 0.7272652915477485
# t-statistic: 1.0303090833954238
# p-value: 0.16249357862491548
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_morphological_threshold_reconstructed_morphological_distVar']
#
# notsign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']

# %% [markdown]
# ## Results QA distance comparison with limits
# For QA, using a threshold that filters out more distant adapters has a significant improvement upon the results only for the morphological distance, which results in the highest overall score for the method.

# %%
task = "copa"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: nan
# reconstructed_featural: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: nan
# reconstructed_featural: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: nan
# reconstructed_syntactic_distVar: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: nan
# reconstructed_syntactic_distVar: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: nan
# reconstructed_morphological_distVar: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: nan
# reconstructed_morphological_distVar: nan
# t-statistic: nan
# p-value: nan
# The difference is not statistically significant
# -----------------------------------
# sign []
#
# notsign ['reconstructed_featural_threshold_reconstructed_featural', 'reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']
# C:\Users\stefa\AppData\Local\Temp\ipykernel_48456\2036528169.py:20: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "copa"
test_columns = ["reconstructed_featural_limit"]
baselines = ["baseline_en", "baseline_avg_adapter", "baseline_closest_featural", "no_train_gain"]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_limit, baseline baseline_en
# average scores
# reconstructed_featural_limit: 0.5181818181818182
# baseline_en: 0.5083636363636364
# t-statistic: 1.4604198759809905
# p-value: 0.08743404052954881
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline baseline_avg_adapter
# average scores
# reconstructed_featural_limit: 0.5181818181818182
# baseline_avg_adapter: 0.5150909090909092
# t-statistic: 0.5544198843936056
# p-value: 0.2957370025331385
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline baseline_closest_featural
# average scores
# reconstructed_featural_limit: 0.5181818181818182
# baseline_closest_featural: 0.5198181818181818
# t-statistic: -0.2559960557948576
# p-value: 0.5984285550587479
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline no_train_gain
# average scores
# reconstructed_featural_limit: 0.5181818181818182
# no_train_gain: 0.503090909090909
# t-statistic: 2.5399965931843855
# p-value: 0.014681662314904273
# The difference is statistically significant
# -----------------------------------
# sign ['reconstructed_featural_limit_no_train_gain']
#
# notsign ['reconstructed_featural_limit_baseline_en', 'reconstructed_featural_limit_baseline_avg_adapter', 'reconstructed_featural_limit_baseline_closest_featural']

# %% [markdown]
# ## Results COPA distance comparison with limits
# reconstructed featural with a limit is the highest performing method!
# Outperforms all other methods significantly. It results in scores that outperform most of the baselines that could not be matched with the regular method.
# However, the highest score remains the MAD-X baseline, which still slightly outperforms our method: as our method approximates adapters, and is mainly targeted to create adapters for language that do not have existing language adapters, the COPA task is not the best representation of the method's performance. This is because all languages in this task setup have an existing adapter, which makes the method less relevant.
#
# # SIB analysis with limits

# %%
task = "sib"
baselines = ["reconstructed_featural", "reconstructed_syntactic_distVar", "reconstructed_morphological_distVar"]
methods = ["threshold", "limit"]
sign = []
not_sign = []
for baseline in baselines:
    for method in methods:
        if baseline == "reconstructed_featural":
            test_column = baseline + f"_{method}"
        else:
            # we replace "distVar" with "threshold"
            test_column = baseline.replace("distVar", method)

        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores_limit_subset)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_featural_threshold, baseline reconstructed_featural
# average scores
# reconstructed_featural_threshold: 0.6327707219251336
# reconstructed_featural: 0.6316705659536542
# t-statistic: 2.758463290837115
# p-value: 0.0032123259076249798
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_featural_limit, baseline reconstructed_featural
# average scores
# reconstructed_featural_limit: 0.6320326426024955
# reconstructed_featural: 0.6316705659536542
# t-statistic: 0.28180203796483927
# p-value: 0.38921413622879614
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_threshold, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_threshold: 0.6329796122994652
# reconstructed_syntactic_distVar: 0.6321579768270945
# t-statistic: 1.3339211587003226
# p-value: 0.09198154087812509
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_syntactic_distVar
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# reconstructed_syntactic_distVar: 0.6321579768270945
# t-statistic: 1.1094083722396806
# p-value: 0.13438812682156528
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_threshold, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_threshold: 0.6308489304812834
# reconstructed_morphological_distVar: 0.6312249331550802
# t-statistic: -0.319230506286128
# p-value: 0.6250337689038192
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_morphological_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_morphological_limit: 0.6305564839572192
# reconstructed_morphological_distVar: 0.6312249331550802
# t-statistic: -0.5085841652468334
# p-value: 0.6941578569493749
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_featural_threshold_reconstructed_featural']
#
# notsign ['reconstructed_featural_limit_reconstructed_featural', 'reconstructed_syntactic_threshold_reconstructed_syntactic_distVar', 'reconstructed_syntactic_limit_reconstructed_syntactic_distVar', 'reconstructed_morphological_threshold_reconstructed_morphological_distVar', 'reconstructed_morphological_limit_reconstructed_morphological_distVar']

# %% [markdown]
# ## Results SIB distance comparison with limits
# For SIB, best results are obtained by using syntactic with limit. As syntactic is already the highest scoring, this does not statistically outperform the other settings within syntactic distance.
# -> Also no significant improvement over others, except for
#
# For morphological, values go down but not significantly when using a threshold or limit.
#
# Only statistically significant improvement is threshold for featural distance

# %%
# we compare with the variant distances and limits in pos
# we know we do better over finetune all over the line
task = "sib"
test_columns = ["reconstructed_syntactic_limit"]
baselines = [
    "baseline_en",
    "baseline_avg_adapter",
    "baseline_closest_featural",
    "no_train_gain",
    "reconstructed_featural",
    "reconstructed_morphological_distVar",
    "reconstructed_featural_limit",
]

sign = []
not_sign = []
for baseline in baselines:
    for test_column in test_columns:
        print(f"test_column: {test_column}, baseline {baseline}")
        t_stat, p_val = get_significance(task, test_column, baseline, alternative="greater", data=scores)
        if p_val < 0.05:
            print("The difference is statistically significant")
            sign.append(test_column + "_" + baseline)
        else:
            print("The difference is not statistically significant")
            not_sign.append(test_column + "_" + baseline)
        print("-----------------------------------")

print("sign", sign)
print("\nnotsign", not_sign)
# Out:
# test_column: reconstructed_syntactic_limit, baseline baseline_en
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# baseline_en: 0.5882074420677362
# t-statistic: 11.097837950657471
# p-value: 2.6217498595481545e-22
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline baseline_avg_adapter
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# baseline_avg_adapter: 0.5429060828877006
# t-statistic: 20.34865138699926
# p-value: 2.695662941050963e-48
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline baseline_closest_featural
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# baseline_closest_featural: 0.5652016488413547
# t-statistic: 8.345711065913747
# p-value: 1.0318153447336321e-14
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline no_train_gain
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# no_train_gain: 0.6158645276292334
# t-statistic: 8.391846561553457
# p-value: 7.801926922116368e-15
# The difference is statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_featural
# average scores
# reconstructed_syntactic_limit: 0.6336898395721925
# reconstructed_featural: 0.6316705659536542
# t-statistic: 1.4485178897839088
# p-value: 0.07463081915828294
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_morphological_distVar
# average scores
# reconstructed_syntactic_limit: 0.633647561588738
# reconstructed_morphological_distVar: 0.631447963800905
# t-statistic: 1.6487641675452565
# p-value: 0.05040718822836627
# The difference is not statistically significant
# -----------------------------------
# test_column: reconstructed_syntactic_limit, baseline reconstructed_featural_limit
# average scores
# reconstructed_syntactic_limit: 0.633647561588738
# reconstructed_featural_limit: 0.6321518350930114
# t-statistic: 1.249874096915166
# p-value: 0.1064256086939728
# The difference is not statistically significant
# -----------------------------------
# sign ['reconstructed_syntactic_limit_baseline_en', 'reconstructed_syntactic_limit_baseline_avg_adapter', 'reconstructed_syntactic_limit_baseline_closest_featural', 'reconstructed_syntactic_limit_no_train_gain']
#
# notsign ['reconstructed_syntactic_limit_reconstructed_featural', 'reconstructed_syntactic_limit_reconstructed_morphological_distVar', 'reconstructed_syntactic_limit_reconstructed_featural_limit']
