# %%
import json

# we look at path "./eval_scores", in which there are json files with scores
import os
from qq import LanguageData, TagType
from urielplus import urielplus
import logging

u = urielplus.URIELPlus()
u.set_cache(True)
try:
    u.integrate_grambank()
except Exception as e:
    print(e, "already using GramBank")
try:
    u.set_glottocodes()
except Exception as e:
    print(e, "already using Glottocodes")

ld = LanguageData.from_db()

# 1) This will silence INFO and DEBUG messages globally:
logging.getLogger().setLevel(logging.WARNING)

# —or—

# 2) Disable INFO (and below) altogether:
logging.disable(logging.INFO)
# Out:
# 2025-05-25 22:34:45,006 - root - ERROR - GRAMBANK database already integrated.
# 2025-05-25 22:34:45,009 - root - ERROR - Already using Glottocodes.
# already using GramBank
# already using Glottocodes

# %% [markdown]
# # Overall top method analysis

# %%
import math
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

scores = {"ner": {}, "pos": {}, "copa": {}, "qa": {}}
f1 = {"ner": "eval_f1", "copa": "eval_acc", "pos": "eval_f1_macro", "qa": "f1"}
inf = math.inf
# From huggingface api, with our trained adapters (eu, sr)
existing_adapters = [
    "th",
    "my",
    "hi",
    "ilo",
    "ht",
    "tr",
    "mi",
    "vi",
    "is",
    "it",
    "ta",
    "jv",
    "ja",
    "sw",
    "qu",
    "de",
    "el",
    "et",
    "ru",
    "gn",
    "id",
    "en",
    "ar",
    "es",
    "tk",
    "zh",
    "mhr",
    "cdo",
    "xmf",
    "eu",
    "sr",
]
# scraped from cc-100 website
xlm_included_langs = [
    "af",
    "am",
    "ar",
    "as",
    "az",
    "be",
    "bg",
    "bn",
    "br",
    "bs",
    "ca",
    "cs",
    "cy",
    "da",
    "de",
    "el",
    "en",
    "eo",
    "es",
    "et",
    "eu",
    "fa",
    "ff",
    "fi",
    "fr",
    "fy",
    "ga",
    "gd",
    "gl",
    "gn",
    "gu",
    "ha",
    "he",
    "hi",
    "hr",
    "ht",
    "hu",
    "hy",
    "id",
    "ig",
    "is",
    "it",
    "ja",
    "jv",
    "ka",
    "kk",
    "km",
    "kn",
    "ko",
    "ku",
    "ky",
    "la",
    "lg",
    "li",
    "ln",
    "lo",
    "lt",
    "lv",
    "mg",
    "mk",
    "ml",
    "mn",
    "mr",
    "ms",
    "my",
    "ne",
    "nl",
    "no",
    "ns",
    "om",
    "or",
    "pa",
    "pl",
    "ps",
    "pt",
    "qu",
    "rm",
    "ro",
    "ru",
    "sa",
    "si",
    "sc",
    "sd",
    "sk",
    "sl",
    "so",
    "sq",
    "sr",
    "ss",
    "su",
    "sv",
    "sw",
    "ta",
    "te",
    "th",
    "tl",
    "tn",
    "tr",
    "ug",
    "uk",
    "ur",
    "uz",
    "vi",
    "wo",
    "xh",
    "yi",
    "yo",
    "zu",
    "zh",
]
for file in os.listdir("../eval_scores/selected"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../eval_scores/selected", file), "r") as f:
                data = json.load(f)
                task_name = file.split(".")[0]

                scores[task_name] = data

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)
langs = set()
tasks = ["ner", "pos", "copa", "qa"]
for task in tasks:
    for lang_name in scores[task]:
        if "reconstructed_featural" not in scores[task][lang_name].keys():
            continue
        langs.add(lang_name)
# we remove all languages from score that are not in langs
for task_name in scores:
    for lang_name in list(scores[task_name].keys()):
        if lang_name not in langs:
            del scores[task_name][lang_name]
# we make a subset consisting of only the languages for which an adapter exists
scores_subset = {}
no_adapter = {}
for task_name in scores:
    scores_subset[task_name] = {}
    no_adapter[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name not in langs:
            continue
        if lang_name in existing_adapters:
            scores_subset[task_name][lang_name] = scores[task_name][lang_name]
        else:
            no_adapter[task_name][lang_name] = scores[task_name][lang_name]

xlm_included = {}
xlm_not_included = {}
for task_name in scores:
    xlm_included[task_name] = {}
    xlm_not_included[task_name] = {}
    for lang_name in scores[task_name]:
        if lang_name in xlm_included_langs:
            xlm_included[task_name][lang_name] = scores[task_name][lang_name]
        else:
            xlm_not_included[task_name][lang_name] = scores[task_name][lang_name]


def get_significance(task_name, option1, option2, alternative="two-sided", subset=scores):
    all_scores1 = []
    all_scores2 = []
    if task_name == "all":
        task_names = subset.keys()
    elif type(task_name) is str:
        task_names = [task_name]
    else:
        task_names = task_name
    for task_name in task_names:
        for lang_name in subset[task_name]:
            if option1 in subset[task_name][lang_name] and option2 in subset[task_name][lang_name]:
                score1 = subset[task_name][lang_name][option1]
                score2 = subset[task_name][lang_name][option2]
                if task_name == "qa":
                    # we divide the scores of qa by 100
                    score1 = score1 / 100
                    score2 = score2 / 100
                all_scores1.append(score1)
                all_scores2.append(score2)
    print("average scores")
    print(f"{option1}: {np.mean(all_scores1)}")
    print(f"{option2}: {np.mean(all_scores2)}")
    t_stat, p_val = stats.ttest_rel(all_scores1, all_scores2, alternative=alternative)
    print(f"t-statistic: {t_stat}")
    print(f"p-value: {p_val}")
    return t_stat, p_val


# we retrieve means of all scores, across languages
means = {}
for task_name in scores:
    means[task_name] = {}
    for lang_name in scores[task_name]:
        for key in scores[task_name][lang_name]:
            if key not in means[task_name]:
                means[task_name][key] = []
            means[task_name][key].append(scores[task_name][lang_name][key])
    for key in means[task_name]:
        means[task_name][key] = np.mean(means[task_name][key])

# %%
# we print the top 3 highest mean score for each task, and the english adapter baseline
top_methods = {}
for task_name in means:
    top_methods[task_name] = {}
    print(f"Task: {task_name}")
    sorted_means = sorted(means[task_name].items(), key=lambda x: x[1], reverse=True)
    for i in range(3):
        print(f"{sorted_means[i][0]}: {sorted_means[i][1]}")
        top_methods[task_name][sorted_means[i][0]] = sorted_means[i][0]
    print("finetune baseline:", means[task_name]["finetune"])
    print("reconstructed base method:", means[task_name]["reconstructed_featural"])
    print()
# Out:
# Task: ner
# reconstructed_featural_limit: 0.5149050084607493
# reconstructed_syntactic_limit: 0.5136309070887364
# reconstructed_morphological_limit: 0.5112425745082357
# finetune baseline: 0.3921577086734175
# reconstructed base method: 0.5013399275268126
#
# Task: pos
# reconstructed_featural_eu: 0.46910944813280614
# reconstructed_featural_sr: 0.4691048132438308
# reconstructed_morphological_threshold: 0.4688215714892937
# finetune baseline: 0.40026520216883055
# reconstructed base method: 0.4679441087506307
#
# Task: copa
# baseline_closest_featural: 0.5645454545454546
# reconstructed_featural_limit: 0.5590909090909091
# reconstructed_morphological_limit: 0.5572727272727273
# finetune baseline: 0.5552727272727273
# reconstructed base method: 0.5498181818181818
#
# Task: qa
# reconstructed_morphological_threshold: 0.7285715530023293
# reconstructed_morphological_limit: 0.7284004003755643
# reconstructed_featural_limit: 0.7281344543568334
# finetune baseline: 0.5336718068640248
# reconstructed base method: 0.7271252762822759

# %%
def plot_top_methods(task_name, top_methods, means, ax):
    task_means = means[task_name]
    top_keys = list(top_methods[task_name].keys())
    top_values = [task_means[key] for key in top_keys]
    ax.bar(top_keys, top_values)
    ax.axhline(y=task_means["finetune"], color="r", linestyle="--", label="Finetune Baseline")
    ax.set_title(f"Top Methods for {task_name} (n={len(scores[task_name])})")
    # we add subtitle: number of languages
    ax.set_xlabel("Methods")
    ax.set_ylabel("Mean Score")
    if task_name == "qa":
        ax.set_ylim(0.3, None)
    else:
        ax.set_ylim(0.3, 0.6)
    ax.legend()
    # Adjust x-axis labels to avoid overlap
    labels = ax.get_xticklabels()
    for i, label in enumerate(labels):
        if i % 2 == 1:  # Shift every second label
            label.set_y(label.get_position()[1] - 0.035)
    ax.set_xticklabels(labels)


# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Plot each task in a separate subplot
for i, task_name in enumerate(top_methods):
    if i < 4:  # Ensure only 4 tasks are plotted
        plot_top_methods(task_name, top_methods, means, axes[i])

# Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\stefa\AppData\Local\Temp\ipykernel_29832\2473946998.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)
# C:\Users\stefa\AppData\Local\Temp\ipykernel_29832\2473946998.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)
# C:\Users\stefa\AppData\Local\Temp\ipykernel_29832\2473946998.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)
# C:\Users\stefa\AppData\Local\Temp\ipykernel_29832\2473946998.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)

# %% [markdown]
# # Language - Task table
# We make a table of scores per language, with columns for each task

# %%
# Initialize a dictionary to store data for the DataFrame
language_data = {}

# Iterate through tasks and languages to extract relevant data
for task_name in ["ner", "pos", "copa", "qa"]:
    for lang_name in scores[task_name]:
        if lang_name not in language_data:
            language_data[lang_name] = {}
        for key in scores[task_name][lang_name]:
            if key in ["reconstructed_featural", "finetune"]:
                if task_name not in language_data[lang_name]:
                    language_data[lang_name][task_name] = {}
                language_data[lang_name][task_name][key] = scores[task_name][lang_name][key]

# Convert the nested dictionary into a DataFrame with a multi-index
df = pd.DataFrame.from_dict(
    {(lang, task): data for lang, tasks in language_data.items() for task, data in tasks.items()}, orient="index"
)

# Set the multi-index with language and task
df.index = pd.MultiIndex.from_tuples(df.index, names=["Language", "Task"])

# Display the resulting DataFrame
print(df)
# Out:
#                finetune  reconstructed_featural
# Language Task
# ace      ner   0.209115                0.364238
# af       ner   0.634340                0.726658
#          pos   0.587463                0.715957
# als      ner   0.358047                0.606316
# am       ner   0.335260                0.367816
# ...                 ...                     ...
# tpn      pos   0.185121                0.131141
# wbp      pos   0.138507                0.133479
# wo       pos   0.146187                0.199334
# yue      pos   0.302430                0.335064
# ht       copa  0.486000                0.478000
#
# [237 rows x 2 columns]

# %%
# starting from `df` (index: Language, Task; columns: reconstructed_featural, finetune)

# 1) unstack the Task level into columns
df2 = df.unstack(level="Task")

# 2) swap the column levels so that Task is outer, metric is inner
df2.columns = df2.columns.swaplevel(0, 1)

# 3) sort by task name
df2 = df2.sort_index(axis=1, level=0)

# give the column-index levels names
df2.columns.names = ["Task", "Metric"]

# build a Boolean DataFrame: True where a metric is NaN
is_na = df2.isna()

# for each task, check if all its metrics are NaN
#    this gives a DataFrame of shape (n_langs, 4 tasks)
# Deprecated: missing_task = is_na.groupby(level='Task', axis=1).all()
missing_task = is_na.T.groupby(level="Task").all().T
# count how many tasks are completely missing per language
n_missing = missing_task.sum(axis=1)

# keep only languages with at most 2 missing tasks
filtered_df = df2[n_missing <= 1]

filtered_df
# Out:
# Task         copa                              ner                         \
# Metric   finetune reconstructed_featural  finetune reconstructed_featural
# Language
# ar            NaN                    NaN  0.230686               0.361266
# de            NaN                    NaN  0.599442               0.711901
# el            NaN                    NaN  0.511275               0.699429
# en            NaN                    NaN  0.765794               0.784810
# es            NaN                    NaN  0.564284               0.719115
# et          0.584                  0.564  0.551324               0.642795
# hi            NaN                    NaN  0.474167               0.641638
# id          0.578                  0.584  0.415720               0.476510
# it          0.566                  0.562  0.658940               0.735425
# ro            NaN                    NaN  0.578720               0.646164
# ru            NaN                    NaN  0.457403               0.609814
# ta          0.556                  0.556  0.121739               0.400606
# th          0.550                  0.578  0.001750               0.039036
# tr          0.550                  0.558  0.510366               0.596380
# vi          0.574                  0.584  0.610865               0.640354
# zh          0.596                  0.606  0.070803               0.188908
#
# Task           pos                               qa
# Metric    finetune reconstructed_featural  finetune reconstructed_featural
# Language
# ar        0.484426               0.544133  0.234367               0.674457
# de        0.693568               0.741805  0.610861               0.754284
# el        0.593793               0.606112  0.527849               0.728946
# en        0.824975               0.825468  0.811572               0.832839
# es        0.625690               0.679653  0.610574               0.754347
# et        0.500778               0.641825       NaN                    NaN
# hi        0.488472               0.576364  0.338192               0.685695
# id        0.657028               0.659888       NaN                    NaN
# it        0.546795               0.666174       NaN                    NaN
# ro        0.548537               0.662538  0.623874               0.789080
# ru        0.646551               0.652222  0.581985               0.743189
# ta        0.382951               0.395184       NaN                    NaN
# th        0.329178               0.355209  0.456854               0.691096
# tr        0.424006               0.529784  0.468949               0.679470
# vi        0.349651               0.372400  0.617961               0.737137
# zh        0.317503               0.230317  0.521021               0.654963

# %%
# 1) Compute per-column stats:
df_for_latex = filtered_df.rename(columns={"reconstructed_featural": r"reconstructed\_featural"}, level="Metric")

# 1) Compute per-column stats on the *renamed* DataFrame
col_stats = {}
for col in df_for_latex.columns:
    vals = df_for_latex[col].dropna().astype(float)
    mn, md, mx = vals.min(), float(np.median(vals)), vals.max()
    col_stats[col] = (mn, md, mx)

# 2) Build your formatters dict using exactly the same column keys
formatters = {}
for col, (mn, md, mx) in col_stats.items():
    """fmt = lambda x, mn=mn, md=md, mx=mx: (
        f"\\tgrad[{mn:.3f}][{md:.3f}][{mx:.3f}]{{{x:.3f}}}"
        if not pd.isna(x) else ""
    )"""

    def fmt(x, mn=mn, md=md, mx=mx):
        if pd.isna(x):
            return ""
        return f"\\tgrad[{mn:.3f}][{md:.3f}][{mx:.3f}]{{{x:.3f}}}"

    formatters[col] = fmt

# 3) Export to LaTeX
latex_table = df_for_latex.to_latex(
    escape=False,
    formatters=formatters,
    multirow=True,
)
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# Task & \multicolumn{2}{r}{copa} & \multicolumn{2}{r}{ner} & \multicolumn{2}{r}{pos} & \multicolumn{2}{r}{qa} \\
# Metric & finetune & reconstructed\_featural & finetune & reconstructed\_featural & finetune & reconstructed\_featural & finetune & reconstructed\_featural \\
# Language &  &  &  &  &  &  &  &  \\
# \midrule
# ar & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.231} & \tgrad[0.039][0.641][0.785]{0.361} & \tgrad[0.318][0.524][0.825]{0.484} & \tgrad[0.230][0.624][0.825]{0.544} & \tgrad[0.234][0.555][0.812]{0.234} & \tgrad[0.655][0.733][0.833]{0.674} \\
# de & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.599} & \tgrad[0.039][0.641][0.785]{0.712} & \tgrad[0.318][0.524][0.825]{0.694} & \tgrad[0.230][0.624][0.825]{0.742} & \tgrad[0.234][0.555][0.812]{0.611} & \tgrad[0.655][0.733][0.833]{0.754} \\
# el & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.511} & \tgrad[0.039][0.641][0.785]{0.699} & \tgrad[0.318][0.524][0.825]{0.594} & \tgrad[0.230][0.624][0.825]{0.606} & \tgrad[0.234][0.555][0.812]{0.528} & \tgrad[0.655][0.733][0.833]{0.729} \\
# en & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.766} & \tgrad[0.039][0.641][0.785]{0.785} & \tgrad[0.318][0.524][0.825]{0.825} & \tgrad[0.230][0.624][0.825]{0.825} & \tgrad[0.234][0.555][0.812]{0.812} & \tgrad[0.655][0.733][0.833]{0.833} \\
# es & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.564} & \tgrad[0.039][0.641][0.785]{0.719} & \tgrad[0.318][0.524][0.825]{0.626} & \tgrad[0.230][0.624][0.825]{0.680} & \tgrad[0.234][0.555][0.812]{0.611} & \tgrad[0.655][0.733][0.833]{0.754} \\
# et & \tgrad[0.550][0.570][0.596]{0.584} & \tgrad[0.556][0.571][0.606]{0.564} & \tgrad[0.002][0.511][0.766]{0.551} & \tgrad[0.039][0.641][0.785]{0.643} & \tgrad[0.318][0.524][0.825]{0.501} & \tgrad[0.230][0.624][0.825]{0.642} & NaN & NaN \\
# hi & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.474} & \tgrad[0.039][0.641][0.785]{0.642} & \tgrad[0.318][0.524][0.825]{0.488} & \tgrad[0.230][0.624][0.825]{0.576} & \tgrad[0.234][0.555][0.812]{0.338} & \tgrad[0.655][0.733][0.833]{0.686} \\
# id & \tgrad[0.550][0.570][0.596]{0.578} & \tgrad[0.556][0.571][0.606]{0.584} & \tgrad[0.002][0.511][0.766]{0.416} & \tgrad[0.039][0.641][0.785]{0.477} & \tgrad[0.318][0.524][0.825]{0.657} & \tgrad[0.230][0.624][0.825]{0.660} & NaN & NaN \\
# it & \tgrad[0.550][0.570][0.596]{0.566} & \tgrad[0.556][0.571][0.606]{0.562} & \tgrad[0.002][0.511][0.766]{0.659} & \tgrad[0.039][0.641][0.785]{0.735} & \tgrad[0.318][0.524][0.825]{0.547} & \tgrad[0.230][0.624][0.825]{0.666} & NaN & NaN \\
# ro & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.579} & \tgrad[0.039][0.641][0.785]{0.646} & \tgrad[0.318][0.524][0.825]{0.549} & \tgrad[0.230][0.624][0.825]{0.663} & \tgrad[0.234][0.555][0.812]{0.624} & \tgrad[0.655][0.733][0.833]{0.789} \\
# ru & NaN & NaN & \tgrad[0.002][0.511][0.766]{0.457} & \tgrad[0.039][0.641][0.785]{0.610} & \tgrad[0.318][0.524][0.825]{0.647} & \tgrad[0.230][0.624][0.825]{0.652} & \tgrad[0.234][0.555][0.812]{0.582} & \tgrad[0.655][0.733][0.833]{0.743} \\
# ta & \tgrad[0.550][0.570][0.596]{0.556} & \tgrad[0.556][0.571][0.606]{0.556} & \tgrad[0.002][0.511][0.766]{0.122} & \tgrad[0.039][0.641][0.785]{0.401} & \tgrad[0.318][0.524][0.825]{0.383} & \tgrad[0.230][0.624][0.825]{0.395} & NaN & NaN \\
# th & \tgrad[0.550][0.570][0.596]{0.550} & \tgrad[0.556][0.571][0.606]{0.578} & \tgrad[0.002][0.511][0.766]{0.002} & \tgrad[0.039][0.641][0.785]{0.039} & \tgrad[0.318][0.524][0.825]{0.329} & \tgrad[0.230][0.624][0.825]{0.355} & \tgrad[0.234][0.555][0.812]{0.457} & \tgrad[0.655][0.733][0.833]{0.691} \\
# tr & \tgrad[0.550][0.570][0.596]{0.550} & \tgrad[0.556][0.571][0.606]{0.558} & \tgrad[0.002][0.511][0.766]{0.510} & \tgrad[0.039][0.641][0.785]{0.596} & \tgrad[0.318][0.524][0.825]{0.424} & \tgrad[0.230][0.624][0.825]{0.530} & \tgrad[0.234][0.555][0.812]{0.469} & \tgrad[0.655][0.733][0.833]{0.679} \\
# vi & \tgrad[0.550][0.570][0.596]{0.574} & \tgrad[0.556][0.571][0.606]{0.584} & \tgrad[0.002][0.511][0.766]{0.611} & \tgrad[0.039][0.641][0.785]{0.640} & \tgrad[0.318][0.524][0.825]{0.350} & \tgrad[0.230][0.624][0.825]{0.372} & \tgrad[0.234][0.555][0.812]{0.618} & \tgrad[0.655][0.733][0.833]{0.737} \\
# zh & \tgrad[0.550][0.570][0.596]{0.596} & \tgrad[0.556][0.571][0.606]{0.606} & \tgrad[0.002][0.511][0.766]{0.071} & \tgrad[0.039][0.641][0.785]{0.189} & \tgrad[0.318][0.524][0.825]{0.318} & \tgrad[0.230][0.624][0.825]{0.230} & \tgrad[0.234][0.555][0.812]{0.521} & \tgrad[0.655][0.733][0.833]{0.655} \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Overview of scores per task and method

# %%
metrics = ["reconstructed_featural", "baseline_closest_featural", "no_train_gain", "finetune"]
tasks = ["ner", "pos", "copa", "qa"]
subsets = {
    "all": scores,
    "no_adapter": no_adapter,
    "with_adapter": scores_subset,
    "xlm_included": xlm_included,
    "xlm_not_included": xlm_not_included,
}
# Compute averages
records = []
for task in tasks:
    row = {"task": task}
    for subset_name, scores in subsets.items():
        langs = list(scores[task].keys())
        for metric in metrics:
            values = [scores[task][lang].get(metric, np.nan) for lang in langs]
            row[(subset_name, metric)] = np.nanmean(values) if values else np.nan
    records.append(row)

# Build DataFrame
index = [r["task"] for r in records]
columns = pd.MultiIndex.from_product([list(subsets.keys()), metrics], names=["Subset", "Metric"])
df_avg = pd.DataFrame(
    [[r[(subset, metric)] for subset in subsets for metric in metrics] for r in records], index=index, columns=columns
)
# for qa, we set all values in the "no_adapter" column to 0
df_avg.loc["qa", ("no_adapter", "reconstructed_featural")] = 0
df_avg.loc["qa", ("no_adapter", "baseline_closest_featural")] = 0
df_avg.loc["qa", ("no_adapter", "no_train_gain")] = 0
df_avg.loc["qa", ("no_adapter", "finetune")] = 0


# Display
df_avg.round(4)
# Out:
# Subset                    all                                          \
# Metric reconstructed_featural baseline_closest_featural no_train_gain
# ner                    0.4120                    0.3707        0.4073
# pos                    0.2409                    0.2211        0.2429
# copa                      NaN                       NaN           NaN
# qa                        NaN                       NaN           NaN
#
# Subset                      no_adapter                            \
# Metric finetune reconstructed_featural baseline_closest_featural
# ner      0.3246                 0.5052                    0.4136
# pos      0.1950                 0.4404                    0.4102
# copa        NaN                    NaN                       NaN
# qa          NaN                 0.0000                    0.0000
#
# Subset                                  with_adapter  \
# Metric no_train_gain finetune reconstructed_featural
# ner           0.4957   0.3969                 0.4875
# pos           0.4393   0.3671                 0.5564
# copa             NaN      NaN                 0.5498
# qa            0.0000   0.0000                 0.7215
#
# Subset                                                   \
# Metric baseline_closest_featural no_train_gain finetune
# ner                       0.5049        0.4839   0.3751
# pos                       0.5614        0.5624   0.5069
# copa                      0.5645        0.5493   0.5553
# qa                        0.7170        0.7202   0.5255
#
# Subset           xlm_included                                          \
# Metric reconstructed_featural baseline_closest_featural no_train_gain
# ner                    0.5518                    0.4689        0.5416
# pos                    0.5595                    0.5369        0.5596
# copa                   0.5498                    0.5645        0.5493
# qa                     0.7271                    0.7211        0.7253
#
# Subset                xlm_not_included                            \
# Metric finetune reconstructed_featural baseline_closest_featural
# ner      0.4311                 0.4120                    0.3707
# pos      0.4831                 0.2409                    0.2211
# copa     0.5553                    NaN                       NaN
# qa       0.5337                    NaN                       NaN
#
# Subset
# Metric no_train_gain finetune
# ner           0.4073   0.3246
# pos           0.2429   0.1950
# copa             NaN      NaN
# qa               NaN      NaN

# %%
df_table = df_avg.T
# 1) transpose so that Subset×Metric → rows, Tasks → columns
df_table.index.names = ["Subset", "Metric"]

# 2) escape the underscore in the one metric name
df_table = df_table.rename(index={"scores_subset": "with_adapter"}, level="Subset")

# 3) compute min/median/max for each Task‐column (for the gradient macro)
col_stats = {}

for task in df_table.columns:
    vals = df_table[task].dropna().astype(float)
    mn, md, mx = vals.min(), float(np.median(vals)), vals.max()
    col_stats[task] = (mn, md, mx)

# 4) build a formatter for each Task
formatters = {}
for task, (mn, md, mx) in col_stats.items():
    formatters[task] = (
        lambda mn, md, mx: lambda x: (f"\\tgrad[{mn:.3f}][{md:.3f}][{mx:.3f}]{{{x:.3f}}}" if not pd.isna(x) else "")
    )(mn, md, mx)

# 5) export to LaTeX, using multirow on the Subset level
latex = df_table.to_latex(escape=True, formatters=formatters, multirow=True)
print(latex)
# Out:
# \begin{tabular}{llrrrr}
# \toprule
#  &  & ner & pos & copa & qa \\
# Subset & Metric &  &  &  &  \\
# \midrule
# \multirow[t]{4}{*}{all} & reconstructed\_featural & \tgrad[0.325][0.413][0.552]{0.412} & \tgrad[0.195][0.425][0.562]{0.241} & NaN & NaN \\
#  & baseline\_closest\_featural & \tgrad[0.325][0.413][0.552]{0.371} & \tgrad[0.195][0.425][0.562]{0.221} & NaN & NaN \\
#  & no\_train\_gain & \tgrad[0.325][0.413][0.552]{0.407} & \tgrad[0.195][0.425][0.562]{0.243} & NaN & NaN \\
#  & finetune & \tgrad[0.325][0.413][0.552]{0.325} & \tgrad[0.195][0.425][0.562]{0.195} & NaN & NaN \\
# \cline{1-6}
# \multirow[t]{4}{*}{no\_adapter} & reconstructed\_featural & \tgrad[0.325][0.413][0.552]{0.505} & \tgrad[0.195][0.425][0.562]{0.440} & NaN & \tgrad[0.000][0.625][0.727]{0.000} \\
#  & baseline\_closest\_featural & \tgrad[0.325][0.413][0.552]{0.414} & \tgrad[0.195][0.425][0.562]{0.410} & NaN & \tgrad[0.000][0.625][0.727]{0.000} \\
#  & no\_train\_gain & \tgrad[0.325][0.413][0.552]{0.496} & \tgrad[0.195][0.425][0.562]{0.439} & NaN & \tgrad[0.000][0.625][0.727]{0.000} \\
#  & finetune & \tgrad[0.325][0.413][0.552]{0.397} & \tgrad[0.195][0.425][0.562]{0.367} & NaN & \tgrad[0.000][0.625][0.727]{0.000} \\
# \cline{1-6}
# \multirow[t]{4}{*}{with\_adapter} & reconstructed\_featural & \tgrad[0.325][0.413][0.552]{0.487} & \tgrad[0.195][0.425][0.562]{0.556} & \tgrad[0.549][0.553][0.565]{0.550} & \tgrad[0.000][0.625][0.727]{0.721} \\
#  & baseline\_closest\_featural & \tgrad[0.325][0.413][0.552]{0.505} & \tgrad[0.195][0.425][0.562]{0.561} & \tgrad[0.549][0.553][0.565]{0.565} & \tgrad[0.000][0.625][0.727]{0.717} \\
#  & no\_train\_gain & \tgrad[0.325][0.413][0.552]{0.484} & \tgrad[0.195][0.425][0.562]{0.562} & \tgrad[0.549][0.553][0.565]{0.549} & \tgrad[0.000][0.625][0.727]{0.720} \\
#  & finetune & \tgrad[0.325][0.413][0.552]{0.375} & \tgrad[0.195][0.425][0.562]{0.507} & \tgrad[0.549][0.553][0.565]{0.555} & \tgrad[0.000][0.625][0.727]{0.525} \\
# \cline{1-6}
# \multirow[t]{4}{*}{xlm\_included} & reconstructed\_featural & \tgrad[0.325][0.413][0.552]{0.552} & \tgrad[0.195][0.425][0.562]{0.560} & \tgrad[0.549][0.553][0.565]{0.550} & \tgrad[0.000][0.625][0.727]{0.727} \\
#  & baseline\_closest\_featural & \tgrad[0.325][0.413][0.552]{0.469} & \tgrad[0.195][0.425][0.562]{0.537} & \tgrad[0.549][0.553][0.565]{0.565} & \tgrad[0.000][0.625][0.727]{0.721} \\
#  & no\_train\_gain & \tgrad[0.325][0.413][0.552]{0.542} & \tgrad[0.195][0.425][0.562]{0.560} & \tgrad[0.549][0.553][0.565]{0.549} & \tgrad[0.000][0.625][0.727]{0.725} \\
#  & finetune & \tgrad[0.325][0.413][0.552]{0.431} & \tgrad[0.195][0.425][0.562]{0.483} & \tgrad[0.549][0.553][0.565]{0.555} & \tgrad[0.000][0.625][0.727]{0.534} \\
# \cline{1-6}
# \multirow[t]{4}{*}{xlm\_not\_included} & reconstructed\_featural & \tgrad[0.325][0.413][0.552]{0.412} & \tgrad[0.195][0.425][0.562]{0.241} & NaN & NaN \\
#  & baseline\_closest\_featural & \tgrad[0.325][0.413][0.552]{0.371} & \tgrad[0.195][0.425][0.562]{0.221} & NaN & NaN \\
#  & no\_train\_gain & \tgrad[0.325][0.413][0.552]{0.407} & \tgrad[0.195][0.425][0.562]{0.243} & NaN & NaN \\
#  & finetune & \tgrad[0.325][0.413][0.552]{0.325} & \tgrad[0.195][0.425][0.562]{0.195} & NaN & NaN \\
# \cline{1-6}
# \bottomrule
# \end{tabular}

# %%
# 3) compute min/median/max per Subset × Task
group_stats = {}
for subset in df_table.index.get_level_values("Subset").unique():
    df_sub = df_table.xs(subset, level="Subset").astype(float)
    group_stats[subset] = {}
    for task in df_table.columns:
        vals = df_sub[task].dropna()
        mn, md, mx = vals.min(), float(np.median(vals)), vals.max()
        group_stats[subset][task] = (mn, md, mx)

# 4) build a formatted copy of df_table
formatted = pd.DataFrame(index=df_table.index, columns=df_table.columns, dtype=object)
for (subset, metric), row in df_table.iterrows():
    for task, x in row.items():
        if pd.isna(x):
            formatted.at[(subset, metric), task] = ""
        else:
            mn, md, mx = group_stats[subset][task]
            formatted.at[(subset, metric), task] = f"\\tgrad[{mn:.3f}][{md:.3f}][{mx:.3f}]{{{x:.3f}}}"

# 5) export to LaTeX with multirow on the Subset level
latex = formatted.to_latex(escape=False, multirow=True)
print(latex)
# Out:
# \begin{tabular}{llllll}
# \toprule
#  &  & ner & pos & copa & qa \\
# Subset & Metric &  &  &  &  \\
# \midrule
# \multirow[t]{4}{*}{all} & reconstructed_featural & \tgrad[0.325][0.389][0.412]{0.412} & \tgrad[0.195][0.231][0.243]{0.241} &  &  \\
#  & baseline_closest_featural & \tgrad[0.325][0.389][0.412]{0.371} & \tgrad[0.195][0.231][0.243]{0.221} &  &  \\
#  & no_train_gain & \tgrad[0.325][0.389][0.412]{0.407} & \tgrad[0.195][0.231][0.243]{0.243} &  &  \\
#  & finetune & \tgrad[0.325][0.389][0.412]{0.325} & \tgrad[0.195][0.231][0.243]{0.195} &  &  \\
# \cline{1-6}
# \multirow[t]{4}{*}{no_adapter} & reconstructed_featural & \tgrad[0.397][0.455][0.505]{0.505} & \tgrad[0.367][0.425][0.440]{0.440} &  & \tgrad[0.000][0.000][0.000]{0.000} \\
#  & baseline_closest_featural & \tgrad[0.397][0.455][0.505]{0.414} & \tgrad[0.367][0.425][0.440]{0.410} &  & \tgrad[0.000][0.000][0.000]{0.000} \\
#  & no_train_gain & \tgrad[0.397][0.455][0.505]{0.496} & \tgrad[0.367][0.425][0.440]{0.439} &  & \tgrad[0.000][0.000][0.000]{0.000} \\
#  & finetune & \tgrad[0.397][0.455][0.505]{0.397} & \tgrad[0.367][0.425][0.440]{0.367} &  & \tgrad[0.000][0.000][0.000]{0.000} \\
# \cline{1-6}
# \multirow[t]{4}{*}{with_adapter} & reconstructed_featural & \tgrad[0.375][0.486][0.505]{0.487} & \tgrad[0.507][0.559][0.562]{0.556} & \tgrad[0.549][0.553][0.565]{0.550} & \tgrad[0.525][0.719][0.721]{0.721} \\
#  & baseline_closest_featural & \tgrad[0.375][0.486][0.505]{0.505} & \tgrad[0.507][0.559][0.562]{0.561} & \tgrad[0.549][0.553][0.565]{0.565} & \tgrad[0.525][0.719][0.721]{0.717} \\
#  & no_train_gain & \tgrad[0.375][0.486][0.505]{0.484} & \tgrad[0.507][0.559][0.562]{0.562} & \tgrad[0.549][0.553][0.565]{0.549} & \tgrad[0.525][0.719][0.721]{0.720} \\
#  & finetune & \tgrad[0.375][0.486][0.505]{0.375} & \tgrad[0.507][0.559][0.562]{0.507} & \tgrad[0.549][0.553][0.565]{0.555} & \tgrad[0.525][0.719][0.721]{0.525} \\
# \cline{1-6}
# \multirow[t]{4}{*}{xlm_included} & reconstructed_featural & \tgrad[0.431][0.505][0.552]{0.552} & \tgrad[0.483][0.548][0.560]{0.560} & \tgrad[0.549][0.553][0.565]{0.550} & \tgrad[0.534][0.723][0.727]{0.727} \\
#  & baseline_closest_featural & \tgrad[0.431][0.505][0.552]{0.469} & \tgrad[0.483][0.548][0.560]{0.537} & \tgrad[0.549][0.553][0.565]{0.565} & \tgrad[0.534][0.723][0.727]{0.721} \\
#  & no_train_gain & \tgrad[0.431][0.505][0.552]{0.542} & \tgrad[0.483][0.548][0.560]{0.560} & \tgrad[0.549][0.553][0.565]{0.549} & \tgrad[0.534][0.723][0.727]{0.725} \\
#  & finetune & \tgrad[0.431][0.505][0.552]{0.431} & \tgrad[0.483][0.548][0.560]{0.483} & \tgrad[0.549][0.553][0.565]{0.555} & \tgrad[0.534][0.723][0.727]{0.534} \\
# \cline{1-6}
# \multirow[t]{4}{*}{xlm_not_included} & reconstructed_featural & \tgrad[0.325][0.389][0.412]{0.412} & \tgrad[0.195][0.231][0.243]{0.241} &  &  \\
#  & baseline_closest_featural & \tgrad[0.325][0.389][0.412]{0.371} & \tgrad[0.195][0.231][0.243]{0.221} &  &  \\
#  & no_train_gain & \tgrad[0.325][0.389][0.412]{0.407} & \tgrad[0.195][0.231][0.243]{0.243} &  &  \\
#  & finetune & \tgrad[0.325][0.389][0.412]{0.325} & \tgrad[0.195][0.231][0.243]{0.195} &  &  \\
# \cline{1-6}
# \bottomrule
# \end{tabular}
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\stefa\anaconda3\envs\Thesis\Lib\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Scores presented on a map
# Not the most informative for analysis, but shows some info about which language families work better.

# %%
from huggingface_hub import HfApi
from qq import LanguageData

ld = LanguageData.from_db()

api = HfApi()
# Fetch all AdapterHub xlm-roberta-base adapters
models = api.list_models(author="AdapterHub", library="adapter-transformers", search="xlm-roberta-base-")
# we print all found models

to_load = {
    m.modelId: m.modelId.split("xlm-roberta-base-")[-1].rsplit("-wiki_pfeiffer", 1)[0]
    for m in models
    if m.modelId.startswith("AdapterHub/xlm-roberta-base-") and m.modelId.endswith("-wiki_pfeiffer")
}


def get_glots(iso_list):
    manuals = {
        "Arabic": "arab1267",
        "Swahili": "swah1253",
        "Bengali": "beng1282",
        "Chinese": "mand1415",
        "Persian": "west2369",
        "Yoruba": "ilaa1246",
        "Nepali": "nepa1254",
        "Quechua": "cusc1236",
        "Estonian": "esto1258",
        "Guarani": "east2555",
    }

    glots = {}
    probs = []

    for lang in iso_list:
        eng = ld.get(lang, tag_type=TagType.BCP_47_CODE).english_name
        glot = ld.get(lang, tag_type=TagType.BCP_47_CODE).glottocode
        # we need to find if glot is in distances
        if not glot:
            if eng in manuals.keys():
                glot = manuals[eng]
        if eng and glot:
            glots[eng] = (lang, glot)
        else:
            probs.append(lang)

    print("no glottocodes found for these languages: ", probs)

    return glots


glots = get_glots(to_load.values())
iso_list = []
iso_s = [scores[key].keys() for key in scores.keys()]


# iso_list = [scores[key].keys() for key in scores.keys()]
for el in iso_s:
    for iso in el:
        iso_list.append(iso)
eval_glots = get_glots(iso_list)
# Out:
# no glottocodes found for these languages:  []
# no glottocodes found for these languages:  ['az', 'mg', 'ms', 'or']

# %%
import geopandas as gpd


def load_and_preprocess_data(file_path, filter_languages=False):
    data = pd.read_csv(file_path)
    if filter_languages:
        # we map "ISO" to "script"
        data_f = data[data["ISO"].isin([lang[0] for lang in filter_languages])]
        # we map "ISO" to "script"
        # Create a new DataFrame with the 'script' column
        script_df = pd.DataFrame(data_f["ISO"].map({lang[0]: lang[1] for lang in filter_languages}), columns=["script"])
        # Use pd.concat to join the new DataFrame with the original DataFrame
        data = pd.concat([data_f, script_df], axis=1)
    data.replace("NaN", np.nan, inplace=True)
    df = data.set_index("WALS-ID").iloc[:, 10:]
    df.fillna(0, inplace=True)
    df_encoded = df.apply(lambda col: pd.factorize(col)[0] if col.dtypes == "O" else col)
    return data, df_encoded


data, df = load_and_preprocess_data("../typdiv-sampling/data/wals_dedup.csv")

# %%
# we check for all languages in glots if they are in the data
# we first check the glottocode, if that is not found we go to ISO
def get_geo_data(glots, data):
    geo_data = {}
    excluded = []
    for lang, codes in glots.items():
        iso, glot = codes
        if glot in data["Glottocode"].values:
            # print(f"{lang} is in the data with glot {glot}")
            geo_data[iso] = (
                data[data["Glottocode"] == glot]["Longitude"].values[0],
                data[data["Glottocode"] == glot]["Latitude"].values[0],
            )

        elif iso in data["ISO"].values:
            # print(f"{lang} is in the data with iso {iso}")
            geo_data[iso] = (
                data[data["ISO"] == iso]["Longitude"].values[0],
                data[data["ISO"] == iso]["Latitude"].values[0],
            )

        else:
            print(f"{lang} is not in the data")
            excluded.append(lang)
    return geo_data, excluded


geo_data_dict, excluded = get_geo_data(glots, data)
eval_geo_data_dict, eval_excluded = get_geo_data(eval_glots, data)
# Out:
# Indonesian is not in the data
# Tosk Albanian is not in the data
# Aragonese is not in the data
# Aymara is not in the data
# Corsican is not in the data
# Esperanto is not in the data
# Extremaduran is not in the data
# Friulian is not in the data
# Gan Chinese is not in the data
# Croatian is not in the data
# Indonesian is not in the data
# Kurmanji Kurdish is not in the data
# Lombard is not in the data
# Mongolian is not in the data
# Mirandese is not in the data
# Nepali is not in the data
# Norwegian Nynorsk is not in the data
# Ossetian is not in the data
# Pennsylvania German is not in the data
# Western Panjabi is not in the data
# Pashto is not in the data
# Sicilian is not in the data
# Scots is not in the data
# Albanian is not in the data
# Serbian is not in the data
# Silesian is not in the data
# Uzbek is not in the data
# Venetian is not in the data
# Vlaams is not in the data
# Walloon is not in the data
# Limburgan is not in the data
# Akuntsu is not in the data
# Russia Buriat is not in the data
# Mbyá Guaraní is not in the data
# Khunsari is not in the data
# Nayini is not in the data
# Livvi is not in the data
# Skolt Sami is not in the data
# Soi is not in the data

# %%
import matplotlib.colors as mcolors


def visualize_on_map(data, task, vis_column="unseen", save_path=None, training_vis=True):
    # Create a GeoDataFrame from the data
    gdf = gpd.GeoDataFrame(data, columns=data.columns, geometry=gpd.points_from_xy(data["Longitude"], data["Latitude"]))

    # Create a world map
    world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

    # Plot the world map
    fig, ax = plt.subplots(figsize=(15, 10))
    world.boundary.plot(ax=ax, linewidth=1, edgecolor="black", zorder=0)

    vmin = gdf[vis_column].min()
    vmax = gdf[vis_column].max()
    try:
        norm = mcolors.TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)  # Center at 0 for red-green mapping
        cmap = plt.get_cmap("RdYlGn")
    except ValueError:
        norm = mcolors.Normalize(vmin=vmin, vmax=vmax)  # No center for other cases (all pos or negative, for example)
        cmap = plt.get_cmap("Greens" if vmin >= 0 else "Reds")  # Choose a color map based on the range of values

    # 3. Choose a colormap (e.g. viridis, plasma, inferno, etc.)

    # 4. Create the plot
    # fig, ax = plt.subplots(figsize=(8, 8))

    # (Optional) Plot a light basemap or boundary first:
    # world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    # world.to_crs(gdf.crs).plot(ax=ax, color='lightgrey', edgecolor='white')

    # 5. Plot points colored by 'vis_column'
    gdf.plot(
        ax=ax,
        column=vis_column,
        cmap=cmap,
        norm=norm,
        markersize=20,  # adjust point size as needed
        edgecolor="k",  # black edge for better visibility
        linewidth=0.2,
        zorder=5,
    )
    # we add a colorbar
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    # we plot the colorbar, slightly smaller than the map
    cbar = plt.colorbar(sm, ax=ax, fraction=0.02, pad=0.04)
    cbar.set_label(vis_column)

    # add the training languages as red dots on top ("unseen" == 0)
    if training_vis:
        gdf[gdf["unseen"] == 0].plot(
            ax=ax, color="red", markersize=20, edgecolor="k", linewidth=0.2, zorder=6, label="Training Languages"
        )

    # 6. Add title and labels
    ax.set_title(f"Improvement relative to finetune baseline for {task}", fontsize=15)
    ax.set_xlabel("Longitude", fontsize=12)
    ax.set_ylabel("Latitude", fontsize=12)

    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=300)

    plt.show()

# %%
# we transform geo_data into a pandas dataframe with lang as index and longitude and latitude as columns
geo_data = pd.DataFrame.from_dict(geo_data_dict, orient="index", columns=["Longitude", "Latitude"])
eval_geo_data = pd.DataFrame.from_dict(eval_geo_data_dict, orient="index", columns=["Longitude", "Latitude"])
# we add a column 'train' and 'eval' to the dataframes and then join them
geo_data["unseen"] = 0
eval_geo_data["unseen"] = 1
geo_data["score"] = 0
vis_column = "score"

for task in ["ner", "pos", "copa", "qa"]:
    # we map the scores from "diffs" to the geo_data
    temp_geo_data = eval_geo_data.copy()
    for lang in temp_geo_data.index:
        if lang in scores[task].keys() and "reconstructed_featural" in scores[task][lang].keys():
            temp_geo_data.loc[lang, "score"] = (
                scores[task][lang]["reconstructed_featural"] - scores[task][lang]["finetune"]
            )
        else:
            # print("no data for", lang)
            continue

    joined_df = pd.concat([geo_data, temp_geo_data], axis=0)
    visualize_on_map(
        joined_df, task, vis_column=vis_column, save_path=f"../output/map_{task}_{vis_column}.png", training_vis=False
    )
# Out:
# C:\Users\stefa\AppData\Local\Temp\ipykernel_33504\1505694026.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# C:\Users\stefa\AppData\Local\Temp\ipykernel_33504\1505694026.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# C:\Users\stefa\AppData\Local\Temp\ipykernel_33504\1505694026.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# C:\Users\stefa\AppData\Local\Temp\ipykernel_33504\1505694026.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# # Score depending on featural distance to English

# %%
def typological_distance(target, glots):
    """
    This function takes a target language and a list of languages.
    It weights the other languages depending on their closeness to the target language.
    """

    # 1. retrieve closeness score of all languages to target language
    weights = {}
    probs = []
    for lang, codes in glots.items():
        iso, glot = codes
        # get the distance
        try:
            dist = u.new_distance("featural", [glot, target])
            # print(f"Distance {lang} to {target}: {dist}")
        except Exception as e:
            print(f"Error {e}: {lang} - {glot} - {target}")
            probs.append(lang)
        weights[iso] = dist
    # delete the problematic from glots
    for lang in probs:
        del glots[lang]

    return weights

# %%
import pickle

dist_glots = eval_glots.copy()
typ_dists = typological_distance(ld.get("en", TagType.BCP_47_CODE).glottocode, dist_glots)
# we save this as a pickle
with open("../pickles/typ_dists.pkl", "wb") as f:
    pickle.dump(typ_dists, f)
# Out:
# 2025-05-24 20:56:10,044 - root - ERROR - No shared featural features between astu1245 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,161 - root - ERROR - No shared featural features between kash1274 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# Error: Asturian - astu1245 - stan1293
# Error: Kashubian - kash1274 - stan1293
# 2025-05-24 20:56:10,397 - root - ERROR - No shared featural features between uppe1395 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,513 - root - ERROR - No shared featural features between kols1241 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,537 - root - ERROR - No shared featural features between ligu1248 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# Error: Upper Sorbian - uppe1395 - stan1293
# Error: Kölsch - kols1241 - stan1293
# Error: Ligurian - ligu1248 - stan1293
# 2025-05-24 20:56:10,636 - root - ERROR - No shared featural features between mira1251 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,679 - root - ERROR - No shared featural features between norw1262 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,714 - root - ERROR - No shared featural features between penn1240 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,726 - root - ERROR - No shared featural features between piem1238 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,844 - root - ERROR - No shared featural features between slov1269 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# Error: Mirandese - mira1251 - stan1293
# Error: Norwegian Nynorsk - norw1262 - stan1293
# Error: Pennsylvania German - penn1240 - stan1293
# Error: Piemontese - piem1238 - stan1293
# 2025-05-24 20:56:10,907 - root - ERROR - No shared featural features between sile1253 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:10,996 - root - ERROR - No shared featural features between vene1258 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,024 - root - ERROR - No shared featural features between wall1255 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,039 - root - ERROR - Unknown languages: yidd1255.
# Error: Slovak - slov1269 - stan1293
# Error: Silesian - sile1253 - stan1293
# Error: Venetian - vene1258 - stan1293
# Error: Walloon - wall1255 - stan1293
# 2025-05-24 20:56:11,061 - root - ERROR - No shared featural features between limb1263 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,064 - root - ERROR - No shared featural features between assy1241 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,067 - root - ERROR - No shared featural features between sout3123 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,145 - root - ERROR - No shared featural features between khun1255 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,168 - root - ERROR - No shared featural features between kare1335 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,196 - root - ERROR - No shared featural features between nayi1242 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# 2025-05-24 20:56:11,221 - root - ERROR - No shared featural features between soii1239 and stan1293 for which the two languages have information.
# Unable to calculate featural distance.
# Error: Yiddish - yidd1255 - stan1293
# Error: Limburgan - limb1263 - stan1293
# Error: Assyrian Neo-Aramaic - assy1241 - stan1293
# Error: South Levantine Arabic - sout3123 - stan1293
# Error: Khunsari - khun1255 - stan1293
# Error: Karelian - kare1335 - stan1293
# Error: Nayini - nayi1242 - stan1293
# Error: Soi - soii1239 - stan1293

# %%
# we define the diffs: the differences between the finetune and the reconstructed scores
tasks = ["ner", "pos", "copa", "qa"]
diffs = {task: {} for task in tasks}
for task in tasks:
    for lang in scores[task]:
        if "reconstructed_featural" in scores[task][lang].keys():
            if lang not in diffs[task].keys():
                diffs[task][lang] = {}
            diffs[task][lang]["improvement_finetune"] = (
                scores[task][lang]["reconstructed_featural"] - scores[task][lang]["finetune"]
            )
            diffs[task][lang]["improvement_madx"] = (
                scores[task][lang]["reconstructed_featural"] - scores[task][lang]["baseline_closest_featural"]
            )
            diffs[task][lang]["madx_baseline_en"] = (
                scores[task][lang]["baseline_closest_featural"] - scores[task][lang]["baseline_en"]
            )
        else:
            # print(f"{lang} not in diffs")
            continue

# %%
# we plot the distance to the difference in score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# we create a dataframe with the distance and the score for each task
dfs = {}
for task in tasks:
    df = pd.DataFrame.from_dict(typ_dists, orient="index", columns=["similarity"])
    # we map the "diff"
    for lang in df.index:
        if lang not in scores_subset[task].keys():
            df.drop(lang, inplace=True)
        elif lang in diffs[task].keys():
            df.loc[lang, "score"] = diffs[task][lang]["madx_baseline_en"]
        else:
            # print(f"{lang} not in diffs")
            # we remove the lang from the geo_data
            df.drop(lang, inplace=True)
    # we add the task as a column
    df["task"] = task
    dfs[task] = df
# we join the dataframes into one
df = pd.concat(dfs.values(), axis=0)

# we visualize
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="similarity", y="score", hue="task")
plt.title("MAD-X improvement vs Distance to English")
plt.xlabel("Distance to English")
plt.ylabel("Target-language improvement over English adapter")
plt.grid()
plt.show()

# %%
# we print the distance for the lowest similarity language for qa
lowest_similarity = df[df["task"] == "qa"].sort_values(by="similarity").iloc[0]
print(f"Lowest similarity language for QA: {lowest_similarity.name}")
# Out:
# Lowest similarity language for QA: en

# %%
# we plot the distance to the difference in score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# we create a dataframe with the distance and the score
df = pd.DataFrame.from_dict(typ_dists, orient="index", columns=["similarity"])
# we map the "diff"
for lang in df.index:
    if lang in diffs.keys():
        df.loc[lang, "score"] = diffs[lang]["improvement_finetune"]
    else:
        print(f"{lang} not in diffs")
        # we remove the lang from the geo_data
        df.drop(lang, inplace=True)

# we visualize
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="similarity", y="score")
plt.title("Similarity to English vs Score")
plt.xlabel("Similarity to English")
plt.ylabel("Score")
plt.grid()
plt.show()

# %% [markdown]
# # Min distance
# For each language, check what the minimal distance to a training included language is

# %%
import pickle

# we have calculated this before and saved as a pickle
# only calculate again if this has not happened
pickle_paths = ["../pickles/min_dists.pkl", "../pickles/max_dists.pkl"]
if os.path.exists(pickle_paths[0]) and os.path.exists(pickle_paths[1]):
    with open(pickle_paths[0], "rb") as f:
        min_dists = pickle.load(f)
    with open(pickle_paths[1], "rb") as f:
        max_dists = pickle.load(f)
else:
    min_dists = {eval_glot[1]: 1 for eval_glot in eval_glots.values()}
    max_dists = {eval_glot[1]: 0 for eval_glot in eval_glots.values()}
    all_dists = {eval_glot[1]: [] for eval_glot in eval_glots.values()}
    for key, value in min_dists.items():
        min_dist = value
        max_dist = max_dists[key]
        for glot in glots.values():
            try:
                dist = u.new_distance("featural", [glot[1], key])
                # print(dist)
                all_dists[key].append((glot[0], dist))
            except Exception:
                dist = False
                # print(e)
            except SystemExit:
                dist = False

            if dist:
                min_dist = min(min_dist, dist)
                max_dist = max(max_dist, dist)
        min_dists[key] = min_dist
        max_dists[key] = max_dist

    # we save this to a pickle and load it in later
    with open("../pickles/min_dists.pkl", "wb") as f:
        pickle.dump(min_dists, f)
    with open("../pickles/max_dists.pkl", "wb") as f:
        pickle.dump(max_dists, f)

# %%
average_distance = {}
for lang, distances in all_dists.items():
    if distances:
        average = sum([distance[1] for distance in distances]) / len(distances)
        average_distance[lang] = average
    else:
        average_distance[lang] = 0

# %%
minima = {ev[0]: min_dists[ev[1]] for ev in eval_glots.values()}
maxima = {ev[0]: max_dists[ev[1]] for ev in eval_glots.values()}
avs = {ev[0]: average_distance[ev[1]] for ev in eval_glots.values()}
distance_types = {"Minimum_train_dist": minima, "Maximum_train_dist": maxima, "Average_train_dist": avs}
# we create a dataframe with the distance and the score
for name, distance_type in distance_types.items():
    df = pd.DataFrame.from_dict(distance_type, orient="index", columns=["distance"])
    # we map the "diff"
    for lang in df.index:
        if lang in diffs.keys():
            df.loc[lang, "score"] = diffs[lang]["improvement_finetune"]
        else:
            # print(f"{lang} not in diffs")
            # we remove the lang from the geo_data
            df.drop(lang, inplace=True)

    # we visualize
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x="distance", y="score")
    plt.title(f"{name} to adapters vs improvement over finetune")
    plt.xlabel(name)
    plt.ylabel("Score")
    plt.grid()
    plt.savefig(f"../output/{name}_distance_train.png", bbox_inches="tight", dpi=300)
    plt.show()

# %% [markdown]
# # Score in function of token overlap

# %%
token_overlap = {}
for file in os.listdir("../data/token_overlap"):
    if file.endswith(".json"):
        try:
            with open(os.path.join("../data/token_overlap", file), "r") as f:
                data = json.load(f)
                file_name = file.split(".")[0]
                els = file_name.split("_")
                task = els[0]
                token_overlap[task] = {}
                for lang, values in data.items():
                    if lang not in token_overlap[task].keys():
                        token_overlap[task][lang] = {}
                    for key, value in values.items():
                        if key == "token_coverage":
                            token_overlap[task][lang]["token_coverage"] = value
                        elif key == "type_overlap":
                            token_overlap[task][lang]["type_overlap"] = value

        except json.JSONDecodeError:
            print(f"Error decoding JSON for file: {file}")
        except KeyError:
            print("KeyError:", file)

# %%
scores["ner"]
# Out:
# {'ace': {'finetune': 0.20911528150134046,
#   'reconstructed_featural_base': 0.3624595469255664,
#   'reconstructed_syntactic_distVar': 0.36065573770491804,
#   'reconstructed_morphological_distVar': 0.36303630363036304,
#   'reconstructed_featural_eu': 0.3514376996805112,
#   'reconstructed_featural': 0.36423841059602646,
#   'baseline_en': 0.3344262295081967,
#   'baseline_task_adapter': 0.33333333333333337,
#   'baseline_avg_adapter': 0.27272727272727276,
#   'baseline_closest_featural': 0.3958333333333333,
#   'no_train_gain': 0.3879598662207358,
#   'reconstructed_featural_limit': 0.3576158940397351,
#   'reconstructed_syntactic_limit': 0.36423841059602646,
#   'reconstructed_morphological_limit': 0.3931034482758621,
#   'reconstructed_featural_sr': 0.3525641025641026,
#   'reconstructed_featural_threshold': 0.3612903225806452,
#   'reconstructed_syntactic_threshold': 0.36774193548387096,
#   'reconstructed_morphological_threshold': 0.3673469387755102},
#  'af': {'finetune': 0.6343397377249161,
#   'reconstructed_featural_base': 0.7264325323475046,
#   'reconstructed_featural_eu': 0.7276084949215142,
#   'reconstructed_featural': 0.7266584766584767,
#   'baseline_en': 0.7029702970297029,
#   'baseline_task_adapter': 0.6938031591737547,
#   'baseline_avg_adapter': 0.6690163409163731,
#   'baseline_closest_featural': 0.6592661116250385,
#   'no_train_gain': 0.7144607843137256,
#   'reconstructed_featural_sr': 0.724593183911575,
#   'reconstructed_featural_threshold': 0.7266563944530045,
#   'reconstructed_syntactic_threshold': 0.7302469135802468,
#   'reconstructed_morphological_threshold': 0.7268247613181397},
#  'als': {'finetune': 0.35804701627486435,
#   'reconstructed_featural_base': 0.59915611814346,
#   'reconstructed_syntactic_distVar': 0.602510460251046,
#   'reconstructed_morphological_distVar': 0.606694560669456,
#   'reconstructed_featural_eu': 0.5945945945945946,
#   'reconstructed_featural': 0.6063157894736841,
#   'baseline_en': 0.5872340425531913,
#   'baseline_task_adapter': 0.5904365904365905,
#   'baseline_avg_adapter': 0.5277777777777778,
#   'baseline_closest_featural': 0.5678496868475991,
#   'no_train_gain': 0.5865580448065173,
#   'reconstructed_featural_limit': 0.6090534979423867,
#   'reconstructed_syntactic_limit': 0.6208333333333333,
#   'reconstructed_morphological_limit': 0.5654008438818565,
#   'reconstructed_featural_sr': 0.602510460251046,
#   'reconstructed_featural_threshold': 0.5966386554621848,
#   'reconstructed_syntactic_threshold': 0.5862785862785862,
#   'reconstructed_morphological_threshold': 0.5929018789144049},
#  'am': {'finetune': 0.3352601156069364,
#   'reconstructed_featural_base': 0.3692307692307692,
#   'reconstructed_syntactic_distVar': 0.3622641509433962,
#   'reconstructed_morphological_distVar': 0.3650190114068441,
#   'reconstructed_featural_eu': 0.3706563706563707,
#   'reconstructed_featural': 0.36781609195402293,
#   'baseline_en': 0.25274725274725274,
#   'baseline_task_adapter': 0.31939163498098866,
#   'baseline_avg_adapter': 0.32888888888888884,
#   'baseline_closest_featural': 0.1588785046728972,
#   'no_train_gain': 0.36293436293436293,
#   'reconstructed_featural_limit': 0.36718749999999994,
#   'reconstructed_syntactic_limit': 0.37500000000000006,
#   'reconstructed_morphological_limit': 0.37984496124031003,
#   'reconstructed_featural_sr': 0.3692307692307692,
#   'reconstructed_featural_threshold': 0.37500000000000006,
#   'reconstructed_syntactic_threshold': 0.3706563706563707,
#   'reconstructed_morphological_threshold': 0.3726235741444867},
#  'an': {'finetune': 0.6336805555555555,
#   'reconstructed_featural_base': 0.7225042301184433,
#   'reconstructed_featural_eu': 0.7278940623665101,
#   'reconstructed_featural': 0.7256486601446195,
#   'baseline_en': 0.7181236673773987,
#   'baseline_task_adapter': 0.7067348678601875,
#   'baseline_avg_adapter': 0.6374193548387097,
#   'baseline_closest_featural': 0.7066836951894423,
#   'no_train_gain': 0.7247863247863248,
#   'reconstructed_featural_sr': 0.7221750212404419,
#   'reconstructed_featural_threshold': 0.7254150702426564,
#   'reconstructed_syntactic_threshold': 0.7258064516129034,
#   'reconstructed_morphological_threshold': 0.7258064516129034},
#  'arz': {'finetune': 0.2510460251046025,
#   'reconstructed_featural_base': 0.44280442804428044,
#   'reconstructed_syntactic_distVar': 0.46494464944649444,
#   'reconstructed_morphological_distVar': 0.46153846153846156,
#   'reconstructed_featural_eu': 0.46494464944649444,
#   'reconstructed_featural': 0.46153846153846156,
#   'baseline_en': 0.26285714285714284,
#   'baseline_task_adapter': 0.393574297188755,
#   'baseline_avg_adapter': 0.3513513513513513,
#   'baseline_closest_featural': 0.3706563706563706,
#   'no_train_gain': 0.4644194756554307,
#   'reconstructed_featural_limit': 0.450381679389313,
#   'reconstructed_syntactic_limit': 0.4534412955465587,
#   'reconstructed_morphological_limit': 0.41379310344827586,
#   'reconstructed_featural_sr': 0.46494464944649444,
#   'reconstructed_featural_threshold': 0.4338235294117647,
#   'reconstructed_syntactic_threshold': 0.44015444015444016,
#   'reconstructed_morphological_threshold': 0.4486692015209126},
#  'ar': {'finetune': 0.23068599870157974,
#   'reconstructed_featural_base': 0.36324417601380504,
#   'reconstructed_syntactic_distVar': 0.36078400688548956,
#   'reconstructed_morphological_distVar': 0.36224050137093616,
#   'reconstructed_featural_eu': 0.36205341385936707,
#   'reconstructed_featural': 0.3612655650403321,
#   'baseline_en': 0.2433960213066638,
#   'baseline_task_adapter': 0.31499051233396586,
#   'baseline_avg_adapter': 0.28210526315789475,
#   'baseline_closest_featural': 0.3594857810673938,
#   'no_train_gain': 0.3301346732012685,
#   'reconstructed_featural_limit': 0.36805260104428544,
#   'reconstructed_syntactic_limit': 0.368191131557583,
#   'reconstructed_morphological_limit': 0.3701895128473433,
#   'reconstructed_featural_sr': 0.3621108758723437,
#   'reconstructed_featural_threshold': 0.36305434103685197,
#   'reconstructed_syntactic_threshold': 0.36265569826549227,
#   'reconstructed_morphological_threshold': 0.36497956617415905},
#  'ast': {'finetune': 0.6742289968096421,
#   'reconstructed_featural_threshold': 0.7892246086639971,
#   'reconstructed_syntactic_threshold': 0.7892246086639971,
#   'reconstructed_morphological_threshold': 0.7892246086639971},
#  'as': {'finetune': 0.09929078014184398,
#   'reconstructed_featural_base': 0.4351464435146444,
#   'reconstructed_featural_eu': 0.46086956521739136,
#   'reconstructed_featural': 0.45,
#   'baseline_en': 0.1954022988505747,
#   'baseline_task_adapter': 0.3220338983050848,
#   'baseline_avg_adapter': 0.1789473684210526,
#   'baseline_closest_featural': 0.04878048780487805,
#   'no_train_gain': 0.3689320388349515,
#   'reconstructed_featural_sr': 0.46086956521739136,
#   'reconstructed_featural_threshold': 0.4416666666666666,
#   'reconstructed_syntactic_threshold': 0.4730290456431535,
#   'reconstructed_morphological_threshold': 0.44635193133047213},
#  'ay': {'finetune': 0.2766798418972332,
#   'reconstructed_featural_base': 0.36123348017621143,
#   'reconstructed_featural_eu': 0.35555555555555557,
#   'reconstructed_featural': 0.3508771929824561,
#   'baseline_en': 0.39631336405529954,
#   'baseline_task_adapter': 0.15261044176706828,
#   'baseline_avg_adapter': 0.13513513513513511,
#   'baseline_closest_featural': 0.3859649122807018,
#   'no_train_gain': 0.3605150214592275,
#   'reconstructed_featural_sr': 0.35555555555555557,
#   'reconstructed_featural_threshold': 0.3596491228070175,
#   'reconstructed_syntactic_threshold': 0.35807860262008734,
#   'reconstructed_morphological_threshold': 0.3596491228070175},
#  'az': {'finetune': 0.4686629526462396,
#   'reconstructed_featural_threshold': 0.47547169811320755,
#   'reconstructed_syntactic_threshold': 0.47547169811320755,
#   'reconstructed_morphological_threshold': 0.47547169811320755},
#  'bar': {'finetune': 0.5429864253393665,
#   'reconstructed_featural_base': 0.5258620689655172,
#   'reconstructed_featural_eu': 0.5414847161572052,
#   'reconstructed_featural': 0.543859649122807,
#   'baseline_en': 0.5253456221198157,
#   'baseline_task_adapter': 0.5504587155963303,
#   'baseline_avg_adapter': 0.5196078431372549,
#   'baseline_closest_featural': 0.7389162561576355,
#   'no_train_gain': 0.5040650406504065,
#   'reconstructed_featural_sr': 0.5414847161572052,
#   'reconstructed_featural_threshold': 0.5321888412017167,
#   'reconstructed_syntactic_threshold': 0.5276595744680851,
#   'reconstructed_morphological_threshold': 0.5258620689655172},
#  'ba': {'finetune': 0.19819819819819817,
#   'reconstructed_featural_base': 0.25641025641025644,
#   'reconstructed_syntactic_distVar': 0.24000000000000002,
#   'reconstructed_morphological_distVar': 0.24223602484472048,
#   'reconstructed_featural_eu': 0.2476780185758514,
#   'reconstructed_featural': 0.23780487804878053,
#   'baseline_en': 0.2434782608695652,
#   'baseline_task_adapter': 0.22435897435897434,
#   'baseline_avg_adapter': 0.20168067226890757,
#   'baseline_closest_featural': 0.17454545454545456,
#   'no_train_gain': 0.24832214765100674,
#   'reconstructed_featural_limit': 0.2784810126582279,
#   'reconstructed_syntactic_limit': 0.28205128205128205,
#   'reconstructed_morphological_limit': 0.255591054313099,
#   'reconstructed_featural_sr': 0.2507836990595611,
#   'reconstructed_featural_threshold': 0.268370607028754,
#   'reconstructed_syntactic_threshold': 0.26332288401253917,
#   'reconstructed_morphological_threshold': 0.26366559485530544},
#  'be': {'finetune': 0.5784735812133072,
#   'reconstructed_featural_base': 0.693354061406918,
#   'reconstructed_syntactic_distVar': 0.6833590138674884,
#   'reconstructed_morphological_distVar': 0.6826070188970306,
#   'reconstructed_featural_eu': 0.6917409848778596,
#   'reconstructed_featural': 0.6823257604928764,
#   'baseline_en': 0.5907769007062734,
#   'baseline_task_adapter': 0.5539033457249071,
#   'baseline_avg_adapter': 0.49807840122982316,
#   'baseline_closest_featural': 0.5692425401683244,
#   'no_train_gain': 0.6600609756097561,
#   'reconstructed_featural_limit': 0.7273440564927423,
#   'reconstructed_syntactic_limit': 0.7209393346379649,
#   'reconstructed_morphological_limit': 0.7171283651970347,
#   'reconstructed_featural_sr': 0.6883468834688347,
#   'reconstructed_featural_threshold': 0.7013592233009709,
#   'reconstructed_syntactic_threshold': 0.6950464396284829,
#   'reconstructed_morphological_threshold': 0.6983261969637992},
#  'bg': {'finetune': 0.6223759294483832,
#   'reconstructed_featural_base': 0.7437472722999966,
#   'reconstructed_featural_eu': 0.7415428973748617,
#   'reconstructed_featural': 0.7424486508256142,
#   'baseline_en': 0.6946546253356114,
#   'baseline_task_adapter': 0.6974208986971551,
#   'baseline_avg_adapter': 0.6352724544772557,
#   'baseline_closest_featural': 0.713845535534865,
#   'no_train_gain': 0.7363134103465594,
#   'reconstructed_featural_sr': 0.7417591630059354,
#   'reconstructed_featural_threshold': 0.7437223042836041,
#   'reconstructed_syntactic_threshold': 0.7431660957754046,
#   'reconstructed_morphological_threshold': 0.7435458421459026},
#  'bn': {'finetune': 0.28039557882489813,
#   'reconstructed_featural_base': 0.5927209705372617,
#   'reconstructed_featural_eu': 0.5903197925669836,
#   'reconstructed_featural': 0.5791274593669803,
#   'baseline_en': 0.3659942363112392,
#   'baseline_task_adapter': 0.47750000000000004,
#   'baseline_avg_adapter': 0.3470115967885817,
#   'baseline_closest_featural': 0.12355212355212357,
#   'no_train_gain': 0.5322723253757737,
#   'reconstructed_featural_sr': 0.5873221216041397,
#   'reconstructed_featural_threshold': 0.5939393939393939,
#   'reconstructed_syntactic_threshold': 0.5985275010827199,
#   'reconstructed_morphological_threshold': 0.5927209705372617},
#  'bo': {'finetune': 0.0,
#   'reconstructed_featural_base': 0.0,
#   'reconstructed_syntactic_distVar': 0.0,
#   'reconstructed_morphological_distVar': 0.0,
#   'reconstructed_featural_eu': 0.0,
#   'reconstructed_featural': 0.0,
#   'baseline_en': 0.0,
#   'baseline_task_adapter': 0.0,
#   'baseline_avg_adapter': 0.0,
#   'baseline_closest_featural': 0.04790419161676647,
#   'no_train_gain': 0.07246376811594202,
#   'reconstructed_featural_limit': 0.0,
#   'reconstructed_syntactic_limit': 0.0,
#   'reconstructed_morphological_limit': 0.0,
#   'reconstructed_featural_sr': 0.0,
#   'reconstructed_featural_threshold': 0.0,
#   'reconstructed_syntactic_threshold': 0.0,
#   'reconstructed_morphological_threshold': 0.0},
#  'br': {'finetune': 0.45170257123002083,
#   'reconstructed_featural_base': 0.5422781271837875,
#   'reconstructed_syntactic_distVar': 0.5331482124262408,
#   'reconstructed_morphological_distVar': 0.5276243093922651,
#   'reconstructed_featural_eu': 0.5350451075641915,
#   'reconstructed_featural': 0.5298196948682385,
#   'baseline_en': 0.4987531172069826,
#   'baseline_task_adapter': 0.4680123161135819,
#   'baseline_avg_adapter': 0.4069940476190476,
#   'baseline_closest_featural': 0.42120343839541546,
#   'no_train_gain': 0.5145526410348544,
#   'reconstructed_featural_limit': 0.5437589670014347,
#   'reconstructed_syntactic_limit': 0.5443037974683543,
#   'reconstructed_morphological_limit': 0.541711040113596,
#   'reconstructed_featural_sr': 0.5348112227225494,
#   'reconstructed_featural_threshold': 0.5433566433566434,
#   'reconstructed_syntactic_threshold': 0.5356026398054881,
#   'reconstructed_morphological_threshold': 0.5407512402551381},
#  'bs': {'finetune': 0.6197183098591549,
#   'reconstructed_featural_base': 0.6264229044498103,
#   'reconstructed_featural_eu': 0.6228944654520453,
#   'reconstructed_featural': 0.631288766368022,
#   'baseline_en': 0.6408450704225352,
#   'baseline_task_adapter': 0.620973269362577,
#   'baseline_avg_adapter': 0.6063446286950254,
#   'baseline_closest_featural': 0.6201716738197425,
#   'no_train_gain': 0.6512270998963015,
#   'reconstructed_featural_sr': 0.6259910375732506,
#   'reconstructed_featural_threshold': 0.6322714681440443,
#   'reconstructed_syntactic_threshold': 0.6322714681440443,
#   'reconstructed_morphological_threshold': 0.6271127975163849},
#  'ca': {'finetune': 0.7128168838196728,
#   'reconstructed_featural_base': 0.7885331347728964,
#   'reconstructed_syntactic_distVar': 0.781798697551727,
#   'reconstructed_morphological_distVar': 0.7838328792007266,
#   'reconstructed_featural_eu': 0.7846617410327321,
#   'reconstructed_featural': 0.7824939157695003,
#   'baseline_en': 0.7902094966203451,
#   'baseline_task_adapter': 0.716385100753104,
#   'baseline_avg_adapter': 0.6547777040477769,
#   'baseline_closest_featural': 0.7895505571088761,
#   'no_train_gain': 0.8033122830496424,
#   'reconstructed_featural_limit': 0.8019954271461235,
#   'reconstructed_syntactic_limit': 0.8017624807748265,
#   'reconstructed_morphological_limit': 0.7906299409170342,
#   'reconstructed_featural_sr': 0.7841875051580424,
#   'reconstructed_featural_threshold': 0.7884129939995862,
#   'reconstructed_syntactic_threshold': 0.789195002895673,
#   'reconstructed_morphological_threshold': 0.7929603187780176},
#  'cdo': {'finetune': 0.09577464788732394,
#   'reconstructed_featural_base': 0.13559322033898305,
#   'reconstructed_featural_eu': 0.13157894736842105,
#   'reconstructed_featural': 0.12459016393442622,
#   'baseline_en': 0.11764705882352941,
#   'baseline_task_adapter': 0.10982658959537571,
#   'baseline_avg_adapter': 0.10572687224669604,
#   'baseline_closest_featural': 0.2463768115942029,
#   'no_train_gain': 0.11904761904761905,
#   'reconstructed_featural_sr': 0.13114754098360656,
#   'reconstructed_featural_threshold': 0.13745704467353953,
#   'reconstructed_syntactic_threshold': 0.13377926421404682,
#   'reconstructed_morphological_threshold': 0.13377926421404682},
#  'ceb': {'finetune': 0.34131736526946105,
#   'reconstructed_featural_base': 0.44525547445255476,
#   'reconstructed_syntactic_distVar': 0.4295774647887324,
#   'reconstructed_morphological_distVar': 0.4326241134751773,
#   'reconstructed_featural_eu': 0.431095406360424,
#   'reconstructed_featural': 0.42704626334519574,
#   'baseline_en': 0.47482014388489213,
#   'baseline_task_adapter': 0.43884892086330934,
#   'baseline_avg_adapter': 0.37344398340248963,
#   'baseline_closest_featural': 0.5156249999999999,
#   'no_train_gain': 0.43448275862068964,
#   'reconstructed_featural_limit': 0.50187265917603,
#   'reconstructed_syntactic_limit': 0.5230769230769231,
#   'reconstructed_morphological_limit': 0.4412811387900356,
#   'reconstructed_featural_sr': 0.431095406360424,
#   'reconstructed_featural_threshold': 0.4525547445255475,
#   'reconstructed_syntactic_threshold': 0.46715328467153283,
#   'reconstructed_morphological_threshold': 0.4398625429553264},
#  'ce': {'finetune': 0.13138686131386862,
#   'reconstructed_featural_base': 0.14207650273224043,
#   'reconstructed_syntactic_distVar': 0.15083798882681562,
#   'reconstructed_morphological_distVar': 0.14207650273224043,
#   'reconstructed_featural_eu': 0.1432506887052342,
#   'reconstructed_featural': 0.15,
#   'baseline_en': 0.05617977528089887,
#   'baseline_task_adapter': 0.14141414141414144,
#   'baseline_avg_adapter': 0.10089020771513355,
#   'baseline_closest_featural': 0.10725552050473187,
#   'no_train_gain': 0.13736263736263737,
#   'reconstructed_featural_limit': 0.15384615384615385,
#   'reconstructed_syntactic_limit': 0.15384615384615385,
#   'reconstructed_morphological_limit': 0.1452513966480447,
#   'reconstructed_featural_sr': 0.14917127071823202,
#   'reconstructed_featural_threshold': 0.14713896457765668,
#   'reconstructed_syntactic_threshold': 0.15512465373961218,
#   'reconstructed_morphological_threshold': 0.14084507042253522},
#  'ckb': {'finetune': 0.060418280402788536,
#   'reconstructed_featural_base': 0.17376681614349776,
#   'reconstructed_syntactic_distVar': 0.17853231106243156,
#   'reconstructed_morphological_distVar': 0.19236969371305748,
#   'reconstructed_featural_eu': 0.17391304347826086,
#   'reconstructed_featural': 0.17853231106243156,
#   'baseline_en': 0.03697749196141478,
#   'baseline_task_adapter': 0.0781869688385269,
#   'baseline_avg_adapter': 0.010480349344978166,
#   'baseline_closest_featural': 0.05241521068859198,
#   'no_train_gain': 0.09640024405125076,
#   'reconstructed_featural_limit': 0.19815668202764977,
#   'reconstructed_syntactic_limit': 0.18202764976958524,
#   'reconstructed_morphological_limit': 0.1951219512195122,
#   'reconstructed_featural_sr': 0.17347509792949078,
#   'reconstructed_featural_threshold': 0.20566981656475822,
#   'reconstructed_syntactic_threshold': 0.22637362637362637,
#   'reconstructed_morphological_threshold': 0.19318759532282664},
#  'co': {'finetune': 0.48605577689243024,
#   'reconstructed_featural_base': 0.5349794238683128,
#   'reconstructed_syntactic_distVar': 0.5101214574898786,
#   'reconstructed_morphological_distVar': 0.5203252032520325,
#   'reconstructed_featural_eu': 0.5267489711934156,
#   'reconstructed_featural': 0.5121951219512195,
#   'baseline_en': 0.5102880658436213,
#   'baseline_task_adapter': 0.4398340248962656,
#   'baseline_avg_adapter': 0.42592592592592593,
#   'baseline_closest_featural': 0.5446808510638298,
#   'no_train_gain': 0.4800000000000001,
#   'reconstructed_featural_limit': 0.5126050420168067,
#   'reconstructed_syntactic_limit': 0.5,
#   'reconstructed_morphological_limit': 0.5062240663900415,
#   'reconstructed_featural_sr': 0.5245901639344263,
#   'reconstructed_featural_threshold': 0.5378151260504201,
#   'reconstructed_syntactic_threshold': 0.5371900826446281,
#   'reconstructed_morphological_threshold': 0.5338983050847459},
#  'crh': {'finetune': 0.3419354838709678,
#   'reconstructed_featural_base': 0.3636363636363636,
#   'reconstructed_syntactic_distVar': 0.343859649122807,
#   'reconstructed_morphological_distVar': 0.35789473684210527,
#   'reconstructed_featural_eu': 0.3745583038869258,
#   'reconstructed_featural': 0.3484320557491289,
#   'baseline_en': 0.37142857142857144,
#   'baseline_task_adapter': 0.2939068100358423,
#   'baseline_avg_adapter': 0.2122448979591837,
#   'baseline_closest_featural': 0.3221476510067114,
#   'no_train_gain': 0.3806228373702422,
#   'reconstructed_featural_limit': 0.3448275862068966,
#   'reconstructed_syntactic_limit': 0.3448275862068966,
#   'reconstructed_morphological_limit': 0.36678200692041524,
#   'reconstructed_featural_sr': 0.3636363636363636,
#   'reconstructed_featural_threshold': 0.3617021276595745,
#   'reconstructed_syntactic_threshold': 0.381294964028777,
#   'reconstructed_morphological_threshold': 0.37722419928825623},
#  'csb': {'finetune': 0.367816091954023,
#   'reconstructed_featural_threshold': 0.5126353790613718,
#   'reconstructed_syntactic_threshold': 0.5126353790613718,
#   'reconstructed_morphological_threshold': 0.5126353790613718},
#  'cs': {'finetune': 0.6297358789197744,
#   'reconstructed_featural_base': 0.7231900637359047,
#   'reconstructed_syntactic_distVar': 0.722488819247217,
#   'reconstructed_morphological_distVar': 0.723340303188709,
#   'reconstructed_featural_eu': 0.7241401856937361,
#   'reconstructed_featural': 0.7218506313419688,
#   'baseline_en': 0.7370901367317139,
#   'baseline_task_adapter': 0.6917078242786587,
#   'baseline_avg_adapter': 0.6251371206329157,
#   'baseline_closest_featural': 0.6590811648692325,
#   'no_train_gain': 0.7211522794668752,
#   'reconstructed_featural_limit': 0.7333025647787961,
#   'reconstructed_syntactic_limit': 0.7303182579564489,
#   'reconstructed_morphological_limit': 0.7294008422029908,
#   'reconstructed_featural_sr': 0.7236726025159287,
#   'reconstructed_featural_threshold': 0.7250433247228854,
#   'reconstructed_syntactic_threshold': 0.7279756249385708,
#   'reconstructed_morphological_threshold': 0.7282619383173282},
#  'cv': {'finetune': 0.3525641025641026,
#   'reconstructed_featural_base': 0.49645390070921985,
#   'reconstructed_syntactic_distVar': 0.49640287769784175,
#   'reconstructed_morphological_distVar': 0.49640287769784175,
#   'reconstructed_featural_eu': 0.49462365591397855,
#   'reconstructed_featural': 0.49640287769784175,
#   'baseline_en': 0.48780487804878053,
#   'baseline_task_adapter': 0.38461538461538464,
#   'baseline_avg_adapter': 0.40143369175627247,
#   'baseline_closest_featural': 0.3221476510067114,
#   'no_train_gain': 0.47096774193548385,
#   'reconstructed_featural_limit': 0.4679487179487179,
#   'reconstructed_syntactic_limit': 0.44078947368421056,
#   'reconstructed_morphological_limit': 0.5140845070422536,
#   'reconstructed_featural_sr': 0.49462365591397855,
#   'reconstructed_featural_threshold': 0.505338078291815,
#   'reconstructed_syntactic_threshold': 0.5201465201465201,
#   'reconstructed_morphological_threshold': 0.505338078291815},
#  'cy': {'finetune': 0.4239917269906929,
#   'reconstructed_featural_base': 0.5317545748116254,
#   'reconstructed_syntactic_distVar': 0.5199294532627866,
#   'reconstructed_morphological_distVar': 0.5132496513249651,
#   'reconstructed_featural_eu': 0.5242857142857142,
#   'reconstructed_featural': 0.5204802259887006,
#   'baseline_en': 0.538037486218302,
#   'baseline_task_adapter': 0.5060742797639709,
#   'baseline_avg_adapter': 0.44944598337950137,
#   'baseline_closest_featural': 0.4437956204379562,
#   'no_train_gain': 0.5333814507398051,
#   'reconstructed_featural_limit': 0.5372168284789643,
#   'reconstructed_syntactic_limit': 0.5333333333333334,
#   'reconstructed_morphological_limit': 0.5246826516220028,
#   'reconstructed_featural_sr': 0.5189380530973451,
#   'reconstructed_featural_threshold': 0.5284900284900285,
#   'reconstructed_syntactic_threshold': 0.5213103205353997,
#   'reconstructed_morphological_threshold': 0.5282748747315676},
#  'da': {'finetune': 0.7094292546002702,
#   'reconstructed_featural_base': 0.7898301552568511,
#   'reconstructed_syntactic_distVar': 0.7885476314419573,
#   'reconstructed_morphological_distVar': 0.7881858883143026,
#   'reconstructed_featural_eu': 0.7889729879869453,
#   'reconstructed_featural': 0.7886297376093293,
#   'baseline_en': 0.784997910572503,
#   'baseline_task_adapter': 0.7530411943599669,
#   'baseline_avg_adapter': 0.7151579694710686,
#   'baseline_closest_featural': 0.7387886869253981,
#   'no_train_gain': 0.7827676600441501,
#   'reconstructed_featural_limit': 0.7927802846233947,
#   'reconstructed_syntactic_limit': 0.7909733777038269,
#   'reconstructed_morphological_limit': 0.7834656637414682,
#   'reconstructed_featural_sr': 0.788646379124883,
#   'reconstructed_featural_threshold': 0.7937480419117904,
#   'reconstructed_syntactic_threshold': 0.791918770429098,
#   'reconstructed_morphological_threshold': 0.7919322813251124},
#  'de': {'finetune': 0.5994424996758719,
#   'reconstructed_featural_base': 0.7142857142857144,
#   'reconstructed_featural_eu': 0.7133333333333334,
#   'reconstructed_featural': 0.711900915455035,
#   'baseline_en': 0.7022521008403362,
#   'baseline_task_adapter': 0.6882305521966949,
#   'baseline_avg_adapter': 0.6393904602859827,
#   'baseline_closest_featural': 0.7426468082205787,
#   'no_train_gain': 0.6997637507070842,
#   'reconstructed_featural_sr': 0.712780638863644,
#   'reconstructed_featural_threshold': 0.7146849850153214,
#   'reconstructed_syntactic_threshold': 0.7159136884693189,
#   'reconstructed_morphological_threshold': 0.7137186301554195},
#  'diq': {'finetune': 0.2484848484848485,
#   'reconstructed_featural_base': 0.3699059561128526,
#   'reconstructed_featural_eu': 0.3699059561128526,
#   'reconstructed_featural': 0.37770897832817335,
#   'baseline_en': 0.26198083067092653,
#   'baseline_task_adapter': 0.3973509933774834,
#   'baseline_avg_adapter': 0.34782608695652173,
#   'baseline_closest_featural': 0.32894736842105265,
#   'no_train_gain': 0.36538461538461536,
#   'reconstructed_featural_sr': 0.36760124610591904,
#   'reconstructed_featural_threshold': 0.3710691823899371,
#   'reconstructed_syntactic_threshold': 0.3664596273291925,
#   'reconstructed_morphological_threshold': 0.3687499999999999},
#  'dv': {'finetune': 0.0,
#   'reconstructed_featural_base': 0.0,
#   'reconstructed_featural_eu': 0.0,
#   'reconstructed_featural': 0.0,
#   'baseline_en': 0.0,
#   'baseline_task_adapter': 0.0,
#   'baseline_avg_adapter': 0.0,
#   'baseline_closest_featural': 0.011428571428571429,
#   'no_train_gain': 0.0,
#   'reconstructed_featural_sr': 0.0,
#   'reconstructed_featural_threshold': 0.0,
#   'reconstructed_syntactic_threshold': 0.0,
#   'reconstructed_morphological_threshold': 0.0},
#  'el': {'finetune': 0.5112746261571327,
#   'reconstructed_featural_base': 0.7047698617651527,
#   'reconstructed_syntactic_distVar': 0.6991451698313034,
#   'reconstructed_morphological_distVar': 0.7006244087038789,
#   'reconstructed_featural_eu': 0.703186646433991,
#   'reconstructed_featural': 0.6994287443725646,
#   'baseline_en': 0.6577599815192701,
#   'baseline_task_adapter': 0.6587917651029362,
#   'baseline_avg_adapter': 0.5905766417738086,
#   'baseline_closest_featural': 0.7424822721929393,
#   'no_train_gain': 0.6916497861805088,
#   'reconstructed_featural_limit': 0.7237564845895637,
#   'reconstructed_syntactic_limit': 0.718817839052443,
#   'reconstructed_morphological_limit': 0.72478919455149,
#   'reconstructed_featural_sr': 0.6996782131364756,
#   'reconstructed_featural_threshold': 0.7056676930094651,
#   'reconstructed_syntactic_threshold': 0.7063612844315935,
#   'reconstructed_morphological_threshold': 0.7086817698038619},
#  'en': {'finetune': 0.7657942873223582,
#   'reconstructed_featural_base': 0.7878977787062184,
#   'reconstructed_syntactic_distVar': 0.7857167716562838,
#   'reconstructed_morphological_distVar': 0.7848004450006952,
#   'reconstructed_featural_eu': 0.7877711619485358,
#   'reconstructed_featural': 0.7848101265822784,
#   'baseline_en': 0.8137337845459673,
#   'baseline_task_adapter': 0.7444179042475855,
#   'baseline_avg_adapter': 0.6895158481365378,
#   'baseline_closest_featural': 0.8137337845459673,
#   'no_train_gain': 0.7826117197009215,
#   'reconstructed_featural_limit': 0.8012605042016805,
#   'reconstructed_syntactic_limit': 0.8009662850540908,
#   'reconstructed_morphological_limit': 0.804071604071604,
#   'reconstructed_featural_sr': 0.7868156346803105,
#   'reconstructed_featural_threshold': 0.7883979247188273,
#   'reconstructed_syntactic_threshold': 0.7900365789932068,
#   'reconstructed_morphological_threshold': 0.7946964410327984},
#  'eo': {'finetune': 0.5440182425278932,
#   'reconstructed_featural_base': 0.5940347324974691,
#   'reconstructed_featural_eu': 0.5927453880283335,
#   'reconstructed_featural': 0.5888017395356061,
#   'baseline_en': 0.5830412350832972,
#   'baseline_task_adapter': 0.5024246821184467,
#   'baseline_avg_adapter': 0.4833020331509757,
#   'baseline_closest_featural': 0.4271596588133619,
#   'no_train_gain': 0.583044583044583,
#   'reconstructed_featural_sr': 0.5921861623472644,
#   'reconstructed_featural_threshold': 0.5968610915905365,
#   'reconstructed_syntactic_threshold': 0.5981608295832518,
#   'reconstructed_morphological_threshold': 0.5944492087003976},
#  'es': {'finetune': 0.5642843232716651,
#   'reconstructed_featural_base': 0.7226014264897614,
#   'reconstructed_featural_eu': 0.7211321476381717,
#   'reconstructed_featural': 0.7191148416634874,
#   'baseline_en': 0.7115317751593586,
#   'baseline_task_adapter': 0.6916510354859701,
#   'baseline_avg_adapter': 0.6609226489452128,
#   'baseline_closest_featural': 0.6711921287468537,
#   'no_train_gain': 0.7245094267025779,
#   'reconstructed_featural_sr': 0.7198685869274554,
#   'reconstructed_featural_threshold': 0.723758389261745,
#   'reconstructed_syntactic_threshold': 0.7192660550458716,
#   'reconstructed_morphological_threshold': 0.7234614350980918},
#  'et': {'finetune': 0.5513243378310845,
#   'reconstructed_featural_base': 0.6484475410945004,
#   'reconstructed_syntactic_distVar': 0.6432764320896025,
#   'reconstructed_morphological_distVar': 0.645226673873387,
#   'reconstructed_featural_eu': 0.6463315768139442,
#   'reconstructed_featural': 0.6427945242430373,
#   'baseline_en': 0.5972070844686649,
#   'baseline_task_adapter': 0.5689282267993212,
#   'baseline_avg_adapter': 0.547408563009187,
#   'baseline_closest_featural': 0.6746080228059458,
#   'no_train_gain': 0.6265318422286211,
#   'reconstructed_featural_limit': 0.6610771155211467,
#   'reconstructed_syntactic_limit': 0.6553771420860882,
#   'reconstructed_morphological_limit': 0.6569170494460957,
#   'reconstructed_featural_sr': 0.6449849870112343,
#   'reconstructed_featural_threshold': 0.6507215936039027,
#   'reconstructed_syntactic_threshold': 0.6502606458601313,
#   'reconstructed_morphological_threshold': 0.6523756307358868},
#  'eu': {'finetune': 0.38562484950638093,
#   'reconstructed_featural_base': 0.4631688248228683,
#   'reconstructed_syntactic_distVar': 0.44122519049483483,
#   'reconstructed_morphological_distVar': 0.44276373278693465,
#   'reconstructed_featural_eu': 0.45022378129914115,
#   'reconstructed_featural': 0.4414075434213299,
#   'baseline_en': 0.4281005859375,
#   'baseline_task_adapter': 0.3875191447190606,
#   'baseline_avg_adapter': 0.3967380876239206,
#   'baseline_closest_featural': 0.42682811465329673,
#   'no_train_gain': 0.4305580748533768,
#   'reconstructed_featural_limit': 0.47439468609385044,
#   'reconstructed_syntactic_limit': 0.47493112947658406,
#   'reconstructed_morphological_limit': 0.47229048906365195,
#   'reconstructed_featural_sr': 0.4566259940508711,
#   'reconstructed_featural_threshold': 0.4633379141853719,
#   'reconstructed_syntactic_threshold': 0.4631971168529717,
#   'reconstructed_morphological_threshold': 0.45935964350028996},
#  'ext': {'finetune': 0.32972972972972975,
#   'reconstructed_featural_base': 0.35540069686411146,
#   'reconstructed_featural_eu': 0.35664335664335667,
#   'reconstructed_featural': 0.35540069686411146,
#   'baseline_en': 0.34843205574912894,
#   'baseline_task_adapter': 0.34090909090909094,
#   'baseline_avg_adapter': 0.3148936170212766,
#   'baseline_closest_featural': 0.2977346278317152,
#   'no_train_gain': 0.35738831615120276,
#   'reconstructed_featural_sr': 0.3541666666666667,
#   'reconstructed_featural_threshold': 0.35664335664335667,
#   'reconstructed_syntactic_threshold': 0.35664335664335667,
#   'reconstructed_morphological_threshold': 0.35540069686411146},
#  'fa': {'finetune': 0.24493870985634256,
#   'reconstructed_featural_threshold': 0.4312996450904174,
#   'reconstructed_syntactic_threshold': 0.4312996450904174,
#   'reconstructed_morphological_threshold': 0.4312996450904174},
#  'fi': {'finetune': 0.5923135852911134,
#   'reconstructed_featural_base': 0.6519988403182683,
#   'reconstructed_syntactic_distVar': 0.6463050390211003,
#   'reconstructed_morphological_distVar': 0.6478891353975755,
#   'reconstructed_featural_eu': 0.6491385960401131,
#   'reconstructed_featural': 0.6472970367037347,
#   'baseline_en': 0.6282753036437246,
#   'baseline_task_adapter': 0.6066606660666067,
#   'baseline_avg_adapter': 0.5703007393035158,
#   'baseline_closest_featural': 0.6072717726586598,
#   'no_train_gain': 0.6366168326023627,
#   'reconstructed_featural_limit': 0.6617899336462211,
#   'reconstructed_syntactic_limit': 0.6586480791052034,
#   'reconstructed_morphological_limit': 0.6497340854149879,
#   'reconstructed_featural_sr': 0.6489648964896488,
#   'reconstructed_featural_threshold': 0.6512287030178106,
#   'reconstructed_syntactic_threshold': 0.6527490965410429,
#   'reconstructed_morphological_threshold': 0.652776881893827},
#  'fo': {'finetune': 0.46735395189003437,
#   'reconstructed_featural_base': 0.5811320754716982,
#   'reconstructed_syntactic_distVar': 0.5576208178438662,
#   'reconstructed_morphological_distVar': 0.5543071161048688,
#   'reconstructed_featural_eu': 0.5671641791044775,
#   'reconstructed_featural_limit': 0.5848375451263539,
#   'reconstructed_syntactic_limit': 0.5818181818181819,
#   'reconstructed_morphological_limit': 0.587360594795539,
#   'reconstructed_featural_sr': 0.5724907063197026,
#   'reconstructed_featural_threshold': 0.5579710144927537,
#   'reconstructed_syntactic_threshold': 0.5639097744360902,
#   'reconstructed_morphological_threshold': 0.5724907063197026},
#  'frr': {'finetune': 0.38783269961977185,
#   'reconstructed_featural_base': 0.45454545454545453,
#   'reconstructed_featural_eu': 0.46413502109704635,
#   'reconstructed_featural': 0.4583333333333333,
#   'baseline_en': 0.4,
#   'baseline_task_adapter': 0.41409691629955947,
#   'baseline_avg_adapter': 0.34871794871794876,
#   'baseline_closest_featural': 0.40816326530612246,
#   'no_train_gain': 0.3951612903225807,
#   'reconstructed_featural_sr': 0.46413502109704635,
#   'reconstructed_featural_threshold': 0.46090534979423864,
#   'reconstructed_syntactic_threshold': 0.4380165289256198,
#   'reconstructed_morphological_threshold': 0.4380165289256198},
#  'fr': {'finetune': 0.64540622627183,
#   'reconstructed_featural_base': 0.7313637676971975,
#   'reconstructed_syntactic_distVar': 0.7295179635313234,
#   'reconstructed_morphological_distVar': 0.7293930750622811,
#   'reconstructed_featural_eu': 0.7296536796536797,
#   'reconstructed_featural': 0.7303650742064781,
#   'baseline_en': 0.7141884385191557,
#   'baseline_task_adapter': 0.675271976772659,
#   'baseline_avg_adapter': 0.6367181857576196,
#   'baseline_closest_featural': 0.6721671770852099,
#   'no_train_gain': 0.7051953990643357,
#   'reconstructed_featural_limit': 0.7318096340228555,
#   'reconstructed_syntactic_limit': 0.7355297017143272,
#   'reconstructed_morphological_limit': 0.7216814478332972,
#   'reconstructed_featural_sr': 0.7294117647058824,
#   'reconstructed_featural_threshold': 0.731548715725588,
#   'reconstructed_syntactic_threshold': 0.7312123072478423,
#   'reconstructed_morphological_threshold': 0.7321131447587355},
#  'fur': {'finetune': 0.30625,
#   'reconstructed_featural_base': 0.5182481751824818,
#   'reconstructed_featural_eu': 0.5090909090909091,
#   'reconstructed_featural': 0.49640287769784175,
#   'baseline_en': 0.43986254295532645,
#   'baseline_task_adapter': 0.36734693877551017,
#   'baseline_avg_adapter': 0.2936507936507937,
#   'baseline_closest_featural': 0.4496644295302013,
#   'no_train_gain': 0.43137254901960786,
#   'reconstructed_featural_sr': 0.510948905109489,
#   'reconstructed_featural_threshold': 0.5255474452554745,
#   'reconstructed_syntactic_threshold': 0.5128205128205129,
#   'reconstructed_morphological_threshold': 0.5128205128205129},
#  'fy': {'finetune': 0.5863192182410424,
#   'reconstructed_featural_base': 0.6958473625140292,
#   'reconstructed_syntactic_distVar': 0.6910447761194031,
#   'reconstructed_morphological_distVar': 0.6913303437967117,
#   'reconstructed_featural_eu': 0.6903249906611879,
#   'reconstructed_featural': 0.6902985074626866,
#   'baseline_en': 0.6393262541193703,
#   'baseline_task_adapter': 0.5944767441860465,
#   'baseline_avg_adapter': 0.5468018720748831,
#   'baseline_closest_featural': 0.5578281889178133,
#   'no_train_gain': 0.6728280961182994,
#   'reconstructed_featural_limit': 0.696629213483146,
#   'reconstructed_syntactic_limit': 0.6965955854844743,
#   'reconstructed_morphological_limit': 0.6861423220973782,
#   'reconstructed_featural_sr': 0.6920777279521674,
#   'reconstructed_featural_threshold': 0.7014535967200894,
#   'reconstructed_syntactic_threshold': 0.6961408767328587,
#   'reconstructed_morphological_threshold': 0.6944237918215613},
#  'gan': {'finetune': 0.2097902097902098,
#   'reconstructed_featural_base': 0.1891891891891892,
#   'reconstructed_featural_eu': 0.1883408071748879,
#   'reconstructed_featural': 0.18264840182648404,
#   'baseline_en': 0.25668449197860954,
#   'baseline_task_adapter': 0.0851063829787234,
#   'baseline_avg_adapter': 0.05263157894736842,
#   'baseline_closest_featural': 0.11392405063291139,
#   'no_train_gain': 0.23963133640552997,
#   'reconstructed_featural_sr': 0.1883408071748879,
#   'reconstructed_featural_threshold': 0.18584070796460178,
#   'reconstructed_syntactic_threshold': 0.1883408071748879,
#   'reconstructed_morphological_threshold': 0.1883408071748879},
#  'ga': {'finetune': 0.4769953051643193,
#   'reconstructed_featural_base': 0.6508951406649617,
#   'reconstructed_syntactic_distVar': 0.6481303930968362,
#   'reconstructed_morphological_distVar': 0.6496490108487555,
#   'reconstructed_featural_eu': 0.6530089628681178,
#   'reconstructed_featural': 0.6485796361315033,
#   'baseline_en': 0.6274384393987847,
#   'baseline_task_adapter': 0.5740276035131744,
#   'baseline_avg_adapter': 0.4819512195121951,
#   'baseline_closest_featural': 0.5550604710375557,
#   'no_train_gain': 0.6228070175438596,
#   'reconstructed_featural_limit': 0.6527196652719666,
#   'reconstructed_syntactic_limit': 0.6540314808866046,
#   'reconstructed_morphological_limit': 0.644034917555771,
#   'reconstructed_featural_sr': 0.6532438478747205,
#   'reconstructed_featural_threshold': 0.6546623794212217,
#   'reconstructed_syntactic_threshold': 0.6506564201088697,
#   'reconstructed_morphological_threshold': 0.6434558349451966},
#  'gd': {'finetune': 0.4258555133079847,
#   'reconstructed_featural_base': 0.49420849420849416,
#   'reconstructed_featural_eu': 0.49056603773584906,
#   'reconstructed_featural': 0.5038167938931297,
#   'baseline_en': 0.4897959183673469,
#   'baseline_task_adapter': 0.42962962962962964,
#   'baseline_avg_adapter': 0.336,
#   'baseline_closest_featural': 0.4180327868852459,
#   'no_train_gain': 0.48995983935742976,
#   'reconstructed_featural_sr': 0.48872180451127817,
#   'reconstructed_featural_threshold': 0.4961832061068703,
#   'reconstructed_syntactic_threshold': 0.4961832061068703,
#   'reconstructed_morphological_threshold': 0.49230769230769234},
#  'gl': {'finetune': 0.6731229076996652,
#   'reconstructed_featural_base': 0.7831211692597833,
#   'reconstructed_syntactic_distVar': 0.7812708505043369,
#   'reconstructed_morphological_distVar': 0.7802064121178826,
#   'reconstructed_featural_eu': 0.7813690452813886,
#   'reconstructed_featural': 0.7816489257237125,
#   'baseline_en': 0.7788206407667023,
#   'baseline_task_adapter': 0.7289865233309962,
#   'baseline_avg_adapter': 0.6870567375886525,
#   'baseline_closest_featural': 0.7508064837309331,
#   'no_train_gain': 0.7849958584782865,
#   'reconstructed_featural_limit': 0.7867988356541579,
#   'reconstructed_syntactic_limit': 0.7870465097977494,
#   'reconstructed_morphological_limit': 0.7775249156399591,
#   'reconstructed_featural_sr': 0.7814819177759454,
#   'reconstructed_featural_threshold': 0.7826770415782441,
#   'reconstructed_syntactic_threshold': 0.7828477185266629,
#   'reconstructed_morphological_threshold': 0.7858461296783568},
#  'gn': {'finetune': 0.30601092896174864,
#   'reconstructed_featural_base': 0.4014598540145985,
#   'reconstructed_syntactic_distVar': 0.4014869888475836,
#   'reconstructed_morphological_distVar': 0.40892193308550195,
#   'reconstructed_featural_eu': 0.41328413284132837,
#   'reconstructed_featural': 0.4014869888475836,
#   'baseline_en': 0.36860068259385664,
#   'baseline_task_adapter': 0.39259259259259255,
#   'baseline_avg_adapter': 0.351931330472103,
#   'baseline_closest_featural': 0.45245901639344255,
#   'no_train_gain': 0.4086021505376344,
#   'reconstructed_featural_limit': 0.46886446886446886,
#   'reconstructed_syntactic_limit': 0.43956043956043955,
#   'reconstructed_morphological_limit': 0.4697508896797153,
#   'reconstructed_featural_sr': 0.41328413284132837,
#   'reconstructed_featural_threshold': 0.4354243542435424,
#   'reconstructed_syntactic_threshold': 0.43816254416961126,
#   'reconstructed_morphological_threshold': 0.4817518248175182},
#  'gu': {'finetune': 0.1946902654867257,
#   'reconstructed_featural_base': 0.31506849315068497,
#   'reconstructed_featural_eu': 0.31724137931034485,
#   'reconstructed_featural': 0.3161512027491408,
#   'baseline_en': 0.2139917695473251,
#   'baseline_task_adapter': 0.27999999999999997,
#   'baseline_avg_adapter': 0.21561338289962825,
#   'baseline_closest_featural': 0.05847953216374269,
#   'no_train_gain': 0.3169014084507042,
#   'reconstructed_featural_sr': 0.31724137931034485,
#   'reconstructed_featural_threshold': 0.32191780821917804,
#   'reconstructed_syntactic_threshold': 0.31506849315068497,
#   'reconstructed_morphological_threshold': 0.3139931740614334},
#  'hak': {'finetune': 0.169811320754717,
#   'reconstructed_featural_base': 0.20689655172413793,
#   'reconstructed_syntactic_distVar': 0.2165605095541401,
#   'reconstructed_morphological_distVar': 0.21935483870967745,
#   'reconstructed_featural_eu': 0.205607476635514,
#   'reconstructed_featural': 0.22292993630573252,
#   'baseline_en': 0.19672131147540986,
#   'baseline_task_adapter': 0.1993127147766323,
#   'baseline_avg_adapter': 0.19811320754716982,
#   'baseline_closest_featural': 0.21167883211678834,
#   'no_train_gain': 0.22516556291390727,
#   'reconstructed_featural_limit': 0.2,
#   'reconstructed_syntactic_limit': 0.19941348973607037,
#   'reconstructed_morphological_limit': 0.2183098591549296,
#   'reconstructed_featural_sr': 0.20625,
#   'reconstructed_featural_threshold': 0.2012578616352201,
#   'reconstructed_syntactic_threshold': 0.1987577639751553,
#   'reconstructed_morphological_threshold': 0.25},
#  'he': {'finetune': 0.19861627523885722,
#   'reconstructed_featural_base': 0.47042895824426395,
#   'reconstructed_syntactic_distVar': 0.46543516873889873,
#   'reconstructed_morphological_distVar': 0.46640822278336946,
#   'reconstructed_featural_eu': 0.46763230008185347,
#   'reconstructed_featural': 0.46595797632168384,
#   'baseline_en': 0.38041326894149313,
#   'baseline_task_adapter': 0.40077126330072127,
#   'baseline_avg_adapter': 0.30740006607201853,
#   'baseline_closest_featural': 0.3650322676359321,
#   'no_train_gain': 0.4551627581379069,
#   'reconstructed_featural_limit': 0.46984627512810406,
#   'reconstructed_syntactic_limit': 0.46056398511308333,
#   'reconstructed_morphological_limit': 0.4683348334833483,
#   'reconstructed_featural_sr': 0.46766735434303197,
#   'reconstructed_featural_threshold': 0.470169443257867,
#   'reconstructed_syntactic_threshold': 0.4684491978609626,
#   'reconstructed_morphological_threshold': 0.4720563521292952},
#  'hi': {'finetune': 0.4741666666666667,
#   'reconstructed_featural_base': 0.6462585034013606,
#   'reconstructed_syntactic_distVar': 0.6386999244142101,
#   'reconstructed_morphological_distVar': 0.6433990895295902,
#   'reconstructed_featural_eu': 0.6446969696969697,
#   'reconstructed_featural': 0.6416382252559727,
#   'baseline_en': 0.5677308024158757,
#   'baseline_task_adapter': 0.5352112676056338,
#   'baseline_avg_adapter': 0.43356643356643354,
#   'baseline_closest_featural': 0.6211085801063022,
#   'no_train_gain': 0.6136449302676217,
#   'reconstructed_featural_limit': 0.6439651910707529,
#   'reconstructed_syntactic_limit': 0.6468797564687975,
#   'reconstructed_morphological_limit': 0.65,
#   'reconstructed_featural_sr': 0.6464339908952959,
#   'reconstructed_featural_threshold': 0.6517620310723758,
#   'reconstructed_syntactic_threshold': 0.6476190476190475,
#   'reconstructed_morphological_threshold': 0.6572411157814291},
#  'hr': {'finetune': 0.6475139655112592,
#   'reconstructed_featural_base': 0.7360078209559722,
#   'reconstructed_featural_eu': 0.7355735643426017,
#   'reconstructed_featural': 0.7329110399554505,
#   'baseline_en': 0.7188574636816619,
#   'baseline_task_adapter': 0.6828172518661875,
#   'baseline_avg_adapter': 0.6526323313914008,
#   'baseline_closest_featural': 0.579699065225701,
#   'no_train_gain': 0.7311797948789506,
#   'reconstructed_featural_sr': 0.7354717112840738,
#   'reconstructed_featural_threshold': 0.7361659044094543,
#   'reconstructed_syntactic_threshold': 0.7352520495377638,
#   'reconstructed_morphological_threshold': 0.7360664897332029},
#  'hsb': {'finetune': 0.429042904290429,
#   'reconstructed_featural_threshold': 0.575438596491228,
#   'reconstructed_syntactic_threshold': 0.575438596491228,
#   'reconstructed_morphological_threshold': 0.575438596491228},
#  'hu': {'finetune': 0.5664127194435243,
#   'reconstructed_featural_base': 0.6553489447435347,
#   'reconstructed_syntactic_distVar': 0.6519271383315735,
#   'reconstructed_morphological_distVar': 0.6531946508172363,
#   'reconstructed_featural_eu': 0.6533333333333334,
#   'reconstructed_featural': 0.6521021714738301,
#   'baseline_en': 0.6392709306983576,
#   'baseline_task_adapter': 0.6087780646426354,
#   'baseline_avg_adapter': 0.5522509125321077,
#   'baseline_closest_featural': 0.5425679563995802,
#   'no_train_gain': 0.6516169607096752,
#   'reconstructed_featural_limit': 0.6564329903728455,
#   'reconstructed_syntactic_limit': 0.6583537839092658,
#   'reconstructed_morphological_limit': 0.66502741319156,
#   'reconstructed_featural_sr': 0.6535071794025418,
#   'reconstructed_featural_threshold': 0.6567894702030558,
#   'reconstructed_syntactic_threshold': 0.6548397753551372,
#   'reconstructed_morphological_threshold': 0.6573829055305637},
#  'hy': {'finetune': 0.2587841606246515,
#   'reconstructed_featural_base': 0.4398073836276083,
#   'reconstructed_syntactic_distVar': 0.42817126850740295,
#   'reconstructed_morphological_distVar': 0.43137254901960786,
#   'reconstructed_featural_eu': 0.4321086261980831,
#   'reconstructed_featural': 0.4289137380191694,
#   'baseline_en': 0.18686296715741788,
#   'baseline_task_adapter': 0.3350454365863295,
#   'baseline_avg_adapter': 0.2739373121511378,
#   'baseline_closest_featural': 0.25380269448066056,
#   'no_train_gain': 0.45867098865478123,
#   'reconstructed_featural_limit': 0.46818923327895595,
#   'reconstructed_syntactic_limit': 0.45672490857375053,
#   'reconstructed_morphological_limit': 0.471492114840275,
#   'reconstructed_featural_sr': 0.4324540367705835,
#   'reconstructed_featural_threshold': 0.4448025785656729,
#   'reconstructed_syntactic_threshold': 0.432475884244373,
#   'reconstructed_morphological_threshold': 0.44543249797898143},
#  'id': {'finetune': 0.41572023858158347,
#   'reconstructed_featural_base': 0.47531767423950716,
#   'reconstructed_syntactic_distVar': 0.4775265700483092,
#   'reconstructed_morphological_distVar': 0.4769741925513831,
#   'reconstructed_featural_eu': 0.477175381053444,
#   'reconstructed_featural': 0.4765103261918549,
#   'baseline_en': 0.4668356915024127,
#   'baseline_task_adapter': 0.4424595568504178,
#   'baseline_avg_adapter': 0.46482329842931935,
#   'baseline_closest_featural': 0.4544288489024078,
#   'no_train_gain': 0.4783385093167702,
#   'reconstructed_featural_limit': 0.4596842766830567,
#   'reconstructed_syntactic_limit': 0.45744125326370755,
#   'reconstructed_morphological_limit': 0.47110712416834866,
#   'reconstructed_featural_sr': 0.4772595764379122,
#   'reconstructed_featural_threshold': 0.47419354838709676,
#   'reconstructed_syntactic_threshold': 0.47942768754833726,
#   'reconstructed_morphological_threshold': 0.472139993255143},
#  'ig': {'finetune': 0.33766233766233766,
#   'reconstructed_featural_base': 0.4247104247104247,
#   'reconstructed_syntactic_distVar': 0.42585551330798477,
#   'reconstructed_morphological_distVar': 0.42105263157894735,
#   'reconstructed_featural_eu': 0.4367816091954023,
#   'reconstructed_featural': 0.42105263157894735,
#   'baseline_en': 0.362934362934363,
#   'baseline_task_adapter': 0.3547169811320755,
#   'baseline_avg_adapter': 0.2895927601809955,
#   'baseline_closest_featural': 0.34057971014492755,
# ...
#   'reconstructed_syntactic_threshold': 0.40946103140752227,
#   'reconstructed_morphological_threshold': 0.411033411033411},
#  'tg': {'finetune': 0.23121387283236994,
#   'reconstructed_featural_base': 0.31304347826086953,
#   'reconstructed_featural_eu': 0.3162393162393162,
#   'reconstructed_featural': 0.3025210084033614,
#   'baseline_en': 0.2571428571428571,
#   'baseline_task_adapter': 0.23580786026200873,
#   'baseline_avg_adapter': 0.12941176470588237,
#   'baseline_closest_featural': 0.2475247524752475,
#   'no_train_gain': 0.25196850393700787,
#   'reconstructed_featural_sr': 0.3189655172413793,
#   'reconstructed_featural_threshold': 0.314410480349345,
#   'reconstructed_syntactic_threshold': 0.314410480349345,
#   'reconstructed_morphological_threshold': 0.314410480349345},
#  'th': {'finetune': 0.0017496354926057071,
#   'reconstructed_featural_base': 0.03862545594163947,
#   'reconstructed_syntactic_distVar': 0.039280561700490525,
#   'reconstructed_morphological_distVar': 0.03929046050730918,
#   'reconstructed_featural_eu': 0.038862595713571126,
#   'reconstructed_featural': 0.03903567984570878,
#   'baseline_en': 0.01753735118545749,
#   'baseline_task_adapter': 0.040869351497489555,
#   'baseline_avg_adapter': 0.024000743385857084,
#   'baseline_closest_featural': 0.04215078290208378,
#   'no_train_gain': 0.03163133923938735,
#   'reconstructed_featural_limit': 0.04142461254233809,
#   'reconstructed_syntactic_limit': 0.04146461740774225,
#   'reconstructed_morphological_limit': 0.03780492657885312,
#   'reconstructed_featural_sr': 0.039125830364879176,
#   'reconstructed_featural_threshold': 0.03816838083476448,
#   'reconstructed_syntactic_threshold': 0.03928653801799031,
#   'reconstructed_morphological_threshold': 0.03784941258174663},
#  'tk': {'finetune': 0.26498422712933756,
#   'reconstructed_featural_base': 0.3878326996197719,
#   'reconstructed_syntactic_distVar': 0.3494423791821561,
#   'reconstructed_morphological_distVar': 0.34686346863468637,
#   'reconstructed_featural_eu': 0.37593984962406013,
#   'reconstructed_featural_limit': 0.39114391143911437,
#   'reconstructed_syntactic_limit': 0.36641221374045796,
#   'reconstructed_morphological_limit': 0.35789473684210527,
#   'reconstructed_featural_sr': 0.38022813688212925,
#   'reconstructed_featural_threshold': 0.3726235741444867,
#   'reconstructed_syntactic_threshold': 0.352059925093633,
#   'reconstructed_morphological_threshold': 0.38022813688212925},
#  'tl': {'finetune': 0.666971637694419,
#   'reconstructed_featural_base': 0.6955727978092195,
#   'reconstructed_syntactic_distVar': 0.6741979213737009,
#   'reconstructed_morphological_distVar': 0.6729815065403698,
#   'reconstructed_featural_eu': 0.6903137789904502,
#   'reconstructed_featural': 0.6720720720720721,
#   'baseline_en': 0.689908256880734,
#   'baseline_task_adapter': 0.578397212543554,
#   'baseline_avg_adapter': 0.4738461538461538,
#   'baseline_closest_featural': 0.6785878037597431,
#   'no_train_gain': 0.6947082767978291,
#   'reconstructed_featural_limit': 0.6762589928057554,
#   'reconstructed_syntactic_limit': 0.6940639269406393,
#   'reconstructed_morphological_limit': 0.6836595357305416,
#   'reconstructed_featural_sr': 0.6900318616294947,
#   'reconstructed_featural_threshold': 0.6967624259005927,
#   'reconstructed_syntactic_threshold': 0.6863368134362233,
#   'reconstructed_morphological_threshold': 0.689812699862951},
#  'tr': {'finetune': 0.5103664992997915,
#   'reconstructed_featural_base': 0.5970827026283198,
#   'reconstructed_syntactic_distVar': 0.5962438084755091,
#   'reconstructed_morphological_distVar': 0.5964332438201474,
#   'reconstructed_featural_eu': 0.5966626526750387,
#   'reconstructed_featural': 0.596380152776822,
#   'baseline_en': 0.5816221413364467,
#   'baseline_task_adapter': 0.5624588516580616,
#   'baseline_avg_adapter': 0.5226119958855034,
#   'baseline_closest_featural': 0.6004517763022795,
#   'no_train_gain': 0.5923749658376606,
#   'reconstructed_featural_limit': 0.5998006393290484,
#   'reconstructed_syntactic_limit': 0.6042429686960127,
#   'reconstructed_morphological_limit': 0.6041300375771367,
#   'reconstructed_featural_sr': 0.5963813979086406,
#   'reconstructed_featural_threshold': 0.5965454483019128,
#   'reconstructed_syntactic_threshold': 0.5977778542189811,
#   'reconstructed_morphological_threshold': 0.5989812775330396},
#  'tt': {'finetune': 0.2558139534883721,
#   'reconstructed_featural_base': 0.38841440772372815,
#   'reconstructed_syntactic_distVar': 0.3733528550512445,
#   'reconstructed_morphological_distVar': 0.37706725468577734,
#   'reconstructed_featural_eu': 0.3763244428206065,
#   'reconstructed_featural': 0.37435897435897436,
#   'baseline_en': 0.286559594251902,
#   'baseline_task_adapter': 0.2891030392883618,
#   'baseline_avg_adapter': 0.25295404814004374,
#   'baseline_closest_featural': 0.28336620644312954,
#   'no_train_gain': 0.35040621688449314,
#   'reconstructed_featural_limit': 0.3715444157758938,
#   'reconstructed_syntactic_limit': 0.3676963155935988,
#   'reconstructed_morphological_limit': 0.37943786982248523,
#   'reconstructed_featural_sr': 0.3784773060029283,
#   'reconstructed_featural_threshold': 0.38175799926443543,
#   'reconstructed_syntactic_threshold': 0.38333333333333336,
#   'reconstructed_morphological_threshold': 0.38588754134509373},
#  'ug': {'finetune': 0.25120772946859904,
#   'reconstructed_featural_base': 0.4067796610169492,
#   'reconstructed_featural_eu': 0.40540540540540543,
#   'reconstructed_featural': 0.3973063973063973,
#   'baseline_en': 0.09580838323353293,
#   'baseline_task_adapter': 0.3040540540540541,
#   'baseline_avg_adapter': 0.2723735408560311,
#   'baseline_closest_featural': 0.0903954802259887,
#   'no_train_gain': 0.32167832167832167,
#   'reconstructed_featural_sr': 0.4067796610169492,
#   'reconstructed_featural_threshold': 0.39867109634551495,
#   'reconstructed_syntactic_threshold': 0.40404040404040403,
#   'reconstructed_morphological_threshold': 0.41237113402061853},
#  'uk': {'finetune': 0.48346132234500844,
#   'reconstructed_featural_base': 0.5953260336656315,
#   'reconstructed_syntactic_distVar': 0.5992457779963929,
#   'reconstructed_morphological_distVar': 0.5936123707304342,
#   'reconstructed_featural_eu': 0.5970813428440548,
#   'reconstructed_featural': 0.6025231397608616,
#   'baseline_en': 0.5676052810476224,
#   'baseline_task_adapter': 0.60357796300061,
#   'baseline_avg_adapter': 0.5777581836217349,
#   'baseline_closest_featural': 0.5801070840197694,
#   'no_train_gain': 0.6008371510497348,
#   'reconstructed_featural_limit': 0.5867548809755464,
#   'reconstructed_syntactic_limit': 0.6018104048542723,
#   'reconstructed_morphological_limit': 0.6006317539484621,
#   'reconstructed_featural_sr': 0.5990303347965669,
#   'reconstructed_featural_threshold': 0.5974136519888688,
#   'reconstructed_syntactic_threshold': 0.5916636886390956,
#   'reconstructed_morphological_threshold': 0.5841516771998055},
#  'ur': {'finetune': 0.20348204570184983,
#   'reconstructed_featural_base': 0.42437527400263036,
#   'reconstructed_featural_eu': 0.418848167539267,
#   'reconstructed_featural': 0.41081552551242917,
#   'baseline_en': 0.23623853211009174,
#   'baseline_task_adapter': 0.31671812968681085,
#   'baseline_avg_adapter': 0.23476523476523475,
#   'baseline_closest_featural': 0.145478374836173,
#   'no_train_gain': 0.4251968503937008,
#   'reconstructed_featural_sr': 0.4190309908336971,
#   'reconstructed_featural_threshold': 0.426128890837352,
#   'reconstructed_syntactic_threshold': 0.42311033883579496,
#   'reconstructed_morphological_threshold': 0.42605633802816906},
#  'uz': {'finetune': 0.6700982686008423,
#   'reconstructed_featural_base': 0.6735518634934891,
#   'reconstructed_featural_eu': 0.6708633093525179,
#   'reconstructed_featural': 0.669051878354204,
#   'baseline_en': 0.7043966323666978,
#   'baseline_task_adapter': 0.6003616636528029,
#   'baseline_avg_adapter': 0.4978050921861283,
#   'baseline_closest_featural': 0.6078865750996899,
#   'no_train_gain': 0.6729815065403699,
#   'reconstructed_featural_sr': 0.6717625899280575,
#   'reconstructed_featural_threshold': 0.6789568345323742,
#   'reconstructed_syntactic_threshold': 0.6747529200359389,
#   'reconstructed_morphological_threshold': 0.6759550561797752},
#  'vec': {'finetune': 0.43283582089552236,
#   'reconstructed_featural_threshold': 0.608,
#   'reconstructed_syntactic_threshold': 0.608,
#   'reconstructed_morphological_threshold': 0.608},
#  'vep': {'finetune': 0.49624060150375937,
#   'reconstructed_featural_base': 0.4609665427509294,
#   'reconstructed_syntactic_distVar': 0.46268656716417905,
#   'reconstructed_morphological_distVar': 0.45588235294117646,
#   'reconstructed_featural_eu': 0.46153846153846156,
#   'reconstructed_featural': 0.47191011235955055,
#   'baseline_en': 0.5238095238095238,
#   'baseline_task_adapter': 0.4382470119521912,
#   'baseline_avg_adapter': 0.3796296296296296,
#   'baseline_closest_featural': 0.4285714285714286,
#   'no_train_gain': 0.48837209302325585,
#   'reconstructed_featural_limit': 0.5039370078740156,
#   'reconstructed_syntactic_limit': 0.5095057034220533,
#   'reconstructed_morphological_limit': 0.5190839694656487,
#   'reconstructed_featural_sr': 0.4575645756457565,
#   'reconstructed_featural_threshold': 0.4621212121212121,
#   'reconstructed_syntactic_threshold': 0.47583643122676583,
#   'reconstructed_morphological_threshold': 0.4679245283018868},
#  'vi': {'finetune': 0.6108647909501512,
#   'reconstructed_featural_base': 0.6480998205839178,
#   'reconstructed_syntactic_distVar': 0.6398054316984192,
#   'reconstructed_morphological_distVar': 0.6426194920068166,
#   'reconstructed_featural_eu': 0.6445474505977068,
#   'reconstructed_featural': 0.6403537238357944,
#   'baseline_en': 0.6122260475270803,
#   'baseline_task_adapter': 0.5351017791312711,
#   'baseline_avg_adapter': 0.4859143190531755,
#   'baseline_closest_featural': 0.6684034844907596,
#   'no_train_gain': 0.618645778657084,
#   'reconstructed_featural_limit': 0.659890154930732,
#   'reconstructed_syntactic_limit': 0.6648842087943729,
#   'reconstructed_morphological_limit': 0.6579711330089545,
#   'reconstructed_featural_sr': 0.6434372969460689,
#   'reconstructed_featural_threshold': 0.6466134809508303,
#   'reconstructed_syntactic_threshold': 0.6502857142857144,
#   'reconstructed_morphological_threshold': 0.6624094314134839},
#  'vls': {'finetune': 0.41279069767441856,
#   'reconstructed_featural_base': 0.7062937062937062,
#   'reconstructed_featural_eu': 0.6782006920415224,
#   'reconstructed_featural': 0.6925795053003533,
#   'baseline_en': 0.62,
#   'baseline_task_adapter': 0.6180555555555556,
#   'baseline_avg_adapter': 0.49612403100775193,
#   'baseline_closest_featural': 0.6420664206642066,
#   'no_train_gain': 0.6689895470383276,
#   'reconstructed_featural_sr': 0.7062937062937062,
#   'reconstructed_featural_threshold': 0.6993006993006993,
#   'reconstructed_syntactic_threshold': 0.6993006993006993,
#   'reconstructed_morphological_threshold': 0.6989619377162629},
#  'war': {'finetune': 0.5041322314049588,
#   'reconstructed_featural_base': 0.5062240663900415,
#   'reconstructed_syntactic_distVar': 0.45559845559845563,
#   'reconstructed_morphological_distVar': 0.45384615384615384,
#   'reconstructed_featural_eu': 0.466403162055336,
#   'reconstructed_featural': 0.45559845559845563,
#   'baseline_en': 0.5966386554621849,
#   'baseline_task_adapter': 0.43037974683544306,
#   'baseline_avg_adapter': 0.43119266055045874,
#   'baseline_closest_featural': 0.6481481481481481,
#   'no_train_gain': 0.5701754385964913,
#   'reconstructed_featural_limit': 0.5789473684210527,
#   'reconstructed_syntactic_limit': 0.6063348416289592,
#   'reconstructed_morphological_limit': 0.5593220338983051,
#   'reconstructed_featural_sr': 0.47011952191235057,
#   'reconstructed_featural_threshold': 0.5145228215767634,
#   'reconstructed_syntactic_threshold': 0.5276595744680851,
#   'reconstructed_morphological_threshold': 0.5145228215767634},
#  'wa': {'finetune': 0.31309904153354634,
#   'reconstructed_featural_threshold': 0.4092664092664092,
#   'reconstructed_syntactic_threshold': 0.4092664092664092,
#   'reconstructed_morphological_threshold': 0.4092664092664092},
#  'wuu': {'finetune': 0.06802721088435375,
#   'reconstructed_featural_base': 0.2557077625570776,
#   'reconstructed_syntactic_distVar': 0.23255813953488372,
#   'reconstructed_morphological_distVar': 0.23364485981308408,
#   'reconstructed_featural_eu': 0.2523364485981308,
#   'reconstructed_featural': 0.23963133640552994,
#   'baseline_en': 0.2905027932960894,
#   'baseline_task_adapter': 0.16494845360824742,
#   'baseline_avg_adapter': 0.14285714285714282,
#   'baseline_closest_featural': 0.0449438202247191,
#   'no_train_gain': 0.2510460251046025,
#   'reconstructed_featural_limit': 0.2378854625550661,
#   'reconstructed_syntactic_limit': 0.24000000000000002,
#   'reconstructed_morphological_limit': 0.23041474654377878,
#   'reconstructed_featural_sr': 0.24299065420560748,
#   'reconstructed_featural_threshold': 0.2777777777777778,
#   'reconstructed_syntactic_threshold': 0.2727272727272727,
#   'reconstructed_morphological_threshold': 0.22522522522522523},
#  'xmf': {'finetune': 0.2159090909090909,
#   'reconstructed_featural_base': 0.4130434782608696,
#   'reconstructed_featural_eu': 0.4028268551236749,
#   'reconstructed_featural': 0.40714285714285714,
#   'baseline_en': 0.25547445255474455,
#   'baseline_task_adapter': 0.3445692883895131,
#   'baseline_avg_adapter': 0.20444444444444446,
#   'baseline_closest_featural': 0.42483660130718953,
#   'no_train_gain': 0.37162162162162166,
#   'reconstructed_featural_sr': 0.40579710144927544,
#   'reconstructed_featural_threshold': 0.4157706093189964,
#   'reconstructed_syntactic_threshold': 0.4130434782608696,
#   'reconstructed_morphological_threshold': 0.4130434782608696},
#  'yi': {'finetune': 0.23762376237623764,
#   'reconstructed_featural_threshold': 0.4444444444444445,
#   'reconstructed_syntactic_threshold': 0.4444444444444445,
#   'reconstructed_morphological_threshold': 0.4444444444444445},
#  'yo': {'finetune': 0.2631578947368421,
#   'reconstructed_featural_base': 0.4162895927601809,
#   'reconstructed_featural_eu': 0.37554585152838427,
#   'reconstructed_featural': 0.3805309734513274,
#   'baseline_en': 0.4298245614035088,
#   'baseline_task_adapter': 0.3257918552036199,
#   'baseline_avg_adapter': 0.3352601156069364,
#   'baseline_closest_featural': 0.43636363636363634,
#   'no_train_gain': 0.3891402714932127,
#   'reconstructed_featural_sr': 0.37885462555066085,
#   'reconstructed_featural_threshold': 0.4166666666666667,
#   'reconstructed_syntactic_threshold': 0.36681222707423583,
#   'reconstructed_morphological_threshold': 0.4088888888888889},
#  'zea': {'finetune': 0.5253164556962024,
#   'reconstructed_featural_base': 0.6690391459074733,
#   'reconstructed_featural_eu': 0.6738351254480287,
#   'reconstructed_featural': 0.6738351254480287,
#   'baseline_en': 0.6618705035971223,
#   'baseline_task_adapter': 0.5673758865248227,
#   'baseline_avg_adapter': 0.49600000000000005,
#   'baseline_closest_featural': 0.5860805860805861,
#   'no_train_gain': 0.6666666666666667,
#   'reconstructed_featural_sr': 0.6738351254480287,
#   'reconstructed_featural_threshold': 0.6690391459074733,
#   'reconstructed_syntactic_threshold': 0.6690391459074733,
#   'reconstructed_morphological_threshold': 0.6738351254480287},
#  'zh': {'finetune': 0.07080319756376095,
#   'reconstructed_featural_base': 0.19202977205768335,
#   'reconstructed_syntactic_distVar': 0.18804003232423697,
#   'reconstructed_morphological_distVar': 0.18845795842382873,
#   'reconstructed_featural_eu': 0.18997640044714945,
#   'reconstructed_featural': 0.1889078763399099,
#   'baseline_en': 0.1625176803394625,
#   'baseline_task_adapter': 0.1316712896434181,
#   'baseline_avg_adapter': 0.0414521933220972,
#   'baseline_closest_featural': 0.1358886060787543,
#   'no_train_gain': 0.19434007999030423,
#   'reconstructed_featural_limit': 0.20129850336818364,
#   'reconstructed_syntactic_limit': 0.20004279644178158,
#   'reconstructed_morphological_limit': 0.18588171163804854,
#   'reconstructed_featural_sr': 0.18902325581395352,
#   'reconstructed_featural_threshold': 0.1911098789390999,
#   'reconstructed_syntactic_threshold': 0.1924998458027509,
#   'reconstructed_morphological_threshold': 0.18588171163804854},
#  'li': {'finetune': 0.4738955823293173}}

# %%
# we create a dataframe with the "reconstructed" scores, the finetune scores and the token overlap
import pandas as pd
import numpy as np

df = pd.DataFrame.from_dict(typ_dists, orient="index", columns=["similarity"])
# we map the "diff"
for lang in df.index:
    if lang in diffs.keys():
        df.loc[lang, "score"] = diffs[lang]["improvement_finetune"]
# columns are "reconstructed", "finetune", "token_coverage" and "type_overlap"
# rows correspond to the languages
for task in scores.keys():
    if not task == "ner":
        continue
    for lang in scores[task].keys():
        # we get the reconstructed score
        if task in token_overlap.keys():
            if lang in token_overlap[task].keys():
                df.loc[lang, "token_coverage"] = token_overlap[task][lang]["token_coverage"]
                df.loc[lang, "type_overlap"] = token_overlap[task][lang]["type_overlap"]

# %%
df
# Out:
#      similarity     score  token_coverage  type_overlap
# ace      0.4017  0.155123        0.828497      0.702703
# af       0.5189  0.128493        0.797986      0.643863
# als      0.5229  0.248269        0.869502      0.765869
# am       0.4774 -0.004714        0.310611      0.106145
# an       0.4597  0.091968        0.863279      0.807992
# ..          ...       ...             ...           ...
# ht       0.4230 -0.008000             NaN           NaN
# az          NaN       NaN        0.576075      0.422044
# mg          NaN       NaN        0.800000      0.852941
# ms          NaN       NaN        0.812943      0.686671
# or          NaN       NaN        0.306832      0.046036
#
# [186 rows x 4 columns]

# %%
# we can now do a correlation analysis
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# we drop the rows with NaN values
df.dropna(inplace=True)
df
# Out:
#      similarity     score  token_coverage  type_overlap
# ace      0.4017  0.155123        0.828497      0.702703
# af       0.5189  0.128493        0.797986      0.643863
# als      0.5229  0.248269        0.869502      0.765869
# am       0.4774 -0.004714        0.310611      0.106145
# an       0.4597  0.091968        0.863279      0.807992
# ..          ...       ...             ...           ...
# wuu      0.4320  0.171604        0.423152      0.201481
# xmf      0.4333  0.191234        0.255700      0.068148
# yo       0.4519 -0.020798        0.787021      0.843915
# zea      0.3333  0.148519        0.870070      0.749568
# zh       0.4136  0.133941        0.622975      0.050614
#
# [134 rows x 4 columns]

# %%
# we start by plotting a scatter plot with a regression line
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x="token_coverage", y="score", marker="o", color="blue")
plt.title("Token Coverage vs Reconstructed Score")
plt.xlabel("Token Coverage")
plt.ylabel("Reconstructed Score")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x="similarity", y="token_coverage", marker="o", color="blue")
plt.title("distance vs token_coverage")
plt.xlabel("distance to english")
plt.ylabel("token_coverage")
plt.grid()
plt.show()
